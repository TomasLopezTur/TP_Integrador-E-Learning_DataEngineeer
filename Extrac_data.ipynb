# %%
import requests
import pandas as pd
from datetime import datetime, timedelta, timezone
from deltalake import DeltaTable, write_deltalake
from deltalake.exceptions import TableNotFoundError
import pyarrow as pa
from pprint import pprint

# %% [markdown]
# #requests.get?
# # #Signature: requests.get(url, params=None, **kwargs)
# #requests.post?
# # #Signature: requests.post(url, data=None, json=none, **kwargs)

# %%
def get_data(base_url, endpoint, data_field, params=None, headers=None):
        try:
            endpoint_url = f"{base_url}/{endpoint}"
            response = requests.get(endpoint_url, params=params, headers=headers)
            response.raise_for_status()  # Levanta una excepción si hay un error en la respuesta HTTP.

        # Verificar si los datos están en formato JSON.
            try:
                data = response.json()
                data = data[data_field]
            except:
                print("El formato de respuesta no es el esperado")
                return None
            return data

        except requests.exceptions.RequestException as e:
            # Capturar cualquier error de solicitud, como errores HTTP.
            print(f"La petición ha fallado. Código de error : {e}")
        return None

def build_table(json_data):
    try:
        df = pd.json_normalize(json_data)
        return df
    except:
        print("Los datos no están en el formato esperado")
        return None

# %%
# Usar la función para hacer la petición a la API de CoinCap
base_url = "https://api.coincap.io/v2"

# %%
endpoint = "assets"
endpoint2 = "markets"

json_data = get_data(base_url, endpoint, data_field="data")
json_data_times =get_data(base_url, endpoint, data_field="timestamp")

json_data2 = get_data(base_url, endpoint2, data_field="data")
json_data_times2 =get_data(base_url, endpoint2, data_field="timestamp")

# %%
pprint(json_data)

pprint(json_data2)
# Out:
# [{'changePercent24Hr': '0.4410115189809265',
#   'explorer': 'https://blockchain.info/',
#   'id': 'bitcoin',
#   'marketCapUsd': '1790318125119.5495605746329380',
#   'maxSupply': '21000000.0000000000000000',
#   'name': 'Bitcoin',
#   'priceUsd': '90494.5093554215387780',
#   'rank': '1',
#   'supply': '19783721.0000000000000000',
#   'symbol': 'BTC',
#   'volumeUsd24Hr': '12519563199.2030121898396041',
#   'vwap24Hr': '90245.7684177295013732'},
#  {'changePercent24Hr': '0.9786167989928653',
#   'explorer': 'https://etherscan.io/',
#   'id': 'ethereum',
#   'marketCapUsd': '373836104330.3023309222233559',
#   'maxSupply': None,
#   'name': 'Ethereum',
#   'priceUsd': '3104.3320219216994461',
#   'rank': '2',
#   'supply': '120424008.0282661200000000',
#   'symbol': 'ETH',
#   'volumeUsd24Hr': '8879590010.1099003588295158',
#   'vwap24Hr': '3098.6174440684339828'},
#  {'changePercent24Hr': '0.0063896807594976',
#   'explorer': 'https://www.omniexplorer.info/asset/31',
#   'id': 'tether',
#   'marketCapUsd': '127540841059.9573799288127283',
#   'maxSupply': None,
#   'name': 'Tether',
#   'priceUsd': '1.0000129243595765',
#   'rank': '3',
#   'supply': '127539192697.5708600000000000',
#   'symbol': 'USDT',
#   'volumeUsd24Hr': '32612943391.4885063471687289',
#   'vwap24Hr': '0.9997484425731084'},
#  {'changePercent24Hr': '10.1332397767590597',
#   'explorer': 'https://explorer.solana.com/',
#   'id': 'solana',
#   'marketCapUsd': '113864476387.2310060201065602',
#   'maxSupply': None,
#   'name': 'Solana',
#   'priceUsd': '239.9116401878865311',
#   'rank': '4',
#   'supply': '474610053.5099429500000000',
#   'symbol': 'SOL',
#   'volumeUsd24Hr': '3099481184.7674778440186049',
#   'vwap24Hr': '234.2336246087076264'},
#  {'changePercent24Hr': '1.5459438255052078',
#   'explorer': 'https://etherscan.io/token/0xB8c77482e45F1F44dE1745F52C74426C631bDD52',
#   'id': 'binance-coin',
#   'marketCapUsd': '104060595432.3626950723921468',
#   'maxSupply': '166801148.0000000000000000',
#   'name': 'BNB',
#   'priceUsd': '623.8601872953697841',
#   'rank': '5',
#   'supply': '166801148.0000000000000000',
#   'symbol': 'BNB',
#   'volumeUsd24Hr': '481361241.2702568295428748',
#   'vwap24Hr': '626.0740744732262052'},
#  {'changePercent24Hr': '5.7502002447362146',
#   'explorer': 'http://dogechain.info/chain/Dogecoin',
#   'id': 'dogecoin',
#   'marketCapUsd': '54323132468.6564966601152408',
#   'maxSupply': None,
#   'name': 'Dogecoin',
#   'priceUsd': '0.3699581471977607',
#   'rank': '6',
#   'supply': '146835886383.7052600000000000',
#   'symbol': 'DOGE',
#   'volumeUsd24Hr': '2493603582.2985157775229262',
#   'vwap24Hr': '0.3616966795665211'},
#  {'changePercent24Hr': '6.3821169864843951',
#   'explorer': 'https://xrpcharts.ripple.com/#/graph/',
#   'id': 'xrp',
#   'marketCapUsd': '50927349275.8087177242630560',
#   'maxSupply': '100000000000.0000000000000000',
#   'name': 'XRP',
#   'priceUsd': '1.1216482501938779',
#   'rank': '7',
#   'supply': '45404028640.0000000000000000',
#   'symbol': 'XRP',
#   'volumeUsd24Hr': '3268618311.0602444013082951',
#   'vwap24Hr': '1.0675636378092954'},
#  {'changePercent24Hr': '0.0233233457097709',
#   'explorer': 'https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#   'id': 'usd-coin',
#   'marketCapUsd': '37112353586.0741281652769641',
#   'maxSupply': None,
#   'name': 'USDC',
#   'priceUsd': '0.9997335878099693',
#   'rank': '8',
#   'supply': '37122243404.2383040000000000',
#   'symbol': 'USDC',
#   'volumeUsd24Hr': '2827455412.1790508739832810',
#   'vwap24Hr': '0.9983979970026891'},
#  {'changePercent24Hr': '0.4205352771910570',
#   'explorer': 'https://etherscan.io/token/0xae7ab96520de3a18e5e111b5eaab095312d7fe84',
#   'id': 'steth',
#   'marketCapUsd': '30207998399.8456786004092164',
#   'maxSupply': None,
#   'name': 'Lido Staked ETH',
#   'priceUsd': '3085.5794271895293343',
#   'rank': '9',
#   'supply': '9790056.9771948300000000',
#   'symbol': 'STETH',
#   'volumeUsd24Hr': '244414.3786366282098690',
#   'vwap24Hr': '3080.7381754679724450'},
#  {'changePercent24Hr': '2.9167033518750132',
#   'explorer': 'https://cardanoexplorer.com/',
#   'id': 'cardano',
#   'marketCapUsd': '25835015572.6503598295590407',
#   'maxSupply': '45000000000.0000000000000000',
#   'name': 'Cardano',
#   'priceUsd': '0.7374316428826544',
#   'rank': '10',
#   'supply': '35033776787.3101960000000000',
#   'symbol': 'ADA',
#   'volumeUsd24Hr': '706506204.9959540352419973',
#   'vwap24Hr': '0.7201877667112661'},
#  {'changePercent24Hr': '3.5333581363723794',
#   'explorer': 'https://tronscan.org/#/',
#   'id': 'tron',
#   'marketCapUsd': '17452908000.2708166042738476',
#   'maxSupply': None,
#   'name': 'TRON',
#   'priceUsd': '0.2020571166559609',
#   'rank': '11',
#   'supply': '86376111315.0376000000000000',
#   'symbol': 'TRX',
#   'volumeUsd24Hr': '253513834.5452838089222488',
#   'vwap24Hr': '0.1974934530803042'},
#  {'changePercent24Hr': '4.1260663988255249',
#   'explorer': 'https://etherscan.io/token/0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce',
#   'id': 'shiba-inu',
#   'marketCapUsd': '14654560690.7028433692799611',
#   'maxSupply': None,
#   'name': 'Shiba Inu',
#   'priceUsd': '0.0000248694094078',
#   'rank': '12',
#   'supply': '589260502748674.5000000000000000',
#   'symbol': 'SHIB',
#   'volumeUsd24Hr': '552541745.6588112719961159',
#   'vwap24Hr': '0.0000247549873253'},
#  {'changePercent24Hr': '2.7844749650105832',
#   'explorer': 'https://avascan.info/',
#   'id': 'avalanche',
#   'marketCapUsd': '14370554117.3474412742470183',
#   'maxSupply': '715748719.0000000000000000',
#   'name': 'Avalanche',
#   'priceUsd': '35.1335513318767988',
#   'rank': '13',
#   'supply': '409026516.6080431300000000',
#   'symbol': 'AVAX',
#   'volumeUsd24Hr': '337853622.5296091938776539',
#   'vwap24Hr': '35.8981549516325351'},
#  {'changePercent24Hr': '0.5465690808960498',
#   'explorer': 'https://etherscan.io/token/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#   'id': 'wrapped-bitcoin',
#   'marketCapUsd': '13281896007.9157531885658096',
#   'maxSupply': None,
#   'name': 'Wrapped Bitcoin',
#   'priceUsd': '90355.0839915379644656',
#   'rank': '14',
#   'supply': '146996.6649487000000000',
#   'symbol': 'WBTC',
#   'volumeUsd24Hr': '14176251.7842172725088189',
#   'vwap24Hr': '89946.4647130139568387'},
#  {'changePercent24Hr': '0.6237454560307200',
#   'explorer': 'https://etherscan.io/token/0x514910771af9ca656af840dff83e8264ecf986ca',
#   'id': 'chainlink',
#   'marketCapUsd': '8945148456.4156838585349600',
#   'maxSupply': None,
#   'name': 'Chainlink',
#   'priceUsd': '14.2699990078238627',
#   'rank': '15',
#   'supply': '626849970.4527867000000000',
#   'symbol': 'LINK',
#   'volumeUsd24Hr': '242364784.2362964036646263',
#   'vwap24Hr': '14.0865785981047089'},
#  {'changePercent24Hr': '0.3307238909440397',
#   'explorer': 'https://blockchair.com/bitcoin-cash/blocks',
#   'id': 'bitcoin-cash',
#   'marketCapUsd': '8834848726.8296238297433075',
#   'maxSupply': '21000000.0000000000000000',
#   'name': 'Bitcoin Cash',
#   'priceUsd': '446.4360134668136956',
#   'rank': '16',
#   'supply': '19789731.2500000000000000',
#   'symbol': 'BCH',
#   'volumeUsd24Hr': '151387499.1738263475536602',
#   'vwap24Hr': '440.6713133606776820'},
#  {'changePercent24Hr': '0.0818249539907590',
#   'explorer': 'https://polkascan.io/polkadot',
#   'id': 'polkadot',
#   'marketCapUsd': '8228382809.9120091298491256',
#   'maxSupply': None,
#   'name': 'Polkadot',
#   'priceUsd': '5.7186319322527061',
#   'rank': '17',
#   'supply': '1438872602.2922500000000000',
#   'symbol': 'DOT',
#   'volumeUsd24Hr': '231892265.4410588177861934',
#   'vwap24Hr': '5.5810122196866996'},
#  {'changePercent24Hr': '0.0508461587436676',
#   'explorer': 'https://explorer.nearprotocol.com/',
#   'id': 'near-protocol',
#   'marketCapUsd': '7210042565.8733780399326635',
#   'maxSupply': None,
#   'name': 'NEAR Protocol',
#   'priceUsd': '5.9200313064132417',
#   'rank': '18',
#   'supply': '1217906155.0000000000000000',
#   'symbol': 'NEAR',
#   'volumeUsd24Hr': '160118714.7248332037504321',
#   'vwap24Hr': '5.9129488499642290'},
#  {'changePercent24Hr': '3.1119787148367679',
#   'explorer': 'https://eospark.com/account/bitfinexleo1',
#   'id': 'unus-sed-leo',
#   'marketCapUsd': '7163665128.9847910629585721',
#   'maxSupply': None,
#   'name': 'UNUS SED LEO',
#   'priceUsd': '7.7457651012377979',
#   'rank': '19',
#   'supply': '924849260.9000000000000000',
#   'symbol': 'LEO',
#   'volumeUsd24Hr': '1333618.4979927961346137',
#   'vwap24Hr': '7.6112920328462346'},
#  {'changePercent24Hr': '1.5817149950085035',
#   'explorer': 'http://explorer.litecoin.net/chain/Litecoin',
#   'id': 'litecoin',
#   'marketCapUsd': '6922086494.0836924862441799',
#   'maxSupply': '84000000.0000000000000000',
#   'name': 'Litecoin',
#   'priceUsd': '92.0394228843079903',
#   'rank': '20',
#   'supply': '75207843.3041093600000000',
#   'symbol': 'LTC',
#   'volumeUsd24Hr': '488370843.8563088389388323',
#   'vwap24Hr': '88.9175938141822156'},
#  {'changePercent24Hr': '7.2200995634636459',
#   'explorer': 'https://dashboard.stellar.org/',
#   'id': 'stellar',
#   'marketCapUsd': '6464407335.2552415882758205',
#   'maxSupply': '50001806812.0000000000000000',
#   'name': 'Stellar',
#   'priceUsd': '0.2158855949407587',
#   'rank': '21',
#   'supply': '29943671494.2891100000000000',
#   'symbol': 'XLM',
#   'volumeUsd24Hr': '621684306.9986022867938923',
#   'vwap24Hr': '0.2024311560392582'},
#  {'changePercent24Hr': '1.3443709155729649',
#   'explorer': 'https://etherscan.io/token/0x1f9840a85d5af5bf1d1762f925bdaddc4201f984',
#   'id': 'uniswap',
#   'marketCapUsd': '5405141571.4976053789218447',
#   'maxSupply': None,
#   'name': 'Uniswap',
#   'priceUsd': '9.0021916275072832',
#   'rank': '22',
#   'supply': '600425073.7100000000000000',
#   'symbol': 'UNI',
#   'volumeUsd24Hr': '114508877.3119369468252443',
#   'vwap24Hr': '8.9348541449973967'},
#  {'changePercent24Hr': '0.0631892251417168',
#   'explorer': 'https://etherscan.io/token/0x89d24a6b4ccb1b6faa2625fe562bdd9a23260359',
#   'id': 'multi-collateral-dai',
#   'marketCapUsd': '5366464295.7461091244613274',
#   'maxSupply': None,
#   'name': 'Multi Collateral DAI',
#   'priceUsd': '1.0002015873128118',
#   'rank': '23',
#   'supply': '5365382702.6648720000000000',
#   'symbol': 'DAI',
#   'volumeUsd24Hr': '12615074.4734095840162889',
#   'vwap24Hr': '0.9996652636024510'},
#  {'changePercent24Hr': '-8.4826178284287918',
#   'explorer': 'https://etherscan.io/token/0x05aaaa829afa407d83315cded1d45eb16025910c',
#   'id': 'sp8de',
#   'marketCapUsd': '4790032603.1982795395340374',
#   'maxSupply': None,
#   'name': 'Sp8de',
#   'priceUsd': '0.6153882580011177',
#   'rank': '24',
#   'supply': '7783756906.1800000000000000',
#   'symbol': 'SPX',
#   'volumeUsd24Hr': '2636650.9299853480218635',
#   'vwap24Hr': '0.6370559151943196'},
#  {'changePercent24Hr': '13.0357487363660559',
#   'explorer': 'https://etherscan.io/token/0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b',
#   'id': 'crypto-com-coin',
#   'marketCapUsd': '4524442411.4952669919759356',
#   'maxSupply': '30263013692.0000000000000000',
#   'name': 'Crypto.com Coin',
#   'priceUsd': '0.1790935343920593',
#   'rank': '25',
#   'supply': '25263013692.0000000000000000',
#   'symbol': 'CRO',
#   'volumeUsd24Hr': '23388765.7280004263784638',
#   'vwap24Hr': '0.1632910425849030'},
#  {'changePercent24Hr': '-0.8557197848034942',
#   'explorer': 'https://www.dfinityexplorer.org/#/',
#   'id': 'internet-computer',
#   'marketCapUsd': '4367725751.4978337543033057',
#   'maxSupply': None,
#   'name': 'Internet Computer',
#   'priceUsd': '9.2057189357986416',
#   'rank': '26',
#   'supply': '474457864.9379449000000000',
#   'symbol': 'ICP',
#   'volumeUsd24Hr': '64721001.7680037977646966',
#   'vwap24Hr': '9.4369371103861887'},
#  {'changePercent24Hr': '-5.0508351070863081',
#   'explorer': 'http://gastracker.io/',
#   'id': 'ethereum-classic',
#   'marketCapUsd': '3948159510.2899322748189396',
#   'maxSupply': '210700000.0000000000000000',
#   'name': 'Ethereum Classic',
#   'priceUsd': '26.3929891766512535',
#   'rank': '27',
#   'supply': '149591222.2698405000000000',
#   'symbol': 'ETC',
#   'volumeUsd24Hr': '229719378.8097647616414926',
#   'vwap24Hr': '26.6260894123707650'},
#  {'changePercent24Hr': '1.4558362386439533',
#   'explorer': 'https://etherscan.io/token/0x1d287cc25dad7ccaf76a26bc660c5f7c8e2a05bd',
#   'id': 'fetch',
#   'marketCapUsd': '3267902626.2117592560000000',
#   'maxSupply': '2630547141.0000000000000000',
#   'name': 'Artificial Superintelligence Alliance',
#   'priceUsd': '1.2967867564332378',
#   'rank': '28',
#   'supply': '2520000000.0000000000000000',
#   'symbol': 'FET',
#   'volumeUsd24Hr': '91193332.0475563610285784',
#   'vwap24Hr': '1.2816341905599402'},
#  {'changePercent24Hr': '7.9043432902066693',
#   'explorer': 'http://moneroblocks.info/',
#   'id': 'monero',
#   'marketCapUsd': '2958034939.0843445590990696',
#   'maxSupply': None,
#   'name': 'Monero',
#   'priceUsd': '160.3553953621636711',
#   'rank': '29',
#   'supply': '18446744.0737095500000000',
#   'symbol': 'XMR',
#   'volumeUsd24Hr': '43650373.1742213480570341',
#   'vwap24Hr': '152.6544189556331546'},
#  {'changePercent24Hr': '-1.4494078666834650',
#   'explorer': 'https://explorer.xinfin.network/',
#   'id': 'stacks',
#   'marketCapUsd': '2866469176.8793398190673778',
#   'maxSupply': '1818000000.0000000000000000',
#   'name': 'Stacks',
#   'priceUsd': '1.9095310441112041',
#   'rank': '30',
#   'supply': '1501137771.8729600000000000',
#   'symbol': 'STX',
#   'volumeUsd24Hr': '21570563.8534261079240394',
#   'vwap24Hr': '1.9097036048956102'},
#  {'changePercent24Hr': '-0.6097653180955389',
#   'explorer': 'https://protocol.ai',
#   'id': 'filecoin',
#   'marketCapUsd': '2717508805.8615097728799578',
#   'maxSupply': None,
#   'name': 'Filecoin',
#   'priceUsd': '4.5325772028229386',
#   'rank': '31',
#   'supply': '599550473.0000000000000000',
#   'symbol': 'FIL',
#   'volumeUsd24Hr': '149229169.1296065367921374',
#   'vwap24Hr': '4.4805922026576955'},
#  {'changePercent24Hr': '0.5102128045999937',
#   'explorer': 'https://etherscan.io/token/0x75231f58b43240c9718dd58b4967c5114342a86c',
#   'id': 'okb',
#   'marketCapUsd': '2692128591.2571683640000000',
#   'maxSupply': None,
#   'name': 'OKB',
#   'priceUsd': '44.8688098542861394',
#   'rank': '32',
#   'supply': '60000000.0000000000000000',
#   'symbol': 'OKB',
#   'volumeUsd24Hr': '1236937.2140212409704030',
#   'vwap24Hr': '45.6694234549974139'},
#  {'changePercent24Hr': '1.1081112388521599',
#   'explorer': 'https://etherscan.io/token/0x80fB784B7eD66730e8b1DBd9820aFD29931aab03',
#   'id': 'aave',
#   'marketCapUsd': '2493663515.5505160152748604',
#   'maxSupply': None,
#   'name': 'Aave',
#   'priceUsd': '166.4887827476664717',
#   'rank': '33',
#   'supply': '14977967.1302538100000000',
#   'symbol': 'AAVE',
#   'volumeUsd24Hr': '81571383.4990562478546342',
#   'vwap24Hr': '165.7140534889803051'},
#  {'changePercent24Hr': '2.8438212181689620',
#   'explorer': 'https://explore.veforge.com/',
#   'id': 'vechain',
#   'marketCapUsd': '2482537378.1382530007747611',
#   'maxSupply': '86712634466.0000000000000000',
#   'name': 'VeChain',
#   'priceUsd': '0.0306542707401043',
#   'rank': '34',
#   'supply': '80985041177.0000000000000000',
#   'symbol': 'VET',
#   'volumeUsd24Hr': '26100521.9866755304213035',
#   'vwap24Hr': '0.0292774235807196'},
#  {'changePercent24Hr': '42.6666772970763214',
#   'explorer': 'https://etherscan.io/token/0x3593d125a4f7849a1b059e64f4517a86dd60c95d',
#   'id': 'mantra-dao',
#   'marketCapUsd': '2129347703.8818670765239597',
#   'maxSupply': '888888888.0000000000000000',
#   'name': 'MANTRA DAO',
#   'priceUsd': '4.2569497758804009',
#   'rank': '35',
#   'supply': '500205033.1781248500000000',
#   'symbol': 'OM',
#   'volumeUsd24Hr': '543779120.9830202378038664',
#   'vwap24Hr': '3.5870344800600799'},
#  {'changePercent24Hr': '0.2894988952818758',
#   'explorer': 'https://etherscan.io/token/0x4e15361fd6b4bb609fa63c81a2be19d873717870',
#   'id': 'fantom',
#   'marketCapUsd': '1989360838.6923088702811995',
#   'maxSupply': None,
#   'name': 'Fantom',
#   'priceUsd': '0.7095648882243458',
#   'rank': '36',
#   'supply': '2803634835.5265927000000000',
#   'symbol': 'FTM',
#   'volumeUsd24Hr': '118390090.6625669856852017',
#   'vwap24Hr': '0.7242330760276008'},
#  {'changePercent24Hr': '-0.6360183642367053',
#   'explorer': 'https://etherscan.io/token/0xc944e90c64b2c07662a292be6244bdf05cda44a7',
#   'id': 'the-graph',
#   'marketCapUsd': '1892151315.4245718880702474',
#   'maxSupply': None,
#   'name': 'The Graph',
#   'priceUsd': '0.1981614988240158',
#   'rank': '37',
#   'supply': '9548531509.1654740000000000',
#   'symbol': 'GRT',
#   'volumeUsd24Hr': '33703033.2292640817119013',
#   'vwap24Hr': '0.1972323021243865'},
#  {'changePercent24Hr': '-0.5715196714598174',
#   'explorer': 'https://explorer.binance.org/asset/RUNE-B1A',
#   'id': 'thorchain',
#   'marketCapUsd': '1851598301.1707316244180580',
#   'maxSupply': None,
#   'name': 'THORChain',
#   'priceUsd': '5.4669525549595070',
#   'rank': '38',
#   'supply': '338689294.0000000000000000',
#   'symbol': 'RUNE',
#   'volumeUsd24Hr': '76637930.7087352107114884',
#   'vwap24Hr': '5.4849583858108142'},
#  {'changePercent24Hr': '-1.3183415032662560',
#   'explorer': 'https://etherscan.io/token/0xe28b3b32b6c345a34ff64674606124dd5aceca30',
#   'id': 'injective-protocol',
#   'marketCapUsd': '1844048179.4351571782861273',
#   'maxSupply': '100000000.0000000000000000',
#   'name': 'Injective',
#   'priceUsd': '25.2590120896785906',
#   'rank': '39',
#   'supply': '73005554.3300000000000000',
#   'symbol': 'INJ',
#   'volumeUsd24Hr': '61007071.8254239251997230',
#   'vwap24Hr': '25.8011928731050552'},
#  {'changePercent24Hr': '16.6483548242218487',
#   'explorer': 'https://explorer.solana.com/address/4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R',
#   'id': 'raydium',
#   'marketCapUsd': '1739213118.4467194283541310',
#   'maxSupply': None,
#   'name': 'Raydium',
#   'priceUsd': '5.9779330721992093',
#   'rank': '40',
#   'supply': '290938874.2632550000000000',
#   'symbol': 'RAY',
#   'volumeUsd24Hr': '197166201.5403622816007283',
#   'vwap24Hr': '5.7737279479855563'},
#  {'changePercent24Hr': '33.1124464870681606',
#   'explorer': 'https://hash-hash.info/',
#   'id': 'hedera-hashgraph',
#   'marketCapUsd': '1686371552.3987041282124228',
#   'maxSupply': '50000000000.0000000000000000',
#   'name': 'Hedera Hashgraph',
#   'priceUsd': '0.1136923946713151',
#   'rank': '41',
#   'supply': '14832756028.0000000000000000',
#   'symbol': 'HBAR',
#   'volumeUsd24Hr': '234010649.5535554744921912',
#   'vwap24Hr': '0.0907561887154486'},
#  {'changePercent24Hr': '6.7232716757987637',
#   'explorer': 'https://algoexplorer.io/',
#   'id': 'algorand',
#   'marketCapUsd': '1664936209.3489338424966489',
#   'maxSupply': '10000000000.0000000000000000',
#   'name': 'Algorand',
#   'priceUsd': '0.2012268185550742',
#   'rank': '42',
#   'supply': '8273928004.7468120000000000',
#   'symbol': 'ALGO',
#   'volumeUsd24Hr': '56290802.8017011139636243',
#   'vwap24Hr': '0.1877364718952243'},
#  {'changePercent24Hr': '0.6513749836886908',
#   'explorer': 'https://explorer.thetatoken.org/',
#   'id': 'theta',
#   'marketCapUsd': '1500487486.4631612000000000',
#   'maxSupply': '1000000000.0000000000000000',
#   'name': 'THETA',
#   'priceUsd': '1.5004874864631612',
#   'rank': '43',
#   'supply': '1000000000.0000000000000000',
#   'symbol': 'THETA',
#   'volumeUsd24Hr': '24511083.2796931033976456',
#   'vwap24Hr': '1.4872127076129303'},
#  {'changePercent24Hr': '-3.7422233114649326',
#   'explorer': 'https://www.mintscan.io/',
#   'id': 'cosmos',
#   'marketCapUsd': '1499182861.4872450145427183',
#   'maxSupply': None,
#   'name': 'Cosmos',
#   'priceUsd': '6.0340653912011583',
#   'rank': '44',
#   'supply': '248453201.0000000000000000',
#   'symbol': 'ATOM',
#   'volumeUsd24Hr': '125394604.1624046795432298',
#   'vwap24Hr': '5.9479714451490593'},
#  {'changePercent24Hr': '-0.2633674431520142',
#   'explorer': 'https://bsvexplorer.io/',
#   'id': 'bitcoin-sv',
#   'marketCapUsd': '1339097665.3187101435489575',
#   'maxSupply': None,
#   'name': 'Bitcoin SV',
#   'priceUsd': '67.6813580428277091',
#   'rank': '45',
#   'supply': '19785325.0000000000000000',
#   'symbol': 'BSV',
#   'volumeUsd24Hr': '8706727.1170311054175892',
#   'vwap24Hr': '67.3078938369621942'},
#  {'changePercent24Hr': '1.3765813198151017',
#   'explorer': 'https://etherscan.io/token/Maker',
#   'id': 'maker',
#   'marketCapUsd': '1322965022.7055051819891194',
#   'maxSupply': '1005577.0000000000000000',
#   'name': 'Maker',
#   'priceUsd': '1501.8927611554003023',
#   'rank': '46',
#   'supply': '880865.1702187800000000',
#   'symbol': 'MKR',
#   'volumeUsd24Hr': '34854080.0680597744395525',
#   'vwap24Hr': '1491.5020025466832908'},
#  {'changePercent24Hr': '-0.2348094015276974',
#   'explorer': 'https://etherscan.io/token/0xf34960d9d60be18cc1d5afc1a6f012a723a28811',
#   'id': 'kucoin-token',
#   'marketCapUsd': '1310259792.9657986807809898',
#   'maxSupply': '170118638.0000000000000000',
#   'name': 'KuCoin Token',
#   'priceUsd': '10.8954867432972732',
#   'rank': '47',
#   'supply': '120257114.1460797300000000',
#   'symbol': 'KCS',
#   'volumeUsd24Hr': '1150710.0736831540368165',
#   'vwap24Hr': '10.8860860641988938'},
#  {'changePercent24Hr': '0.0579200691246455',
#   'explorer': 'https://viewblock.io/arweave',
#   'id': 'arweave',
#   'marketCapUsd': '1179646215.7722487389205776',
#   'maxSupply': '66000000.0000000000000000',
#   'name': 'Arweave',
#   'priceUsd': '17.9680412274574536',
#   'rank': '48',
#   'supply': '65652466.0000000000000000',
#   'symbol': 'AR',
#   'volumeUsd24Hr': '32875810.4445868392796015',
#   'vwap24Hr': '17.9306672651538183'},
#  {'changePercent24Hr': '3.5469113926463162',
#   'explorer': 'https://etherscan.io/token/0x5a98fcbea516cf06857215779fd812ca3bef1b32',
#   'id': 'lido-dao',
#   'marketCapUsd': '1088639356.4502365027717573',
#   'maxSupply': None,
#   'name': 'Lido DAO',
#   'priceUsd': '1.2153742424842987',
#   'rank': '49',
#   'supply': '895723570.8936793000000000',
#   'symbol': 'LDO',
#   'volumeUsd24Hr': '9544969.5125143676415844',
#   'vwap24Hr': '1.1938760772770749'},
#  {'changePercent24Hr': '6.3438175622734785',
#   'explorer': 'https://etherscan.io/token/0x4a220e6096b25eadb88358cb44068a3248254675',
#   'id': 'quant',
#   'marketCapUsd': '1064071420.5081403719074640',
#   'maxSupply': '14881364.0000000000000000',
#   'name': 'Quant',
#   'priceUsd': '88.1383676601066280',
#   'rank': '50',
#   'supply': '12072738.0000000000000000',
#   'symbol': 'QNT',
#   'volumeUsd24Hr': '27738244.8745294410305664',
#   'vwap24Hr': '81.3503456324042040'},
#  {'changePercent24Hr': '1.1411490477788705',
#   'explorer': 'https://ethplorer.io/es/address/0x15d4c048f83bd7e37d49ea4c83a07267ec4203da#chart=candlestick',
#   'id': 'gala',
#   'marketCapUsd': '1048967274.0322591289424670',
#   'maxSupply': None,
#   'name': 'Gala',
#   'priceUsd': '0.0293069528027811',
#   'rank': '51',
#   'supply': '35792437415.4899100000000000',
#   'symbol': 'GALA',
#   'volumeUsd24Hr': '59985802.2503011736474962',
#   'vwap24Hr': '0.0288100063260637'},
#  {'changePercent24Hr': '2.0495513538050931',
#   'explorer': 'https://flowscan.org/',
#   'id': 'flow',
#   'marketCapUsd': '1047171908.2312438524453089',
#   'maxSupply': None,
#   'name': 'Flow',
#   'priceUsd': '0.6778871178404193',
#   'rank': '52',
#   'supply': '1544758530.8410559000000000',
#   'symbol': 'FLOW',
#   'volumeUsd24Hr': '15892349.3345118413110223',
#   'vwap24Hr': '0.6595300746180738'},
#  {'changePercent24Hr': '-0.5529775370714091',
#   'explorer': 'https://bloks.io/',
#   'id': 'eos',
#   'marketCapUsd': '981311453.1677202864584072',
#   'maxSupply': None,
#   'name': 'EOS',
#   'priceUsd': '0.6421917680369883',
#   'rank': '53',
#   'supply': '1528066073.1098000000000000',
#   'symbol': 'EOS',
#   'volumeUsd24Hr': '68419260.6334733184417973',
#   'vwap24Hr': '0.6326793787306732'},
#  {'changePercent24Hr': '-1.9718129128794819',
#   'explorer': 'https://explorer.helium.com/',
#   'id': 'helium',
#   'marketCapUsd': '981085622.2823310535979689',
#   'maxSupply': None,
#   'name': 'Helium',
#   'priceUsd': '5.7551085339677737',
#   'rank': '54',
#   'supply': '170472132.1052022300000000',
#   'symbol': 'HNT',
#   'volumeUsd24Hr': '3229898.7012481424624577',
#   'vwap24Hr': '5.9028820313120874'},
#  {'changePercent24Hr': '-2.2018794717681073',
#   'explorer': 'https://etherscan.io/token/0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0',
#   'id': 'polygon',
#   'marketCapUsd': '972323037.7468226029625507',
#   'maxSupply': None,
#   'name': 'Polygon',
#   'priceUsd': '0.4144910682654151',
#   'rank': '55',
#   'supply': '2345823860.1276820000000000',
#   'symbol': 'MATIC',
#   'volumeUsd24Hr': '6346326.1679582223663161',
#   'vwap24Hr': '0.4107881123886867'},
#  {'changePercent24Hr': '9.5289059961471691',
#   'explorer': 'https://etherscan.io/token/0x626e8036deb333b408be468f951bdb42433cbf18',
#   'id': 'aioz-network',
#   'marketCapUsd': '917998951.9516683176824506',
#   'maxSupply': None,
#   'name': 'AIOZ Network',
#   'priceUsd': '0.8073423143871614',
#   'rank': '56',
#   'supply': '1137062848.7972965000000000',
#   'symbol': 'AIOZ',
#   'volumeUsd24Hr': '6571883.3227783775853427',
#   'vwap24Hr': '0.7598835874261444'},
#  {'changePercent24Hr': '-2.1562185473892993',
#   'explorer': 'https://explorer.bitcoinabc.org/',
#   'id': 'ecash',
#   'marketCapUsd': '895143320.3496269141446144',
#   'maxSupply': '21000000000000.0000000000000000',
#   'name': 'eCash',
#   'priceUsd': '0.0000452416439716',
#   'rank': '57',
#   'supply': '19785826547584.0000000000000000',
#   'symbol': 'XEC',
#   'volumeUsd24Hr': '8496832.0402411508990307',
#   'vwap24Hr': '0.0000446483822327'},
#  {'changePercent24Hr': '2.0987764744317445',
#   'explorer': None,
#   'id': 'gatetoken',
#   'marketCapUsd': '893908141.9919600364390414',
#   'maxSupply': None,
#   'name': 'GateToken',
#   'priceUsd': '9.8214544673333912',
#   'rank': '58',
#   'supply': '91015861.7509391900000000',
#   'symbol': 'GT',
#   'volumeUsd24Hr': '4400687.7064045409555264',
#   'vwap24Hr': '9.7584074101165237'},
#  {'changePercent24Hr': '-0.7398150331264402',
#   'explorer': 'https://neotracker.io',
#   'id': 'neo',
#   'marketCapUsd': '873830193.0002443970311261',
#   'maxSupply': '100000000.0000000000000000',
#   'name': 'Neo',
#   'priceUsd': '12.3879313083632531',
#   'rank': '59',
#   'supply': '70538831.0000000000000000',
#   'symbol': 'NEO',
#   'volumeUsd24Hr': '12844074.1427788743496248',
#   'vwap24Hr': '12.3120550216122433'},
#  {'changePercent24Hr': '-1.0808426416211090',
#   'explorer': 'https://etherscan.io/token/0xf5d669627376ebd411e34b98f19c868c8aba5ada',
#   'id': 'axie-infinity',
#   'marketCapUsd': '871904994.2041899786764087',
#   'maxSupply': None,
#   'name': 'Axie Infinity',
#   'priceUsd': '5.6817538061255567',
#   'rank': '60',
#   'supply': '153457017.6666543200000000',
#   'symbol': 'AXS',
#   'volumeUsd24Hr': '26249642.2743471158605289',
#   'vwap24Hr': '5.6381508651664082'},
#  {'changePercent24Hr': '-0.2397116164150720',
#   'explorer': 'https://etherscan.io/token/0x3845badAde8e6dFF049820680d1F14bD3903a5d0',
#   'id': 'the-sandbox',
#   'marketCapUsd': '864331733.2349020439509401',
#   'maxSupply': None,
#   'name': 'The Sandbox',
#   'priceUsd': '0.3610058205167870',
#   'rank': '61',
#   'supply': '2394232126.2233224000000000',
#   'symbol': 'SAND',
#   'volumeUsd24Hr': '60528597.5336424728245353',
#   'vwap24Hr': '0.3559419337630121'},
#  {'changePercent24Hr': '-0.8622769079368242',
#   'explorer': 'https://etherscan.io/token/0x808507121b80c02388fad14726482e061b8da827',
#   'id': 'pendle',
#   'marketCapUsd': '851472405.9804399902816592',
#   'maxSupply': None,
#   'name': 'Pendle',
#   'priceUsd': '5.1993761546750281',
#   'rank': '62',
#   'supply': '163764340.3074111300000000',
#   'symbol': 'PENDLE',
#   'volumeUsd24Hr': '5342920.7707245993908361',
#   'vwap24Hr': '5.3050936447005066'},
#  {'changePercent24Hr': '-0.1959379240110633',
#   'explorer': 'https://tzkt.io/',
#   'id': 'tezos',
#   'marketCapUsd': '837942977.9235165197856739',
#   'maxSupply': None,
#   'name': 'Tezos',
#   'priceUsd': '0.8270467804415480',
#   'rank': '63',
#   'supply': '1013174826.0674580000000000',
#   'symbol': 'XTZ',
#   'volumeUsd24Hr': '22794108.7821583630878647',
#   'vwap24Hr': '0.8034723075658109'},
#  {'changePercent24Hr': '4.6183891905479074',
#   'explorer': 'https://akash.bigdipper.live/',
#   'id': 'akash-network',
#   'marketCapUsd': '836337762.6928162366561162',
#   'maxSupply': '388539008.0000000000000000',
#   'name': 'Akash Network',
#   'priceUsd': '3.3684478962408829',
#   'rank': '64',
#   'supply': '248285794.6611410000000000',
#   'symbol': 'AKT',
#   'volumeUsd24Hr': '2377526.8541961439692265',
#   'vwap24Hr': '3.2833519284415969'},
#  {'changePercent24Hr': '0.0637185905949746',
#   'explorer': 'https://etherscan.io/token/decentraland',
#   'id': 'decentraland',
#   'marketCapUsd': '789454750.1400442283432223',
#   'maxSupply': None,
#   'name': 'Decentraland',
#   'priceUsd': '0.4064629388545341',
#   'rank': '65',
#   'supply': '1942255184.1130493000000000',
#   'symbol': 'MANA',
#   'volumeUsd24Hr': '31091014.7480983553418831',
#   'vwap24Hr': '0.3993909726506379'},
#  {'changePercent24Hr': '0.3080209773873194',
#   'explorer': 'https://etherscan.io/token/0xb62132e35a6c13ee1ee0f84dc5d40bad8d815206',
#   'id': 'nexo',
#   'marketCapUsd': '788996391.8980443382250023',
#   'maxSupply': None,
#   'name': 'Nexo',
#   'priceUsd': '1.2210809751826132',
#   'rank': '66',
#   'supply': '646145839.5746847000000000',
#   'symbol': 'NEXO',
#   'volumeUsd24Hr': '630686.5833341938984105',
#   'vwap24Hr': '1.2345898979668363'},
#  {'changePercent24Hr': '-1.5672619977168638',
#   'explorer': 'https://minaexplorer.com/',
#   'id': 'mina',
#   'marketCapUsd': '785877285.6724524019813797',
#   'maxSupply': None,
#   'name': 'Mina',
#   'priceUsd': '0.6642480552360747',
#   'rank': '67',
#   'supply': '1183108146.8400393000000000',
#   'symbol': 'MINA',
#   'volumeUsd24Hr': '20788306.1478718467420943',
#   'vwap24Hr': '0.6668229466340283'},
#  {'changePercent24Hr': '7.3962137512348520',
#   'explorer': 'https://explorer.zcha.in/',
#   'id': 'zcash',
#   'marketCapUsd': '758556780.9768787697725238',
#   'maxSupply': '21000000.0000000000000000',
#   'name': 'Zcash',
#   'priceUsd': '46.4566570155748306',
#   'rank': '68',
#   'supply': '16328268.7500000000000000',
#   'symbol': 'ZEC',
#   'volumeUsd24Hr': '79187109.7264357099244670',
#   'vwap24Hr': '43.7541641583088574'},
#  {'changePercent24Hr': '-2.5530739062409496',
#   'explorer': 'https://explorer.elrond.com/',
#   'id': 'elrond-egld',
#   'marketCapUsd': '726039630.1687125041053616',
#   'maxSupply': '31415926.0000000000000000',
#   'name': 'MultiversX',
#   'priceUsd': '30.0207923770501272',
#   'rank': '69',
#   'supply': '24184559.1898415400000000',
#   'symbol': 'EGLD',
#   'volumeUsd24Hr': '12339135.8899752904634987',
#   'vwap24Hr': '30.2475309745995799'},
#  {'changePercent24Hr': '1.6528733819690193',
#   'explorer': 'http://www.confluxscan.io/',
#   'id': 'conflux-network',
#   'marketCapUsd': '719238691.6861028801847310',
#   'maxSupply': None,
#   'name': 'Conflux',
#   'priceUsd': '0.1554026935077404',
#   'rank': '70',
#   'supply': '4628225389.4800000000000000',
#   'symbol': 'CFX',
#   'volumeUsd24Hr': '18574390.6115008284498579',
#   'vwap24Hr': '0.1539983415932176'},
#  {'changePercent24Hr': '-0.6876683495844674',
#   'explorer': 'https://etherscan.io/token/Gnosis',
#   'id': 'gnosis-gno',
#   'marketCapUsd': '669253776.4190775537081468',
#   'maxSupply': '3000000.0000000000000000',
#   'name': 'Gnosis',
#   'priceUsd': '258.4402524336217011',
#   'rank': '71',
#   'supply': '2589588.0000000000000000',
#   'symbol': 'GNO',
#   'volumeUsd24Hr': '4083631.0061882470921876',
#   'vwap24Hr': '255.6680484881150722'},
#  {'changePercent24Hr': '-1.0783241532457357',
#   'explorer': 'https://etherscan.io/token/0x3506424f91fd33084466f402d5d97f05f8e3b4af',
#   'id': 'chiliz',
#   'marketCapUsd': '653423189.5953573210655065',
#   'maxSupply': None,
#   'name': 'Chiliz',
#   'priceUsd': '0.0716329461618195',
#   'rank': '72',
#   'supply': '9121824867.0000000000000000',
#   'symbol': 'CHZ',
#   'volumeUsd24Hr': '32113698.0778320762669606',
#   'vwap24Hr': '0.0709946747047163'},
#  {'changePercent24Hr': '1.7291885763645776',
#   'explorer': 'https://etherscan.io/token/0xe53ec727dbdeb9e2d5456c3be40cff031ab40a55',
#   'id': 'superfarm',
#   'marketCapUsd': '650001364.5629587358636096',
#   'maxSupply': '1000000000.0000000000000000',
#   'name': 'SuperVerse',
#   'priceUsd': '1.3320352642923641',
#   'rank': '73',
#   'supply': '487976093.4169172600000000',
#   'symbol': 'SUPER',
#   'volumeUsd24Hr': '7510108.3023151968339125',
#   'vwap24Hr': '1.3393240722950932'},
#  {'changePercent24Hr': '2.3017225893749471',
#   'explorer': 'https://etherscan.io/token/0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9',
#   'id': 'ftx-token',
#   'marketCapUsd': '648353661.2780183035805030',
#   'maxSupply': None,
#   'name': 'FTX Token',
#   'priceUsd': '1.9713083404435382',
#   'rank': '74',
#   'supply': '328895103.8132070000000000',
#   'symbol': 'FTT',
#   'volumeUsd24Hr': '18620839.1105733917486064',
#   'vwap24Hr': '1.9564591904192347'},
#  {'changePercent24Hr': '1.5230130489273135',
#   'explorer': 'https://explorer.nervos.org/',
#   'id': 'nervos-network',
#   'marketCapUsd': '601696973.9286749458691514',
#   'maxSupply': None,
#   'name': 'Nervos Network',
#   'priceUsd': '0.0133488547131831',
#   'rank': '75',
#   'supply': '45074801311.1903400000000000',
#   'symbol': 'CKB',
#   'volumeUsd24Hr': '24088068.3102077783008724',
#   'vwap24Hr': '0.0130229276315704'},
#  {'changePercent24Hr': '1.6343054063132579',
#   'explorer': 'https://www.oasisscan.com/',
#   'id': 'oasis-network',
#   'marketCapUsd': '584877460.8398651269942537',
#   'maxSupply': None,
#   'name': 'Oasis',
#   'priceUsd': '0.0827953674218177',
#   'rank': '76',
#   'supply': '7064132681.0000000000000000',
#   'symbol': 'ROSE',
#   'volumeUsd24Hr': '13963917.6989864935007221',
#   'vwap24Hr': '0.0811390688441483'},
#  {'changePercent24Hr': '-2.9683772129886760',
#   'explorer': 'https://thetangle.org/',
#   'id': 'iota',
#   'marketCapUsd': '558424989.9793257504279451',
#   'maxSupply': '4600000000.0000000000000000',
#   'name': 'IOTA',
#   'priceUsd': '0.1587981514544449',
#   'rank': '77',
#   'supply': '3516571099.0000000000000000',
#   'symbol': 'IOTA',
#   'volumeUsd24Hr': '7210803.6492145500933016',
#   'vwap24Hr': '0.1590469609722210'},
#  {'changePercent24Hr': '1.9215136312975468',
#   'explorer': 'https://bscscan.com/token/0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82',
#   'id': 'pancakeswap',
#   'marketCapUsd': '540668905.9521573572310429',
#   'maxSupply': '450000000.0000000000000000',
#   'name': 'PancakeSwap',
#   'priceUsd': '1.9209652831900880',
#   'rank': '78',
#   'supply': '281456885.5998715000000000',
#   'symbol': 'CAKE',
#   'volumeUsd24Hr': '14868744.9757510280295108',
#   'vwap24Hr': '1.9126256640909243'},
#  {'changePercent24Hr': '3.1674927706810995',
#   'explorer': 'https://etherscan.io/token/0xde4EE8057785A7e8e800Db58F9784845A5C2Cbd6',
#   'id': 'dexe',
#   'marketCapUsd': '526807480.4357226060351291',
#   'maxSupply': None,
#   'name': 'DeXe',
#   'priceUsd': '9.2255257500207626',
#   'rank': '79',
#   'supply': '57103247.5232684700000000',
#   'symbol': 'DEXE',
#   'volumeUsd24Hr': '701153.1476582953372864',
#   'vwap24Hr': '9.3791481018600142'},
#  {'changePercent24Hr': '-5.8818874099307360',
#   'explorer': 'https://etherscan.io/token/0x41ab1b6fcbb2fa9dced81acbdec13ea6315f2bf2',
#   'id': 'xinfin-network',
#   'marketCapUsd': '502068231.8698203626911947',
#   'maxSupply': None,
#   'name': 'XinFin Network',
#   'priceUsd': '0.0408408235850078',
#   'rank': '80',
#   'supply': '12293293518.5500000000000000',
#   'symbol': 'XDC',
#   'volumeUsd24Hr': '2056931.8986606714398720',
#   'vwap24Hr': '0.0399894863358674'},
#  {'changePercent24Hr': '8.2580064816019261',
#   'explorer': 'https://www.mintscan.io/kava',
#   'id': 'kava',
#   'marketCapUsd': '501011841.2972379880175856',
#   'maxSupply': None,
#   'name': 'Kava',
#   'priceUsd': '0.4626770900394419',
#   'rank': '81',
#   'supply': '1082854224.0000000000000000',
#   'symbol': 'KAVA',
#   'volumeUsd24Hr': '98479742.9831542608245399',
#   'vwap24Hr': '0.4580782583666530'},
#  {'changePercent24Hr': '-0.0502264605489073',
#   'explorer': 'https://etherscan.io/token/0x8dd5fbce2f6a956c3022ba3663759011dd51e73e',
#   'id': 'trueusd',
#   'marketCapUsd': '494177779.8822606449717586',
#   'maxSupply': None,
#   'name': 'TrueUSD',
#   'priceUsd': '0.9971271826727715',
#   'rank': '82',
#   'supply': '495601552.6100000000000000',
#   'symbol': 'TUSD',
#   'volumeUsd24Hr': '5359356.3549602839916020',
#   'vwap24Hr': '0.9965580278905417'},
#  {'changePercent24Hr': '4.2490634774022647',
#   'explorer': 'https://etherscan.io/token/0xc00e94cb662c3520282e6f5717214004a7f26888',
#   'id': 'compound',
#   'marketCapUsd': '473163367.0728007153488305',
#   'maxSupply': None,
#   'name': 'Compound',
#   'priceUsd': '53.5199074287423009',
#   'rank': '83',
#   'supply': '8840885.3790112000000000',
#   'symbol': 'COMP',
#   'volumeUsd24Hr': '12960552.5107856688528329',
#   'vwap24Hr': '52.3740077479358986'},
#  {'changePercent24Hr': '-4.9479888228971511',
#   'explorer': 'https://explorer.thetatoken.org/',
#   'id': 'theta-fuel',
#   'marketCapUsd': '450539862.3485745112801785',
#   'maxSupply': None,
#   'name': 'Theta Fuel',
#   'priceUsd': '0.0667601212850989',
#   'rank': '84',
#   'supply': '6748637565.0000000000000000',
#   'symbol': 'TFUEL',
#   'volumeUsd24Hr': '13364763.7931879199857035',
#   'vwap24Hr': '0.0677749344864111'},
#  {'changePercent24Hr': '-4.6271576639771400',
#   'explorer': 'https://etherscan.io/token/0x4691937a7508860f876c9c0a2a617e7d9e945d4b',
#   'id': 'wootrade',
#   'marketCapUsd': '441925789.6009925261940448',
#   'maxSupply': None,
#   'name': 'WOO',
#   'priceUsd': '0.2397806740975546',
#   'rank': '85',
#   'supply': '1843041734.9698305000000000',
#   'symbol': 'WOO',
#   'volumeUsd24Hr': '3209376.0398378029265736',
#   'vwap24Hr': '0.2435234330115784'},
#  {'changePercent24Hr': '-3.4945379536139257',
#   'explorer': 'https://etherscan.io/token/0xd7c49cee7e9188cca6ad8ff264c1da2e69d4cf3b',
#   'id': 'nxm',
#   'marketCapUsd': '437346720.7356503810549692',
#   'maxSupply': None,
#   'name': 'NXM',
#   'priceUsd': '66.3242676996783650',
#   'rank': '86',
#   'supply': '6594067.8412913900000000',
#   'symbol': 'NXM',
#   'volumeUsd24Hr': '527152.0182226419323419',
#   'vwap24Hr': '68.6360499012047508'},
#  {'changePercent24Hr': '0.6052270207007003',
#   'explorer': 'https://etherscan.io/token/0xD533a949740bb3306d119CC777fa900bA034cd52',
#   'id': 'curve-dao-token',
#   'marketCapUsd': '410323599.1720860729670770',
#   'maxSupply': None,
#   'name': 'Curve DAO Token',
#   'priceUsd': '0.3322541052411915',
#   'rank': '87',
#   'supply': '1234969238.0000000000000000',
#   'symbol': 'CRV',
#   'volumeUsd24Hr': '20612512.8361675211561532',
#   'vwap24Hr': '0.3271932338585319'},
#  {'changePercent24Hr': '1.2245497696477869',
#   'explorer': 'https://explorer.binance.org/asset/TWT-8C2',
#   'id': 'trust-wallet-token',
#   'marketCapUsd': '401939292.4154671732987800',
#   'maxSupply': None,
#   'name': 'Trust Wallet Token',
#   'priceUsd': '0.9646931210483122',
#   'rank': '88',
#   'supply': '416649900.0000000000000000',
#   'symbol': 'TWT',
#   'volumeUsd24Hr': '3266478.0400565532171903',
#   'vwap24Hr': '0.9610778708466924'},
#  {'changePercent24Hr': '3.5442083013819283',
#   'explorer': 'https://etherscan.io/token/0x6fb3e0a217407efff7ca062d46c26e5d60a14d69',
#   'id': 'iotex',
#   'marketCapUsd': '398664000.5438534476677222',
#   'maxSupply': '10000000000.0000000000000000',
#   'name': 'IoTeX',
#   'priceUsd': '0.0422252321815846',
#   'rank': '89',
#   'supply': '9441369057.0000000000000000',
#   'symbol': 'IOTX',
#   'volumeUsd24Hr': '5273177.0422937849718503',
#   'vwap24Hr': '0.0414800978375104'},
#  {'changePercent24Hr': '4.4642934399230361',
#   'explorer': 'https://etherscan.io/token/0x8762db106b2c2a0bccb3a80d1ed41273552616e8',
#   'id': 'reserve-rights',
#   'marketCapUsd': '397954645.0493133610926864',
#   'maxSupply': '100000000000.0000000000000000',
#   'name': 'Reserve Rights',
#   'priceUsd': '0.0075451017918324',
#   'rank': '90',
#   'supply': '52743442836.0000000000000000',
#   'symbol': 'RSR',
#   'volumeUsd24Hr': '6139072.7355411666822023',
#   'vwap24Hr': '0.0073568294553846'},
#  {'changePercent24Hr': '0.9803321994513674',
#   'explorer': None,
#   'id': 'amp',
#   'marketCapUsd': '394725982.8194879826357788',
#   'maxSupply': None,
#   'name': 'Amp',
#   'priceUsd': '0.0048899082378844',
#   'rank': '91',
#   'supply': '80722574661.2915300000000000',
#   'symbol': 'AMP',
#   'volumeUsd24Hr': '6344764.4622694775276041',
#   'vwap24Hr': '0.0049382933260254'},
#  {'changePercent24Hr': '-0.5081746223274495',
#   'explorer': 'https://etherscan.io/token/0x111111111117dc0aa78b770fa6a738034120c302',
#   'id': '1inch',
#   'marketCapUsd': '392249655.6501691663634012',
#   'maxSupply': None,
#   'name': '1inch Network',
#   'priceUsd': '0.3067679695646064',
#   'rank': '92',
#   'supply': '1278652579.6903970000000000',
#   'symbol': '1INCH',
#   'volumeUsd24Hr': '13226872.4300090908469425',
#   'vwap24Hr': '0.3058782487182465'},
#  {'changePercent24Hr': '1.5923639812844817',
#   'explorer': 'https://etherscan.io/token/0xc011a72400e58ecd99ee497cf89e3775d4bd732f',
#   'id': 'synthetix-network-token',
#   'marketCapUsd': '389464201.3643479275799024',
#   'maxSupply': '212424133.0000000000000000',
#   'name': 'Synthetix',
#   'priceUsd': '1.6663941667703133',
#   'rank': '93',
#   'supply': '233716733.4900000000000000',
#   'symbol': 'SNX',
#   'volumeUsd24Hr': '16395797.1968406420747989',
#   'vwap24Hr': '1.6556192724442493'},
#  {'changePercent24Hr': '-2.4666702109105317',
#   'explorer': 'https://explorer.livepeer.org/',
#   'id': 'livepeer',
#   'marketCapUsd': '384141229.0594592897784622',
#   'maxSupply': None,
#   'name': 'Livepeer',
#   'priceUsd': '10.6939826850854956',
#   'rank': '94',
#   'supply': '35921250.3303569900000000',
#   'symbol': 'LPT',
#   'volumeUsd24Hr': '10143273.5137620002565688',
#   'vwap24Hr': '10.8353824759572047'},
#  {'changePercent24Hr': '-2.6549015489023864',
#   'explorer': 'https://etherscan.io/token/0x05f4a42e251f2d52b8ed15e9fedaacfcef1fad27',
#   'id': 'zilliqa',
#   'marketCapUsd': '373027066.1150615392842031',
#   'maxSupply': None,
#   'name': 'Zilliqa',
#   'priceUsd': '0.0194580317328216',
#   'rank': '95',
#   'supply': '19170853004.9235900000000000',
#   'symbol': 'ZIL',
#   'volumeUsd24Hr': '15776018.4770788059277486',
#   'vwap24Hr': '0.0193872502329087'},
#  {'changePercent24Hr': '1.5267295504027512',
#   'explorer': 'https://etherscan.io/token/0x6c6ee5e31d828de241282b9606c8e98ea48526e2',
#   'id': 'holo',
#   'marketCapUsd': '361160520.5344787543269489',
#   'maxSupply': None,
#   'name': 'Holo',
#   'priceUsd': '0.0020749585411858',
#   'rank': '96',
#   'supply': '174056740588.2154500000000000',
#   'symbol': 'HOT',
#   'volumeUsd24Hr': '6134575.8264970675947848',
#   'vwap24Hr': '0.0020899056327912'},
#  {'changePercent24Hr': '-0.4622208808440222',
#   'explorer': 'https://explorer.celo.org/blocks',
#   'id': 'celo',
#   'marketCapUsd': '360679631.9562194426236990',
#   'maxSupply': '1000000000.0000000000000000',
#   'name': 'Celo',
#   'priceUsd': '0.6512421157922762',
#   'rank': '97',
#   'supply': '553833395.0000000000000000',
#   'symbol': 'CELO',
#   'volumeUsd24Hr': '9046892.0924680387113210',
#   'vwap24Hr': '0.6470334757006440'},
#  {'changePercent24Hr': '-0.8785240429850314',
#   'explorer': 'https://etherscan.io/token/Golem',
#   'id': 'golem-network-tokens',
#   'marketCapUsd': '348043399.8064521000000000',
#   'maxSupply': '1000000000.0000000000000000',
#   'name': 'Golem',
#   'priceUsd': '0.3480433998064521',
#   'rank': '98',
#   'supply': '1000000000.0000000000000000',
#   'symbol': 'GLM',
#   'volumeUsd24Hr': '316139.8409639371720295',
#   'vwap24Hr': '0.3495728976426609'},
#  {'changePercent24Hr': '-3.3255487107701925',
#   'explorer': 'https://explorer.dash.org',
#   'id': 'dash',
#   'marketCapUsd': '340391972.9714778376307934',
#   'maxSupply': '18900000.0000000000000000',
#   'name': 'Dash',
#   'priceUsd': '28.2980862480642648',
#   'rank': '99',
#   'supply': '12028798.3430244300000000',
#   'symbol': 'DASH',
#   'volumeUsd24Hr': '20608952.7166975735220679',
#   'vwap24Hr': '28.3387193154573330'},
#  {'changePercent24Hr': '4.5124636464646054',
#   'explorer': 'https://etherscan.io/token/ZRX',
#   'id': '0x',
#   'marketCapUsd': '338390924.6696779395400215',
#   'maxSupply': '1000000000.0000000000000000',
#   'name': '0x Protocol',
#   'priceUsd': '0.3988593771691450',
#   'rank': '100',
#   'supply': '848396562.8973439000000000',
#   'symbol': 'ZRX',
#   'volumeUsd24Hr': '11179012.0056447313101551',
#   'vwap24Hr': '0.3798863203297778'}]
# [{'baseId': 'bitcoin',
#   'baseSymbol': 'BTC',
#   'exchangeId': 'alterdice',
#   'percentExchangeVolume': '100.0000000000000000',
#   'priceQuote': '90488.7200000000000000',
#   'priceUsd': '90487.2968923742133047',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '1',
#   'tradesCount24Hr': '7',
#   'updated': 1731901429141,
#   'volumeUsd24Hr': '33972182.8691674586957539'},
#  {'baseId': 'ethereum',
#   'baseSymbol': 'ETH',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '23.4033242117026192',
#   'priceQuote': '3104.7200000000000000',
#   'priceUsd': '3104.6711723592959159',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '1',
#   'tradesCount24Hr': None,
#   'updated': 1731901423330,
#   'volumeUsd24Hr': '28927631.4545180456406826'},
#  {'baseId': 'chainlink',
#   'baseSymbol': 'LINK',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '10.9112962164268855',
#   'priceQuote': '14.2650000000000000',
#   'priceUsd': '14.2647756556808202',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '2',
#   'tradesCount24Hr': None,
#   'updated': 1731901098057,
#   'volumeUsd24Hr': '13486885.5716677303289241'},
#  {'baseId': 'bitcoin',
#   'baseSymbol': 'BTC',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '5.3607794070065404',
#   'priceQuote': '90517.3000000000000000',
#   'priceUsd': '90515.8764428992296274',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '3',
#   'tradesCount24Hr': None,
#   'updated': 1731901408218,
#   'volumeUsd24Hr': '6626180.5200011426889621'},
#  {'baseId': 'binance-coin',
#   'baseSymbol': 'BNB',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '4.4513114906814356',
#   'priceQuote': '626.0800000000000000',
#   'priceUsd': '626.0701536984681347',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '4',
#   'tradesCount24Hr': None,
#   'updated': 1731893357144,
#   'volumeUsd24Hr': '5502034.5454730611391885'},
#  {'baseId': 'chiliz',
#   'baseSymbol': 'CHZ',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '4.3493402526371221',
#   'priceQuote': '0.0704520000000000',
#   'priceUsd': '0.0704508920079934',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '5',
#   'tradesCount24Hr': None,
#   'updated': 1731893405390,
#   'volumeUsd24Hr': '5375993.2033789403380056'},
#  {'baseId': 'polkadot',
#   'baseSymbol': 'DOT',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '4.2089597212022512',
#   'priceQuote': '5.7023000000000000',
#   'priceUsd': '5.7022103204618816',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '6',
#   'tradesCount24Hr': None,
#   'updated': 1731900807251,
#   'volumeUsd24Hr': '5202476.1320431201636921'},
#  {'baseId': 'livepeer',
#   'baseSymbol': 'LPT',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '3.7065211200987884',
#   'priceQuote': '10.6140200000000000',
#   'priceUsd': '10.6138530743013908',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '7',
#   'tradesCount24Hr': None,
#   'updated': 1731900458040,
#   'volumeUsd24Hr': '4581437.9175668704908997'},
#  {'baseId': 'gnosis-gno',
#   'baseSymbol': 'GNO',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '2.6690351084205848',
#   'priceQuote': '258.4926000000000000',
#   'priceUsd': '258.4885347110858742',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '8',
#   'tradesCount24Hr': None,
#   'updated': 1731900577614,
#   'volumeUsd24Hr': '3299055.4357638092162226'},
#  {'baseId': 'small-love-potion',
#   'baseSymbol': 'SLP',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '2.3024944652405258',
#   'priceQuote': '0.0029530000000000',
#   'priceUsd': '0.0029529535584455',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '9',
#   'tradesCount24Hr': None,
#   'updated': 1731898152795,
#   'volumeUsd24Hr': '2845993.6167204812238670'},
#  {'baseId': 'litecoin',
#   'baseSymbol': 'LTC',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '1.9366532652715164',
#   'priceQuote': '0.0278777300000000',
#   'priceUsd': '86.5548203352850216',
#   'quoteId': 'ethereum',
#   'quoteSymbol': 'ETH',
#   'rank': '10',
#   'tradesCount24Hr': None,
#   'updated': 1731901315342,
#   'volumeUsd24Hr': '2393796.3430404349083792'},
#  {'baseId': 'fantom',
#   'baseSymbol': 'FTM',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '1.4607377801520425',
#   'priceQuote': '0.7073850000000000',
#   'priceUsd': '0.7073738750223468',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '11',
#   'tradesCount24Hr': None,
#   'updated': 1731901055448,
#   'volumeUsd24Hr': '1805541.9723151773265213'},
#  {'baseId': 'myneighboralice',
#   'baseSymbol': 'ALICE',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '1.4138266496627887',
#   'priceQuote': '1.2956000000000000',
#   'priceUsd': '1.2955796242201241',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '12',
#   'tradesCount24Hr': None,
#   'updated': 1731893426772,
#   'volumeUsd24Hr': '1747557.5645604290728366'},
#  {'baseId': 'uma',
#   'baseSymbol': 'UMA',
# ...
#  {'baseId': 'nxm',
#   'baseSymbol': 'NXM',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3452837819005292',
#   'priceQuote': '66.1512210000000000',
#   'priceUsd': '66.1501806459419450',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '56',
#   'tradesCount24Hr': None,
#   'updated': 1731900818542,
#   'volumeUsd24Hr': '426787.3187453501714351'},
#  {'baseId': 'sushiswap',
#   'baseSymbol': 'SUSHI',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3282726362812612',
#   'priceQuote': '0.7635000000000000',
#   'priceUsd': '0.7634879925069966',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '57',
#   'tradesCount24Hr': None,
#   'updated': 1731898131335,
#   'volumeUsd24Hr': '405760.7266833875387645'},
#  {'baseId': 'algorand',
#   'baseSymbol': 'ALGO',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3233388130110834',
#   'priceQuote': '0.0000458400000000',
#   'priceUsd': '0.1423241047305310',
#   'quoteId': 'ethereum',
#   'quoteSymbol': 'ETH',
#   'rank': '58',
#   'tradesCount24Hr': None,
#   'updated': 1731901085505,
#   'volumeUsd24Hr': '399662.2844308950956395'},
#  {'baseId': 'ethereum-classic',
#   'baseSymbol': 'ETC',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3225826017546700',
#   'priceQuote': '26.5500000000000000',
#   'priceUsd': '26.5495824506362270',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '59',
#   'tradesCount24Hr': None,
#   'updated': 1731901297763,
#   'volumeUsd24Hr': '398727.5710402073088729'},
#  {'baseId': 'maker',
#   'baseSymbol': 'MKR',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3169781608345637',
#   'priceQuote': '1505.5700000000000000',
#   'priceUsd': '1505.5463220415963926',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '60',
#   'tradesCount24Hr': None,
#   'updated': 1731901337843,
#   'volumeUsd24Hr': '391800.2132008287578640'},
#  {'baseId': 'balancer',
#   'baseSymbol': 'BAL',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3069451799009056',
#   'priceQuote': '2.2520000000000000',
#   'priceUsd': '2.2519645830068845',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '61',
#   'tradesCount24Hr': None,
#   'updated': 1731900803485,
#   'volumeUsd24Hr': '379398.9674541266415055'},
#  {'baseId': 'uquid-coin',
#   'baseSymbol': 'UQC',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2970065695103894',
#   'priceQuote': '0.0021600000000000',
#   'priceUsd': '6.7063714270930828',
#   'quoteId': 'ethereum',
#   'quoteSymbol': 'ETH',
#   'rank': '62',
#   'tradesCount24Hr': None,
#   'updated': 1731898128829,
#   'volumeUsd24Hr': '367114.3682259908199126'},
#  {'baseId': 'kusama',
#   'baseSymbol': 'KSM',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2964515448072257',
#   'priceQuote': '0.0068070300000000',
#   'priceUsd': '21.1344775441506608',
#   'quoteId': 'ethereum',
#   'quoteSymbol': 'ETH',
#   'rank': '63',
#   'tradesCount24Hr': None,
#   'updated': 1731900784660,
#   'volumeUsd24Hr': '366428.3310666523150890'},
#  {'baseId': 'marlin',
#   'baseSymbol': 'POND',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2681576026181401',
#   'priceQuote': '0.0173830000000000',
#   'priceUsd': '0.0173827266191868',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '64',
#   'tradesCount24Hr': None,
#   'updated': 1731897308994,
#   'volumeUsd24Hr': '331455.6611742259130159'},
#  {'baseId': 'aave',
#   'baseSymbol': 'AAVE',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2625628755077542',
#   'priceQuote': '160.0900000000000000',
#   'priceUsd': '160.0874822795613399',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '65',
#   'tradesCount24Hr': None,
#   'updated': 1731898166561,
#   'volumeUsd24Hr': '324540.3100696628981727'},
#  {'baseId': 'qtum',
#   'baseSymbol': 'QTUM',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2616284620820322',
#   'priceQuote': '3.0170000000000000',
#   'priceUsd': '3.0169525519235215',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '66',
#   'tradesCount24Hr': None,
#   'updated': 1731901355451,
#   'volumeUsd24Hr': '323385.3302488080568512'},
#  {'baseId': 'basic-attention-token',
#   'baseSymbol': 'BAT',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2600757534068522',
#   'priceQuote': '0.2015000000000000',
#   'priceUsd': '0.2014968310283691',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '67',
#   'tradesCount24Hr': None,
#   'updated': 1731901094315,
#   'volumeUsd24Hr': '321466.1078381138871708'},
#  {'baseId': 'dogecoin',
#   'baseSymbol': 'DOGE',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2546316945430964',
#   'priceQuote': '0.3563060000000000',
#   'priceUsd': '0.3563003964089036',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '68',
#   'tradesCount24Hr': None,
#   'updated': 1731901074254,
#   'volumeUsd24Hr': '314736.9899144011137500'},
#  {'baseId': 'qtum',
#   'baseSymbol': 'QTUM',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2415783562933398',
#   'priceQuote': '0.0000335600000000',
#   'priceUsd': '3.0375765057192631',
#   'quoteId': 'bitcoin',
#   'quoteSymbol': 'BTC',
#   'rank': '69',
#   'tradesCount24Hr': None,
#   'updated': 1731901352956,
#   'volumeUsd24Hr': '298602.4376292473275062'},
#  {'baseId': 'qtum',
#   'baseSymbol': 'QTUM',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2330581868145017',
#   'priceQuote': '0.0009751100000000',
#   'priceUsd': '3.0275230751262666',
#   'quoteId': 'ethereum',
#   'quoteSymbol': 'ETH',
#   'rank': '70',
#   'tradesCount24Hr': None,
#   'updated': 1731901354205,
#   'volumeUsd24Hr': '288071.0994148829188117'},
#  {'baseId': 'zilliqa',
#   'baseSymbol': 'ZIL',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2223675276813588',
#   'priceQuote': '0.0190000000000000',
#   'priceUsd': '0.0189997011887792',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '71',
#   'tradesCount24Hr': None,
#   'updated': 1731893364762,
#   'volumeUsd24Hr': '274856.9318627881077749'},
#  {'baseId': 'the-sandbox',
#   'baseSymbol': 'SAND',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2132654759523443',
#   'priceQuote': '0.3562540000000000',
#   'priceUsd': '0.3562483972267028',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '72',
#   'tradesCount24Hr': None,
#   'updated': 1731849864591,
#   'volumeUsd24Hr': '263606.3592725392057006'},
#  {'baseId': 'synthetix-network-token',
#   'baseSymbol': 'SNX',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2099264831895662',
#   'priceQuote': '1.6724000000000000',
#   'priceUsd': '1.6723736983218089',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '73',
#   'tradesCount24Hr': None,
#   'updated': 1731898120056,
#   'volumeUsd24Hr': '259479.2040360771379193'},
#  {'baseId': 'stafi',
#   'baseSymbol': 'FIS',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2089310825627792',
#   'priceQuote': '0.3219000000000000',
#   'priceUsd': '0.3218949375088437',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '74',
#   'tradesCount24Hr': None,
#   'updated': 1731898142668,
#   'volumeUsd24Hr': '258248.8411089639948245'},
#  {'baseId': 'akropolis',
#   'baseSymbol': 'AKRO',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2008733720797934',
#   'priceQuote': '0.0041460000000000',
#   'priceUsd': '0.0041459347962462',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '75',
#   'tradesCount24Hr': None,
#   'updated': 1731898130083,
#   'volumeUsd24Hr': '248289.1243990418631127'},
#  {'baseId': 'ontology',
#   'baseSymbol': 'ONT',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1964534572089719',
#   'priceQuote': '0.2188000000000000',
#   'priceUsd': '0.2187965589528891',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '76',
#   'tradesCount24Hr': None,
#   'updated': 1731901374208,
#   'volumeUsd24Hr': '242825.8975819072937909'},
#  {'baseId': 'litecoin',
#   'baseSymbol': 'LTC',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1949825310939114',
#   'priceQuote': '86.5500000000000000',
#   'priceUsd': '86.5486388362548190',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '77',
#   'tradesCount24Hr': None,
#   'updated': 1731901316585,
#   'volumeUsd24Hr': '241007.7623388797014973'},
#  {'baseId': 'phala-network',
#   'baseSymbol': 'PHA',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1809308802514795',
#   'priceQuote': '0.0000014100000000',
#   'priceUsd': '0.1276216589113278',
#   'quoteId': 'bitcoin',
#   'quoteSymbol': 'BTC',
#   'rank': '78',
#   'tradesCount24Hr': None,
#   'updated': 1731898140119,
#   'volumeUsd24Hr': '223639.2477970788044785'},
#  {'baseId': 'decentraland',
#   'baseSymbol': 'MANA',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1682167539167421',
#   'priceQuote': '0.3996840000000000',
#   'priceUsd': '0.3996777142071597',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '79',
#   'tradesCount24Hr': None,
#   'updated': 1731901334084,
#   'volumeUsd24Hr': '207923.9777119189841169'},
#  {'baseId': 'dao',
#   'baseSymbol': 'DAO',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1660914127653480',
#   'priceQuote': '0.4094050000000000',
#   'priceUsd': '0.4093985613259030',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '80',
#   'tradesCount24Hr': None,
#   'updated': 1731875464674,
#   'volumeUsd24Hr': '205296.9540896976545328'},
#  {'baseId': 'mask-network',
#   'baseSymbol': 'MASK',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1640945563902902',
#   'priceQuote': '2.9200590000000000',
#   'priceUsd': '2.9200130765055507',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '81',
#   'tradesCount24Hr': None,
#   'updated': 1731849856980,
#   'volumeUsd24Hr': '202828.7438148345020269'},
#  {'baseId': 'ontology-gas',
#   'baseSymbol': 'ONG',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1542193418554698',
#   'priceQuote': '0.0000037600000000',
#   'priceUsd': '0.3403244237635408',
#   'quoteId': 'bitcoin',
#   'quoteSymbol': 'BTC',
#   'rank': '82',
#   'tradesCount24Hr': None,
#   'updated': 1731901051695,
#   'volumeUsd24Hr': '190622.5049056311591519'},
#  {'baseId': 'crypto-com-coin',
#   'baseSymbol': 'CRO',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1539092551862421',
#   'priceQuote': '0.1793000000000000',
#   'priceUsd': '0.1792971801656902',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '83',
#   'tradesCount24Hr': None,
#   'updated': 1731901084251,
#   'volumeUsd24Hr': '190239.2229066622872993'},
#  {'baseId': 'phala-network',
#   'baseSymbol': 'PHA',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1518040031661708',
#   'priceQuote': '0.0000418200000000',
#   'priceUsd': '0.1298428023523300',
#   'quoteId': 'ethereum',
#   'quoteSymbol': 'ETH',
#   'rank': '84',
#   'tradesCount24Hr': None,
#   'updated': 1731898141425,
#   'volumeUsd24Hr': '187637.0304144927517792'},
#  {'baseId': 'orbs',
#   'baseSymbol': 'ORBS',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1451081476935947',
#   'priceQuote': '0.0281000000000000',
#   'priceUsd': '0.0280995580739314',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '85',
#   'tradesCount24Hr': None,
#   'updated': 1731893377380,
#   'volumeUsd24Hr': '179360.6318297761523963'},
#  {'baseId': 'tokocrypto',
#   'baseSymbol': 'TKO',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1393863407909982',
#   'priceQuote': '0.3199450000000000',
#   'priceUsd': '0.3199399682549457',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '86',
#   'tradesCount24Hr': None,
#   'updated': 1731893430525,
#   'volumeUsd24Hr': '172288.2040056355484563'},
#  {'baseId': 'internet-computer',
#   'baseSymbol': 'ICP',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1298215861882148',
#   'priceQuote': '8.9900000000000000',
#   'priceUsd': '8.9898586151118524',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '87',
#   'tradesCount24Hr': None,
#   'updated': 1731893382541,
#   'volumeUsd24Hr': '160465.7084661399716105'},
#  {'baseId': 'ravencoin',
#   'baseSymbol': 'RVN',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1225590031313854',
#   'priceQuote': '0.0220010000000000',
#   'priceUsd': '0.0220006539923332',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '88',
#   'tradesCount24Hr': None,
#   'updated': 1731900817286,
#   'volumeUsd24Hr': '151488.8073996353607694'},
#  {'baseId': 'nest-protocol',
#   'baseSymbol': 'NEST',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.0966382605799123',
#   'priceQuote': '0.0009830000000000',
#   'priceUsd': '0.0009829845404511',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '89',
#   'tradesCount24Hr': None,
#   'updated': 1731900789697,
#   'volumeUsd24Hr': '119449.5261089239379261'},
#  {'baseId': 'nem',
#   'baseSymbol': 'XEM',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.0931440134627502',
#   'priceQuote': '0.0217000000000000',
#   'priceUsd': '0.0216996587261321',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '90',
#   'tradesCount24Hr': None,
#   'updated': 1731849858248,
#   'volumeUsd24Hr': '115130.4690424182458370'},
#  {'baseId': 'filecoin',
#   'baseSymbol': 'FIL',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.0864289786124721',
#   'priceQuote': '4.5338000000000000',
#   'priceUsd': '4.5337286973519595',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '91',
#   'tradesCount24Hr': None,
#   'updated': 1731898155295,
#   'volumeUsd24Hr': '106830.3638267686675987'},
#  {'baseId': 'bitcoin-cash',
#   'baseSymbol': 'BCH',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.0859298667775934',
#   'priceQuote': '444.9900000000000000',
#   'priceUsd': '444.9830016839402876',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '92',
#   'tradesCount24Hr': None,
#   'updated': 1731901305288,
#   'volumeUsd24Hr': '106213.4376549413911799'},
#  {'baseId': 'dydx',
#   'baseSymbol': 'DYDX',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.0857344949022048',
#   'priceQuote': '1.3085500000000000',
#   'priceUsd': '1.3085294205566868',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '93',
#   'tradesCount24Hr': None,
#   'updated': 1731897593475,
#   'volumeUsd24Hr': '105971.9486443761763000'},
#  {'baseId': 'deeper-network',
#   'baseSymbol': 'DPR',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.0853253735928339',
#   'priceQuote': '0.0020970000000000',
#   'priceUsd': '0.0020969670206774',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '94',
#   'tradesCount24Hr': None,
#   'updated': 1731900568860,
#   'volumeUsd24Hr': '105466.2550791965990957'},
#  {'baseId': 'compound',
#   'baseSymbol': 'COMP',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.0800732349075189',
#   'priceQuote': '50.9800000000000000',
#   'priceUsd': '50.9791982423139303',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '95',
#   'tradesCount24Hr': None,
#   'updated': 1731900793438,
#   'volumeUsd24Hr': '98974.3597030329601481'},
#  {'baseId': 'algorand',
#   'baseSymbol': 'ALGO',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.0773839877990803',
#   'priceQuote': '0.1910000000000000',
#   'priceUsd': '0.1909729291653250',
#   'quoteId': 'usd-coin',
#   'quoteSymbol': 'USDC',
#   'rank': '96',
#   'tradesCount24Hr': None,
#   'updated': 1731901088017,
#   'volumeUsd24Hr': '95650.3212656156287832'},
#  {'baseId': 'fei-protocol',
#   'baseSymbol': 'FEI',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.0749686628527496',
#   'priceQuote': '0.9778000000000000',
#   'priceUsd': '0.9777846222309643',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '97',
#   'tradesCount24Hr': None,
#   'updated': 1731893360925,
#   'volumeUsd24Hr': '92664.8637614453795095'},
#  {'baseId': 'mxc',
#   'baseSymbol': 'MXC',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.0691558484625709',
#   'priceQuote': '0.0053000000000000',
#   'priceUsd': '0.0052999166473963',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '98',
#   'tradesCount24Hr': None,
#   'updated': 1731901070425,
#   'volumeUsd24Hr': '85479.9463167463273277'},
#  {'baseId': 'standard-tokenization-protocol',
#   'baseSymbol': 'STPT',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.0686727047470541',
#   'priceQuote': '0.0468260000000000',
#   'priceUsd': '0.0468252635718829',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '99',
#   'tradesCount24Hr': None,
#   'updated': 1731849859506,
#   'volumeUsd24Hr': '84882.7575064897319279'}]

# %%
df_assets = build_table(json_data)

df_markets = build_table(json_data2)

# %%
df_assets.head()

df_markets.head()
# Out:
#   exchangeId rank baseSymbol        baseId quoteSymbol quoteId  \
# 0  alterdice    1        BTC       bitcoin        USDT  tether
# 1      bibox    1        ETH      ethereum        USDT  tether
# 2      bibox    2       LINK     chainlink        USDT  tether
# 3      bibox    3        BTC       bitcoin        USDT  tether
# 4      bibox    4        BNB  binance-coin        USDT  tether
#
#                priceQuote                priceUsd              volumeUsd24Hr  \
# 0  90488.7200000000000000  90487.2968923742133047  33972182.8691674586957539
# 1   3104.7200000000000000   3104.6711723592959159  28927631.4545180456406826
# 2     14.2650000000000000     14.2647756556808202  13486885.5716677303289241
# 3  90517.3000000000000000  90515.8764428992296274   6626180.5200011426889621
# 4    626.0800000000000000    626.0701536984681347   5502034.5454730611391885
#
#   percentExchangeVolume tradesCount24Hr        updated
# 0  100.0000000000000000               7  1731901429141
# 1   23.4033242117026192            None  1731901423330
# 2   10.9112962164268855            None  1731901098057
# 3    5.3607794070065404            None  1731901408218
# 4    4.4513114906814356            None  1731893357144

# %%
# Si los datos de los activos y el timestamp son válidos
if df_assets is not None and json_data_times is not None:
    # Convertir el timestamp de milisegundos a segundos y luego a una fecha legible
    timestamp_datetime = datetime.fromtimestamp(json_data_times / 1000, tz=timezone.utc)

    # Dividir el timestamp en columnas de fecha y hora
    df_assets['date'] = timestamp_datetime.date()  
    df_assets['time'] = timestamp_datetime.time()

    # Convertir la columna 'date' a un tipo compatible con Delta Lake
    df_assets['date'] = pd.to_datetime(df_assets['date'], errors='coerce')

    # Convertir la columna 'time' a un tipo compatible (por ejemplo, string)
    df_assets['time'] = df_assets['time'].astype(str)
# Si los datos de los activos y el timestamp son válidos
if df_markets is not None and json_data_times2 is not None:
    # Convertir el timestamp de milisegundos a segundos y luego a una fecha legible
    timestamp_datetime2 = datetime.fromtimestamp(json_data_times2 / 1000, tz=timezone.utc)

# Asignar el timestamp al DataFrame
    # Dividir el timestamp en columnas de fecha y hora
    df_markets['date'] = timestamp_datetime2.date()  
    df_markets['time'] = timestamp_datetime2.time()
    
    # Convertir la columna 'date' a un tipo compatible con Delta Lake
    df_markets['date'] = pd.to_datetime(df_markets['date'], errors='coerce')

    # Convertir la columna 'time' a un tipo compatible (por ejemplo, string)
    df_markets['time'] = df_markets['time'].astype(str)

# %%
# Aquí debería aparecer la columna 'timestamp' en el DataFrame
# DF temporal
df_assets.head()
# Out:
#              id rank symbol      name                         supply  \
# 0       bitcoin    1    BTC   Bitcoin      19783721.0000000000000000
# 1      ethereum    2    ETH  Ethereum     120424008.0282661200000000
# 2        tether    3   USDT    Tether  127539192697.5708600000000000
# 3        solana    4    SOL    Solana     474610053.5099429500000000
# 4  binance-coin    5    BNB       BNB     166801148.0000000000000000
#
#                     maxSupply                    marketCapUsd  \
# 0   21000000.0000000000000000  1790318125119.5495605746329380
# 1                        None   373836104330.3023309222233559
# 2                        None   127540841059.9573799288127283
# 3                        None   113864476387.2310060201065602
# 4  166801148.0000000000000000   104060595432.3626950723921468
#
#                   volumeUsd24Hr                priceUsd    changePercent24Hr  \
# 0  12519563199.2030121898396041  90494.5093554215387780   0.4410115189809265
# 1   8879590010.1099003588295158   3104.3320219216994461   0.9786167989928653
# 2  32612943391.4885063471687289      1.0000129243595765   0.0063896807594976
# 3   3099481184.7674778440186049    239.9116401878865311  10.1332397767590597
# 4    481361241.2702568295428748    623.8601872953697841   1.5459438255052078
#
#                  vwap24Hr                                           explorer  \
# 0  90245.7684177295013732                           https://blockchain.info/
# 1   3098.6174440684339828                              https://etherscan.io/
# 2      0.9997484425731084             https://www.omniexplorer.info/asset/31
# 3    234.2336246087076264                       https://explorer.solana.com/
# 4    626.0740744732262052  https://etherscan.io/token/0xB8c77482e45F1F44d...
#
#         date             time
# 0 2024-11-18  03:44:52.621000
# 1 2024-11-18  03:44:52.621000
# 2 2024-11-18  03:44:52.621000
# 3 2024-11-18  03:44:52.621000
# 4 2024-11-18  03:44:52.621000

# %%
# DF estatico
df_markets.head()
# Out:
#   exchangeId rank baseSymbol        baseId quoteSymbol quoteId  \
# 0  alterdice    1        BTC       bitcoin        USDT  tether
# 1      bibox    1        ETH      ethereum        USDT  tether
# 2      bibox    2       LINK     chainlink        USDT  tether
# 3      bibox    3        BTC       bitcoin        USDT  tether
# 4      bibox    4        BNB  binance-coin        USDT  tether
#
#                priceQuote                priceUsd              volumeUsd24Hr  \
# 0  90488.7200000000000000  90487.2968923742133047  33972182.8691674586957539
# 1   3104.7200000000000000   3104.6711723592959159  28927631.4545180456406826
# 2     14.2650000000000000     14.2647756556808202  13486885.5716677303289241
# 3  90517.3000000000000000  90515.8764428992296274   6626180.5200011426889621
# 4    626.0800000000000000    626.0701536984681347   5502034.5454730611391885
#
#   percentExchangeVolume tradesCount24Hr        updated       date  \
# 0  100.0000000000000000               7  1731901429141 2024-11-18
# 1   23.4033242117026192            None  1731901423330 2024-11-18
# 2   10.9112962164268855            None  1731901098057 2024-11-18
# 3    5.3607794070065404            None  1731901408218 2024-11-18
# 4    4.4513114906814356            None  1731893357144 2024-11-18
#
#               time
# 0  03:44:53.800000
# 1  03:44:53.800000
# 2  03:44:53.800000
# 3  03:44:53.800000
# 4  03:44:53.800000

# %% [markdown]
# ## Delta lake

# %%
def save_data_as_delta(df, path, mode="overwrite", partition_cols=None):
    #Guardar datos (opcionalmente particionados)|Escribe (write_deltalake)

    write_deltalake(
        path, df, mode=mode, partition_by=partition_cols
    )

def save_new_data_as_delta(new_data, data_path, predicate, partition_cols=None):
    #Guardar solo datos nuevos evitando duplicados	| MERGE (inserción condicional)
    try:
        dt = DeltaTable(data_path)
        # Convertir los nuevos datos a formato Arrow para trabajar con Delta
        new_data_pa = pa.Table.from_pandas(new_data)
        # Se insertan en target, datos de source que no existen en target
        dt.merge(
            source=new_data_pa,
            source_alias="source",
            target_alias="target",
            predicate=predicate
        ) \
        .when_not_matched_insert_all() \
        .execute()

    # sino se guarda como nueva
    except TableNotFoundError:
        save_data_as_delta(new_data, data_path, partition_cols=partition_cols)

def upsert_data_as_delta(data, data_path, predicate):
    #Actualizar o insertar registros dependiendo de coincidencias | MERGE (actualización/inserción)
    try:
        dt = DeltaTable(data_path)
        data_pa = pa.Table.from_pandas(data)
        dt.merge(
            source=data_pa,
            source_alias="source",
            target_alias="target",
            predicate=predicate
        ) \
        .when_matched_update_all() \
        .when_not_matched_insert_all() \
        .execute()
    except TableNotFoundError:
        save_data_as_delta(data, data_path)
    except Exception as e:
        # Capturar cualquier otro error
        print(f"Ocurrió un error al realizar el upsert: {e}")

# %%
#Ruta de guardado
bronze_dir = "datalake/bronze/api_coincap"
assets_raw_dir = f"{bronze_dir}/assets"

markets_raw_dir = f"{bronze_dir}/markets"

# %% [markdown]
# ### Assets
# https://api.coincap.io/v2/assets

# %%
# Guardar solo los nuevos datos (evitar duplicados) usando el predicado basado en el id
try:
    upsert_data_as_delta(
        df_assets,
        assets_raw_dir,
        "target.id = source.id"
    )
except Exception as e:
    print(f"Ocurrió un error al guardar los datos: {e}")

# %%
canRow = DeltaTable(assets_raw_dir)
print(f"Cant de filas: {canRow.to_pandas().shape[0]}")
# Out:
# Cant de filas: 100

# %%
#.sort_values("rank")
DeltaTable(assets_raw_dir).to_pandas()
# Cargar la tabla Delta como un DataFrame de Pandas
#df = DeltaTable(f"{bronze_dir}/assets").to_pandas()

# Filtrar las filas donde el id es "bitcoin"
#df_bitcoin = df[df['id'] == 'bitcoin']

# Mostrar las primeras 10 filas del DataFrame filtrado
#df_bitcoin.head(10)
# Out:
#                   id rank symbol                                   name  \
# 0           dogecoin    6   DOGE                               Dogecoin
# 1              fetch   28    FET  Artificial Superintelligence Alliance
# 2            vechain   34    VET                                VeChain
# 3           filecoin   31    FIL                               Filecoin
# 4   hedera-hashgraph   41   HBAR                       Hedera Hashgraph
# ..               ...  ...    ...                                    ...
# 95  ethereum-classic   27    ETC                       Ethereum Classic
# 96   crypto-com-coin   25    CRO                        Crypto.com Coin
# 97            monero   29    XMR                                 Monero
# 98        gnosis-gno   71    GNO                                 Gnosis
# 99    nervos-network   75    CKB                         Nervos Network
#
#                            supply                     maxSupply  \
# 0   146835886383.7052600000000000                          None
# 1     2520000000.0000000000000000   2630547141.0000000000000000
# 2    80985041177.0000000000000000  86712634466.0000000000000000
# 3      599550473.0000000000000000                          None
# 4    14832756028.0000000000000000  50000000000.0000000000000000
# ..                            ...                           ...
# 95     149591222.2698405000000000    210700000.0000000000000000
# 96   25263013692.0000000000000000  30263013692.0000000000000000
# 97      18446744.0737095500000000                          None
# 98       2589588.0000000000000000      3000000.0000000000000000
# 99   45074801311.1903400000000000                          None
#
#                     marketCapUsd                volumeUsd24Hr  \
# 0   54323132468.6564966601152408  2493603582.2985157775229262
# 1    3267902626.2117592560000000    91193332.0475563610285784
# 2    2482537378.1382530007747611    26100521.9866755304213035
# 3    2717508805.8615097728799578   149229169.1296065367921374
# 4    1686371552.3987041282124228   234010649.5535554744921912
# ..                           ...                          ...
# 95   3948159510.2899322748189396   229719378.8097647616414926
# 96   4524442411.4952669919759356    23388765.7280004263784638
# 97   2958034939.0843445590990696    43650373.1742213480570341
# 98    669253776.4190775537081468     4083631.0061882470921876
# 99    601696973.9286749458691514    24088068.3102077783008724
#
#                 priceUsd    changePercent24Hr              vwap24Hr  \
# 0     0.3699581471977607   5.7502002447362146    0.3616966795665211
# 1     1.2967867564332378   1.4558362386439533    1.2816341905599402
# 2     0.0306542707401043   2.8438212181689620    0.0292774235807196
# 3     4.5325772028229386  -0.6097653180955389    4.4805922026576955
# 4     0.1136923946713151  33.1124464870681606    0.0907561887154486
# ..                   ...                  ...                   ...
# 95   26.3929891766512535  -5.0508351070863081   26.6260894123707650
# 96    0.1790935343920593  13.0357487363660559    0.1632910425849030
# 97  160.3553953621636711   7.9043432902066693  152.6544189556331546
# 98  258.4402524336217011  -0.6876683495844674  255.6680484881150722
# 99    0.0133488547131831   1.5230130489273135    0.0130229276315704
#
#                                              explorer       date  \
# 0                http://dogechain.info/chain/Dogecoin 2024-11-18
# 1   https://etherscan.io/token/0x1d287cc25dad7ccaf... 2024-11-18
# 2                        https://explore.veforge.com/ 2024-11-18
# 3                                 https://protocol.ai 2024-11-18
# 4                             https://hash-hash.info/ 2024-11-18
# ..                                                ...        ...
# 95                              http://gastracker.io/ 2024-11-18
# 96  https://etherscan.io/token/0xa0b73e1ff0b80914a... 2024-11-18
# 97                          http://moneroblocks.info/ 2024-11-18
# 98                  https://etherscan.io/token/Gnosis 2024-11-18
# 99                       https://explorer.nervos.org/ 2024-11-18
#
#                time
# 0   03:44:52.621000
# 1   03:44:52.621000
# 2   03:44:52.621000
# 3   03:44:52.621000
# 4   03:44:52.621000
# ..              ...
# 95  03:44:52.621000
# 96  03:44:52.621000
# 97  03:44:52.621000
# 98  03:44:52.621000
# 99  03:44:52.621000
#
# [100 rows x 14 columns]

# %% [markdown]
# ### markets
# https://api.coincap.io/v2/markets

# %%
save_new_data_as_delta(
    df_markets,
    markets_raw_dir,
    """target.date = source.date""",
    partition_cols=["date"]
    )

# %%
canRowTwo = DeltaTable(markets_raw_dir)
print(f"Cant de filas: {canRowTwo.to_pandas().shape[0]}")
# Out:
# Cant de filas: 100

# %%
DeltaTable(markets_raw_dir).to_pandas()
# Out:
#    exchangeId rank baseSymbol                          baseId quoteSymbol  \
# 0   alterdice    1        BTC                         bitcoin        USDT
# 1       bibox    1        ETH                        ethereum        USDT
# 2       bibox    2       LINK                       chainlink        USDT
# 3       bibox    3        BTC                         bitcoin        USDT
# 4       bibox    4        BNB                    binance-coin        USDT
# ..        ...  ...        ...                             ...         ...
# 95      bibox   95       COMP                        compound        USDT
# 96      bibox   96       ALGO                        algorand        USDC
# 97      bibox   97        FEI                    fei-protocol        USDT
# 98      bibox   98        MXC                             mxc        USDT
# 99      bibox   99       STPT  standard-tokenization-protocol        USDT
#
#      quoteId              priceQuote                priceUsd  \
# 0     tether  90493.5800000000000000  90491.1997356390204594
# 1     tether   3104.8400000000000000   3104.7583329911520384
# 2     tether     14.2650000000000000     14.2646247858565285
# 3     tether  90542.5000000000000000  90540.1184488899213618
# 4     tether    626.0800000000000000    626.0635321366319901
# ..       ...                     ...                     ...
# 95    tether     50.9800000000000000     50.9786590664539657
# 96  usd-coin      0.1910000000000000      0.1909546324229206
# 97    tether      0.9778000000000000      0.9777742807998958
# 98    tether      0.0053000000000000      0.0052998605934132
# 99    tether      0.0468260000000000      0.0468247683296542
#
#                 volumeUsd24Hr percentExchangeVolume tradesCount24Hr  \
# 0   33915994.9717930165497698  100.0000000000000000               7
# 1   28882723.8299292803158661   23.3777260266278375            None
# 2   13486742.9291120003610098   10.9161927747834771            None
# 3    6619736.4581741334791749    5.3580260019421284            None
# 4    5501976.3538123467077092    4.4533090632928981            None
# ..                        ...                   ...             ...
# 95     98973.3129116484884251    0.0801091686095969            None
# 96     95641.1571956254842941    0.0774121160786120            None
# 97     92663.8837017479005621    0.0750023058247021            None
# 98     85479.0422475346855024    0.0691868828732385            None
# 99     84881.8597533795870478    0.0687035223419236            None
#
#           updated       date             time
# 0   1731901354347 2024-11-18  03:43:38.954000
# 1   1731901285184 2024-11-18  03:43:38.954000
# 2   1731901098057 2024-11-18  03:43:38.954000
# 3   1731901270152 2024-11-18  03:43:38.954000
# 4   1731893357144 2024-11-18  03:43:38.954000
# ..            ...        ...              ...
# 95  1731900793438 2024-11-18  03:43:38.954000
# 96  1731901088017 2024-11-18  03:43:38.954000
# 97  1731893360925 2024-11-18  03:43:38.954000
# 98  1731901070425 2024-11-18  03:43:38.954000
# 99  1731849859506 2024-11-18  03:43:38.954000
#
# [100 rows x 14 columns]
