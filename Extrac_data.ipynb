# %%
import requests
import pandas as pd
from datetime import datetime, timedelta, timezone
from deltalake import DeltaTable, write_deltalake
from deltalake.exceptions import TableNotFoundError
import pyarrow as pa
from pprint import pprint

# %% [markdown]
# #requests.get?
# # #Signature: requests.get(url, params=None, **kwargs)
# #requests.post?
# # #Signature: requests.post(url, data=None, json=none, **kwargs)

# %%
def get_data(base_url, endpoint, data_field, params=None, headers=None):
        try:
            endpoint_url = f"{base_url}/{endpoint}"
            response = requests.get(endpoint_url, params=params, headers=headers)
            response.raise_for_status()  # Levanta una excepción si hay un error en la respuesta HTTP.

        # Verificar si los datos están en formato JSON.
            try:
                data = response.json()
                data = data[data_field]
            except:
                print("El formato de respuesta no es el esperado")
                return None
            return data

        except requests.exceptions.RequestException as e:
            # Capturar cualquier error de solicitud, como errores HTTP.
            print(f"La petición ha fallado. Código de error : {e}")
        return None

def build_table(json_data):
    try:
        df = pd.json_normalize(json_data)
        return df
    except:
        print("Los datos no están en el formato esperado")
        return None

# %%
# Usar la función para hacer la petición a la API de CoinCap
base_url = "https://api.coincap.io/v2"

# %%
endpoint = "assets"
endpoint2 = "markets"

json_data = get_data(base_url, endpoint, data_field="data")
json_data_times =get_data(base_url, endpoint, data_field="timestamp")

json_data2 = get_data(base_url, endpoint2, data_field="data")
json_data_times2 =get_data(base_url, endpoint2, data_field="timestamp")

# %%
pprint(json_data)

pprint(json_data2)
# Out:
# [{'changePercent24Hr': '4.2783813194041564',
#   'explorer': 'https://blockchain.info/',
#   'id': 'bitcoin',
#   'marketCapUsd': '1979715808471.1145134388494256',
#   'maxSupply': '21000000.0000000000000000',
#   'name': 'Bitcoin',
#   'priceUsd': '100033.2991186061215342',
#   'rank': '1',
#   'supply': '19790568.0000000000000000',
#   'symbol': 'BTC',
#   'volumeUsd24Hr': '27055581785.2751703938677858',
#   'vwap24Hr': '97051.5062276099056651'},
#  {'changePercent24Hr': '5.0276625574947599',
#   'explorer': 'https://etherscan.io/',
#   'id': 'ethereum',
#   'marketCapUsd': '461769382749.4349832916737059',
#   'maxSupply': None,
#   'name': 'Ethereum',
#   'priceUsd': '3833.9567645040828457',
#   'rank': '2',
#   'supply': '120441990.1196158200000000',
#   'symbol': 'ETH',
#   'volumeUsd24Hr': '19690161901.8066180021863565',
#   'vwap24Hr': '3776.4260733775174657'},
#  {'changePercent24Hr': '0.0060468274224712',
#   'explorer': 'https://www.omniexplorer.info/asset/31',
#   'id': 'tether',
#   'marketCapUsd': '135746019561.9712812862370636',
#   'maxSupply': None,
#   'name': 'Tether',
#   'priceUsd': '1.0004047305177132',
#   'rank': '3',
#   'supply': '135691101232.3204500000000000',
#   'symbol': 'USDT',
#   'volumeUsd24Hr': '67212530575.9733740471874540',
#   'vwap24Hr': '1.0008207745951950'},
#  {'changePercent24Hr': '-4.0687374077078990',
#   'explorer': 'https://etherscan.io/token/0xB8c77482e45F1F44dE1745F52C74426C631bDD52',
#   'id': 'binance-coin',
#   'marketCapUsd': '120620418671.5942988014635172',
#   'maxSupply': '166801148.0000000000000000',
#   'name': 'BNB',
#   'priceUsd': '723.1390198321314839',
#   'rank': '4',
#   'supply': '166801148.0000000000000000',
#   'symbol': 'BNB',
#   'volumeUsd24Hr': '1925464184.0828705250403807',
#   'vwap24Hr': '749.4005444409089440'},
#  {'changePercent24Hr': '-2.7100850749053788',
#   'explorer': 'https://explorer.solana.com/',
#   'id': 'solana',
#   'marketCapUsd': '110067415722.1157333236138697',
#   'maxSupply': None,
#   'name': 'Solana',
#   'priceUsd': '231.5471153194320264',
#   'rank': '5',
#   'supply': '475356454.2156859000000000',
#   'symbol': 'SOL',
#   'volumeUsd24Hr': '2053827815.3164765042266833',
#   'vwap24Hr': '232.6796691822089342'},
#  {'changePercent24Hr': '-8.2680698539634366',
#   'explorer': 'https://xrpcharts.ripple.com/#/graph/',
#   'id': 'xrp',
#   'marketCapUsd': '105340223472.8628296518718400',
#   'maxSupply': '100000000000.0000000000000000',
#   'name': 'XRP',
#   'priceUsd': '2.3200633650393810',
#   'rank': '6',
#   'supply': '45404028640.0000000000000000',
#   'symbol': 'XRP',
#   'volumeUsd24Hr': '7448470152.9054716799805080',
#   'vwap24Hr': '2.4816048260166877'},
#  {'changePercent24Hr': '3.4472547560202620',
#   'explorer': 'http://dogechain.info/chain/Dogecoin',
#   'id': 'dogecoin',
#   'marketCapUsd': '62903574151.4616469849005007',
#   'maxSupply': None,
#   'name': 'Dogecoin',
#   'priceUsd': '0.4277198645695764',
#   'rank': '7',
#   'supply': '147067226383.7052600000000000',
#   'symbol': 'DOGE',
#   'volumeUsd24Hr': '3749901275.6906224394917296',
#   'vwap24Hr': '0.4187989291152939'},
#  {'changePercent24Hr': '-3.1077935256749373',
#   'explorer': 'https://cardanoexplorer.com/',
#   'id': 'cardano',
#   'marketCapUsd': '40690105763.3414708886006071',
#   'maxSupply': '45000000000.0000000000000000',
#   'name': 'Cardano',
#   'priceUsd': '1.1597286685035273',
#   'rank': '8',
#   'supply': '35085884197.2463600000000000',
#   'symbol': 'ADA',
#   'volumeUsd24Hr': '1333630061.7267432300021409',
#   'vwap24Hr': '1.1942229571202596'},
#  {'changePercent24Hr': '-0.1515435527220172',
#   'explorer': 'https://etherscan.io/token/0xa0b86991c6218b36c1d19d4a2e9eb0ce3606eb48',
#   'id': 'usd-coin',
#   'marketCapUsd': '40639001622.4993820962856626',
#   'maxSupply': None,
#   'name': 'USDC',
#   'priceUsd': '0.9988553662981032',
#   'rank': '9',
#   'supply': '40685571699.0470500000000000',
#   'symbol': 'USDC',
#   'volumeUsd24Hr': '6748097875.3234249010688979',
#   'vwap24Hr': '0.9994796734139239'},
#  {'changePercent24Hr': '5.2192768100619119',
#   'explorer': 'https://etherscan.io/token/0xae7ab96520de3a18e5e111b5eaab095312d7fe84',
#   'id': 'steth',
#   'marketCapUsd': '37559970377.7107974431270507',
#   'maxSupply': None,
#   'name': 'Lido Staked ETH',
#   'priceUsd': '3816.8743846731598374',
#   'rank': '10',
#   'supply': '9840504.7146782300000000',
#   'symbol': 'STETH',
#   'volumeUsd24Hr': '586282.5913829451794407',
#   'vwap24Hr': '3723.2996337828766062'},
#  {'changePercent24Hr': '-11.5858802521052685',
#   'explorer': 'https://tronscan.org/#/',
#   'id': 'tron',
#   'marketCapUsd': '28765253410.2844419476491587',
#   'maxSupply': None,
#   'name': 'TRON',
#   'priceUsd': '0.3333767925856516',
#   'rank': '11',
#   'supply': '86284510649.8948500000000000',
#   'symbol': 'TRX',
#   'volumeUsd24Hr': '2977435219.3217041809269447',
#   'vwap24Hr': '0.3694827311625633'},
#  {'changePercent24Hr': '0.0216949785181647',
#   'explorer': 'https://avascan.info/',
#   'id': 'avalanche',
#   'marketCapUsd': '21084856462.1773733553440941',
#   'maxSupply': '715748719.0000000000000000',
#   'name': 'Avalanche',
#   'priceUsd': '51.5077475502823562',
#   'rank': '12',
#   'supply': '409353106.3767472000000000',
#   'symbol': 'AVAX',
#   'volumeUsd24Hr': '709826759.0292905378102378',
#   'vwap24Hr': '53.7161168045991353'},
#  {'changePercent24Hr': '5.7556136874340431',
#   'explorer': 'https://etherscan.io/token/0x95ad61b0a150d79219dcf64e1e6cc01f0b64c4ce',
#   'id': 'shiba-inu',
#   'marketCapUsd': '18720982094.3943470069665596',
#   'maxSupply': None,
#   'name': 'Shiba Inu',
#   'priceUsd': '0.0000317705392129',
#   'rank': '13',
#   'supply': '589256039028539.5000000000000000',
#   'symbol': 'SHIB',
#   'volumeUsd24Hr': '1472448054.0686386776266729',
#   'vwap24Hr': '0.0000307092105064'},
#  {'changePercent24Hr': '5.4087788648598725',
#   'explorer': 'https://polkascan.io/polkadot',
#   'id': 'polkadot',
#   'marketCapUsd': '15705739800.5834280542317800',
#   'maxSupply': None,
#   'name': 'Polkadot',
#   'priceUsd': '10.3173353830460130',
#   'rank': '14',
#   'supply': '1522267060.0000000000000000',
#   'symbol': 'DOT',
#   'volumeUsd24Hr': '1113866189.6466356219373558',
#   'vwap24Hr': '10.7743967641186914'},
#  {'changePercent24Hr': '-0.7816364667146088',
#   'explorer': 'https://etherscan.io/token/0x514910771af9ca656af840dff83e8264ecf986ca',
#   'id': 'chainlink',
#   'marketCapUsd': '14874802064.0965675160925789',
#   'maxSupply': None,
#   'name': 'Chainlink',
#   'priceUsd': '23.7294452663883677',
#   'rank': '15',
#   'supply': '626849970.4527867000000000',
#   'symbol': 'LINK',
#   'volumeUsd24Hr': '936764121.2937993228263504',
#   'vwap24Hr': '24.6583153616802486'},
#  {'changePercent24Hr': '-3.9801854160425329',
#   'explorer': 'https://dashboard.stellar.org/',
#   'id': 'stellar',
#   'marketCapUsd': '14681921652.5590942622152206',
#   'maxSupply': '50001806812.0000000000000000',
#   'name': 'Stellar',
#   'priceUsd': '0.4874726014665801',
#   'rank': '16',
#   'supply': '30118455085.2457500000000000',
#   'symbol': 'XLM',
#   'volumeUsd24Hr': '644863938.9044028863594749',
#   'vwap24Hr': '0.5016746108343699'},
#  {'changePercent24Hr': '4.1459312335977909',
#   'explorer': 'https://etherscan.io/token/0x2260fac5e5542a773aa44fbcfedf7c193bc2c599',
#   'id': 'wrapped-bitcoin',
#   'marketCapUsd': '13730859020.5108990156782745',
#   'maxSupply': None,
#   'name': 'Wrapped Bitcoin',
#   'priceUsd': '99519.0748004387960801',
#   'rank': '17',
#   'supply': '137972.1329608900000000',
#   'symbol': 'WBTC',
#   'volumeUsd24Hr': '61025741.3989695921550446',
#   'vwap24Hr': '96604.7771043853842781'},
#  {'changePercent24Hr': '5.0108645154239155',
#   'explorer': 'https://blockchair.com/bitcoin-cash/blocks',
#   'id': 'bitcoin-cash',
#   'marketCapUsd': '11764477707.2009327164250475',
#   'maxSupply': None,
#   'name': 'Bitcoin Cash',
#   'priceUsd': '594.2371943688125382',
#   'rank': '18',
#   'supply': '19797612.5000000000000000',
#   'symbol': 'BCH',
#   'volumeUsd24Hr': '294250106.9395359741390944',
#   'vwap24Hr': '569.2856248686518891'},
#  {'changePercent24Hr': '0.8403479537374443',
#   'explorer': 'http://explorer.litecoin.net/chain/Litecoin',
#   'id': 'litecoin',
#   'marketCapUsd': '9788320465.0213880828806823',
#   'maxSupply': '84000000.0000000000000000',
#   'name': 'Litecoin',
#   'priceUsd': '130.0439092805604143',
#   'rank': '19',
#   'supply': '75269349.5541093600000000',
#   'symbol': 'LTC',
#   'volumeUsd24Hr': '960588302.2843340228315603',
#   'vwap24Hr': '129.5068442075368518'},
#  {'changePercent24Hr': '3.2642948110895183',
#   'explorer': 'https://etherscan.io/token/0x1f9840a85d5af5bf1d1762f925bdaddc4201f984',
#   'id': 'uniswap',
#   'marketCapUsd': '9189736123.0032788416321060',
#   'maxSupply': None,
#   'name': 'Uniswap',
#   'priceUsd': '15.3039053477823946',
#   'rank': '20',
#   'supply': '600483073.7100000000000000',
#   'symbol': 'UNI',
#   'volumeUsd24Hr': '459402428.7128520293400751',
#   'vwap24Hr': '15.5934857181189879'},
#  {'changePercent24Hr': '1.3491346211775855',
#   'explorer': 'https://explorer.nearprotocol.com/',
#   'id': 'near-protocol',
#   'marketCapUsd': '8980164839.7693225423224680',
#   'maxSupply': None,
#   'name': 'NEAR Protocol',
#   'priceUsd': '7.3734456492416056',
#   'rank': '21',
#   'supply': '1217906155.0000000000000000',
#   'symbol': 'NEAR',
#   'volumeUsd24Hr': '305711516.8305397760563111',
#   'vwap24Hr': '7.4368719000813796'},
#  {'changePercent24Hr': '2.8957372751349539',
#   'explorer': 'https://eospark.com/account/bitfinexleo1',
#   'id': 'unus-sed-leo',
#   'marketCapUsd': '8930616381.5585040524178836',
#   'maxSupply': None,
#   'name': 'UNUS SED LEO',
#   'priceUsd': '9.6586585984505158',
#   'rank': '22',
#   'supply': '924622843.9000000000000000',
#   'symbol': 'LEO',
#   'volumeUsd24Hr': '1257201.9943327410553770',
#   'vwap24Hr': '9.4167177885296860'},
#  {'changePercent24Hr': '0.1875547405825765',
#   'explorer': 'https://www.dfinityexplorer.org/#/',
#   'id': 'internet-computer',
#   'marketCapUsd': '6831005817.7173934041864988',
#   'maxSupply': None,
#   'name': 'Internet Computer',
#   'priceUsd': '14.3683563390580802',
#   'rank': '23',
#   'supply': '475420128.5465336000000000',
#   'symbol': 'ICP',
#   'volumeUsd24Hr': '180301070.1551788752973113',
#   'vwap24Hr': '14.8013785926927448'},
#  {'changePercent24Hr': '-1.6261459212406400',
#   'explorer': 'https://explore.veforge.com/',
#   'id': 'vechain',
#   'marketCapUsd': '5695051750.7580188499053889',
#   'maxSupply': '86712634466.0000000000000000',
#   'name': 'VeChain',
#   'priceUsd': '0.0703222677668457',
#   'rank': '24',
#   'supply': '80985041177.0000000000000000',
#   'symbol': 'VET',
#   'volumeUsd24Hr': '231606213.4597140108553998',
#   'vwap24Hr': '0.0696734737862013'},
#  {'changePercent24Hr': '3.7350417171066410',
#   'explorer': 'http://gastracker.io/',
#   'id': 'ethereum-classic',
#   'marketCapUsd': '5539266032.5433823349024184',
#   'maxSupply': '210700000.0000000000000000',
#   'name': 'Ethereum Classic',
#   'priceUsd': '36.9738028443214190',
#   'rank': '25',
#   'supply': '149815967.1556242000000000',
#   'symbol': 'ETC',
#   'volumeUsd24Hr': '398558051.8777839816606374',
#   'vwap24Hr': '37.2110858370740626'},
#  {'changePercent24Hr': '0.0938698811565369',
#   'explorer': 'https://etherscan.io/token/0x89d24a6b4ccb1b6faa2625fe562bdd9a23260359',
#   'id': 'multi-collateral-dai',
#   'marketCapUsd': '5366843331.5934544307643345',
#   'maxSupply': None,
#   'name': 'Multi Collateral DAI',
#   'priceUsd': '1.0002722320120533',
#   'rank': '26',
#   'supply': '5365382702.6648720000000000',
#   'symbol': 'DAI',
#   'volumeUsd24Hr': '20925019.1759020506090269',
#   'vwap24Hr': '1.0003760717218052'},
#  {'changePercent24Hr': '4.4574868835941350',
#   'explorer': 'https://etherscan.io/token/0xa0b73e1ff0b80914ab6fe0444e65848c4c34450b',
#   'id': 'crypto-com-coin',
#   'marketCapUsd': '5265720693.1822495591376844',
#   'maxSupply': '30263013692.0000000000000000',
#   'name': 'Crypto.com Coin',
#   'priceUsd': '0.2084359671961757',
#   'rank': '27',
#   'supply': '25263013692.0000000000000000',
#   'symbol': 'CRO',
#   'volumeUsd24Hr': '74235787.5696091000958415',
#   'vwap24Hr': '0.2133686836909129'},
#  {'changePercent24Hr': '-0.3504096179925493',
#   'explorer': 'https://etherscan.io/token/0x05aaaa829afa407d83315cded1d45eb16025910c',
#   'id': 'sp8de',
#   'marketCapUsd': '4905117871.4441059838450521',
#   'maxSupply': None,
#   'name': 'Sp8de',
#   'priceUsd': '0.6301735692117560',
#   'rank': '28',
#   'supply': '7783756906.1800000000000000',
#   'symbol': 'SPX',
#   'volumeUsd24Hr': '5720435.1428574279804251',
#   'vwap24Hr': '0.6573450021708661'},
#  {'changePercent24Hr': '5.5237489043755574',
#   'explorer': 'https://protocol.ai',
#   'id': 'filecoin',
#   'marketCapUsd': '4816425678.1062541978749762',
#   'maxSupply': None,
#   'name': 'Filecoin',
#   'priceUsd': '7.9231419943778073',
#   'rank': '29',
#   'supply': '607893394.0000000000000000',
#   'symbol': 'FIL',
#   'volumeUsd24Hr': '655527624.1976609798935116',
#   'vwap24Hr': '7.9958758222484739'},
#  {'changePercent24Hr': '-4.4286842483455357',
#   'explorer': 'https://etherscan.io/token/0x1d287cc25dad7ccaf76a26bc660c5f7c8e2a05bd',
#   'id': 'fetch',
#   'marketCapUsd': '4584315465.7322150520000000',
#   'maxSupply': '2630547141.0000000000000000',
#   'name': 'Artificial Superintelligence Alliance',
#   'priceUsd': '1.8191728038619901',
#   'rank': '30',
#   'supply': '2520000000.0000000000000000',
#   'symbol': 'FET',
#   'volumeUsd24Hr': '296362792.3395605832333426',
#   'vwap24Hr': '1.9299066316039066'},
#  {'changePercent24Hr': '-8.8081146427298533',
#   'explorer': 'https://hash-hash.info/',
#   'id': 'hedera-hashgraph',
#   'marketCapUsd': '4364917994.6794002142042832',
#   'maxSupply': '50000000000.0000000000000000',
#   'name': 'Hedera Hashgraph',
#   'priceUsd': '0.2942755875199244',
#   'rank': '31',
#   'supply': '14832756028.0000000000000000',
#   'symbol': 'HBAR',
#   'volumeUsd24Hr': '851605135.5739971058553404',
#   'vwap24Hr': '0.3098260129159576'},
#  {'changePercent24Hr': '4.9762968095362347',
#   'explorer': 'https://explorer.xinfin.network/',
#   'id': 'stacks',
#   'marketCapUsd': '4090192458.6907601193810440',
#   'maxSupply': '1818000000.0000000000000000',
#   'name': 'Stacks',
#   'priceUsd': '2.7205803674544014',
#   'rank': '32',
#   'supply': '1503426440.7773700000000000',
#   'symbol': 'STX',
#   'volumeUsd24Hr': '129875069.7878275201544500',
#   'vwap24Hr': '2.6084932931263048'},
#  {'changePercent24Hr': '-8.3264024690324576',
#   'explorer': 'https://algoexplorer.io/',
#   'id': 'algorand',
#   'marketCapUsd': '3954903910.3248322047038693',
#   'maxSupply': '10000000000.0000000000000000',
#   'name': 'Algorand',
#   'priceUsd': '0.4765909413609378',
#   'rank': '33',
#   'supply': '8298319517.0083080000000000',
#   'symbol': 'ALGO',
#   'volumeUsd24Hr': '327451306.3084226791951081',
#   'vwap24Hr': '0.5001748223200967'},
#  {'changePercent24Hr': '4.4879834316337398',
#   'explorer': 'https://etherscan.io/token/0x80fB784B7eD66730e8b1DBd9820aFD29931aab03',
#   'id': 'aave',
#   'marketCapUsd': '3758404720.5398723001435510',
#   'maxSupply': None,
#   'name': 'Aave',
#   'priceUsd': '250.4363640119091468',
#   'rank': '34',
#   'supply': '15007424.0830343100000000',
#   'symbol': 'AAVE',
#   'volumeUsd24Hr': '315760476.9911949757803008',
#   'vwap24Hr': '253.8863591013357505'},
#  {'changePercent24Hr': '-4.1656569525202506',
#   'explorer': 'http://moneroblocks.info/',
#   'id': 'monero',
#   'marketCapUsd': '3560012972.7386169620046814',
#   'maxSupply': None,
#   'name': 'Monero',
#   'priceUsd': '192.9886899559893860',
#   'rank': '35',
#   'supply': '18446744.0737095500000000',
#   'symbol': 'XMR',
#   'volumeUsd24Hr': '116243807.3615057092844545',
#   'vwap24Hr': '197.1609942729892265'},
#  {'changePercent24Hr': '-6.8065218677343989',
#   'explorer': 'https://etherscan.io/token/0x75231f58b43240c9718dd58b4967c5114342a86c',
#   'id': 'okb',
#   'marketCapUsd': '3439235006.7713147040000000',
#   'maxSupply': None,
#   'name': 'OKB',
#   'priceUsd': '57.3205834461885784',
#   'rank': '36',
#   'supply': '60000000.0000000000000000',
#   'symbol': 'OKB',
#   'volumeUsd24Hr': '417867.1953275817544547',
#   'vwap24Hr': '59.6189700508088557'},
#  {'changePercent24Hr': '-2.7935984274310214',
#   'explorer': 'https://etherscan.io/token/0x4e15361fd6b4bb609fa63c81a2be19d873717870',
#   'id': 'fantom',
#   'marketCapUsd': '3392860644.0974246779210301',
#   'maxSupply': None,
#   'name': 'Fantom',
#   'priceUsd': '1.2101649619645137',
#   'rank': '37',
#   'supply': '2803634835.5265927000000000',
#   'symbol': 'FTM',
#   'volumeUsd24Hr': '284286437.9839911942877514',
#   'vwap24Hr': '1.2321010531232524'},
#  {'changePercent24Hr': '1.5886219721954708',
#   'explorer': 'https://etherscan.io/token/0xc944e90c64b2c07662a292be6244bdf05cda44a7',
#   'id': 'the-graph',
#   'marketCapUsd': '3046242693.4243242656998202',
#   'maxSupply': None,
#   'name': 'The Graph',
#   'priceUsd': '0.3190273489175050',
#   'rank': '38',
#   'supply': '9548531509.1654740000000000',
#   'symbol': 'GRT',
#   'volumeUsd24Hr': '122556572.8313060718480217',
#   'vwap24Hr': '0.3232693371735588'},
#  {'changePercent24Hr': '-0.7506804989914074',
#   'explorer': 'https://explorer.thetatoken.org/',
#   'id': 'theta',
#   'marketCapUsd': '2914499801.2571051000000000',
#   'maxSupply': '1000000000.0000000000000000',
#   'name': 'THETA',
#   'priceUsd': '2.9144998012571051',
#   'rank': '39',
#   'supply': '1000000000.0000000000000000',
#   'symbol': 'THETA',
#   'volumeUsd24Hr': '96742749.9131060205215919',
#   'vwap24Hr': '2.9864967619894860'},
#  {'changePercent24Hr': '2.1812641065695789',
#   'explorer': 'https://www.mintscan.io/',
#   'id': 'cosmos',
#   'marketCapUsd': '2417844543.1953317947116434',
#   'maxSupply': None,
#   'name': 'Cosmos',
#   'priceUsd': '9.7315894239387634',
#   'rank': '40',
#   'supply': '248453201.0000000000000000',
#   'symbol': 'ATOM',
#   'volumeUsd24Hr': '302885340.0185991666081782',
#   'vwap24Hr': '10.1187630945585593'},
#  {'changePercent24Hr': '2.8600646953735309',
#   'explorer': 'https://explorer.binance.org/asset/RUNE-B1A',
#   'id': 'thorchain',
#   'marketCapUsd': '2397817847.3331295205533818',
#   'maxSupply': None,
#   'name': 'THORChain',
#   'priceUsd': '7.0517363894725821',
#   'rank': '41',
#   'supply': '340032258.0000000000000000',
#   'symbol': 'RUNE',
#   'volumeUsd24Hr': '214430202.2039784297191342',
#   'vwap24Hr': '6.9677352246883994'},
#  {'changePercent24Hr': '-5.5572801501034678',
#   'explorer': 'https://etherscan.io/token/0xe28b3b32b6c345a34ff64674606124dd5aceca30',
#   'id': 'injective-protocol',
#   'marketCapUsd': '2274606556.5867996311840679',
#   'maxSupply': '100000000.0000000000000000',
#   'name': 'Injective',
#   'priceUsd': '31.1566233208108240',
#   'rank': '42',
#   'supply': '73005554.3300000000000000',
#   'symbol': 'INJ',
#   'volumeUsd24Hr': '112699826.8216012444145042',
#   'vwap24Hr': '32.4735561494885067'},
#  {'changePercent24Hr': '15.0681630868819811',
#   'explorer': 'https://etherscan.io/token/0x3845badAde8e6dFF049820680d1F14bD3903a5d0',
#   'id': 'the-sandbox',
#   'marketCapUsd': '2161062210.7834720185008846',
#   'maxSupply': None,
#   'name': 'The Sandbox',
#   'priceUsd': '0.8892410677418905',
#   'rank': '43',
#   'supply': '2430232126.2233224000000000',
#   'symbol': 'SAND',
#   'volumeUsd24Hr': '913929069.0146368568722688',
#   'vwap24Hr': '0.9361759528099867'},
#  {'changePercent24Hr': '13.2899434449272963',
#   'explorer': 'https://ethplorer.io/es/address/0x15d4c048f83bd7e37d49ea4c83a07267ec4203da#chart=candlestick',
#   'id': 'gala',
#   'marketCapUsd': '2117088140.4514749890254544',
#   'maxSupply': None,
#   'name': 'Gala',
#   'priceUsd': '0.0581554359435481',
#   'rank': '44',
#   'supply': '36403959597.2859300000000000',
#   'symbol': 'GALA',
#   'volumeUsd24Hr': '425420870.7523279174866761',
#   'vwap24Hr': '0.0595039828219428'},
#  {'changePercent24Hr': '-7.7184213208654723',
#   'explorer': 'https://bloks.io/',
#   'id': 'eos',
#   'marketCapUsd': '2021351618.8896352419663477',
#   'maxSupply': None,
#   'name': 'EOS',
#   'priceUsd': '1.3197654247021158',
#   'rank': '45',
#   'supply': '1531599162.2874000000000000',
#   'symbol': 'EOS',
#   'volumeUsd24Hr': '577997096.1972858320345020',
#   'vwap24Hr': '1.4135090828209638'},
#  {'changePercent24Hr': '-3.6399577885640656',
#   'explorer': 'https://etherscan.io/token/Maker',
#   'id': 'maker',
#   'marketCapUsd': '1994512456.8930219224948408',
#   'maxSupply': '1005577.0000000000000000',
#   'name': 'Maker',
#   'priceUsd': '2243.1104922899232129',
#   'rank': '46',
#   'supply': '889172.6304828100000000',
#   'symbol': 'MKR',
#   'volumeUsd24Hr': '171264004.5327777882643063',
#   'vwap24Hr': '2314.5162287797212921'},
#  {'changePercent24Hr': '1.3620543452197141',
#   'explorer': 'https://etherscan.io/token/0x3593d125a4f7849a1b059e64f4517a86dd60c95d',
#   'id': 'mantra-dao',
#   'marketCapUsd': '1962130963.1455831547298725',
#   'maxSupply': '888888888.0000000000000000',
#   'name': 'MANTRA DAO',
#   'priceUsd': '3.9226533781135727',
#   'rank': '47',
#   'supply': '500205033.1781248500000000',
#   'symbol': 'OM',
#   'volumeUsd24Hr': '89674831.4385839697234858',
#   'vwap24Hr': '3.8415164799224574'},
#  {'changePercent24Hr': '3.5992915463976994',
#   'explorer': 'https://flowscan.org/',
#   'id': 'flow',
#   'marketCapUsd': '1861591687.5009402780535191',
#   'maxSupply': None,
#   'name': 'Flow',
#   'priceUsd': '1.2017147775879854',
#   'rank': '48',
#   'supply': '1549112753.0589437000000000',
#   'symbol': 'FLOW',
#   'volumeUsd24Hr': '91856883.4186176382191586',
#   'vwap24Hr': '1.2183077136464930'},
#  {'changePercent24Hr': '0.4324846471125582',
#   'explorer': 'https://etherscan.io/token/0x5a98fcbea516cf06857215779fd812ca3bef1b32',
#   'id': 'lido-dao',
#   'marketCapUsd': '1842463808.0427758296061888',
#   'maxSupply': None,
#   'name': 'Lido DAO',
#   'priceUsd': '2.0569116124258348',
#   'rank': '49',
#   'supply': '895742819.9211009000000000',
#   'symbol': 'LDO',
#   'volumeUsd24Hr': '18661830.0743814965974188',
#   'vwap24Hr': '2.1152687577928451'},
#  {'changePercent24Hr': '2.1488999548382668',
#   'explorer': 'https://etherscan.io/token/0x4a220e6096b25eadb88358cb44068a3248254675',
#   'id': 'quant',
#   'marketCapUsd': '1765002890.6706017667987516',
#   'maxSupply': '14881364.0000000000000000',
#   'name': 'Quant',
#   'priceUsd': '146.1973986903883582',
#   'rank': '50',
#   'supply': '12072738.0000000000000000',
#   'symbol': 'QNT',
#   'volumeUsd24Hr': '69539128.4587789104776067',
#   'vwap24Hr': '152.2602782601388842'},
#  {'changePercent24Hr': '-3.6777575988542252',
#   'explorer': 'https://viewblock.io/arweave',
#   'id': 'arweave',
#   'marketCapUsd': '1732991436.4019052274519678',
#   'maxSupply': '66000000.0000000000000000',
#   'name': 'Arweave',
#   'priceUsd': '26.3964408648702583',
#   'rank': '51',
#   'supply': '65652466.0000000000000000',
#   'symbol': 'AR',
#   'volumeUsd24Hr': '116762173.9478900347070991',
#   'vwap24Hr': '26.9661167043212391'},
#  {'changePercent24Hr': '-0.5761267393122247',
#   'explorer': 'https://tzkt.io/',
#   'id': 'tezos',
#   'marketCapUsd': '1710446639.5431155457111634',
#   'maxSupply': None,
#   'name': 'Tezos',
#   'priceUsd': '1.6826743312826337',
#   'rank': '52',
#   'supply': '1016504862.3754260000000000',
#   'symbol': 'XTZ',
#   'volumeUsd24Hr': '142427533.8922038989965519',
#   'vwap24Hr': '1.7328601232292443'},
#  {'changePercent24Hr': '-18.6525084028694699',
#   'explorer': 'https://thetangle.org/',
#   'id': 'iota',
#   'marketCapUsd': '1672197837.6047850744824444',
#   'maxSupply': None,
#   'name': 'IOTA',
#   'priceUsd': '0.4729455744671932',
#   'rank': '53',
#   'supply': '3535708817.0000000000000000',
#   'symbol': 'IOTA',
#   'volumeUsd24Hr': '152999909.4725417684919375',
#   'vwap24Hr': '0.5254712767303482'},
#  {'changePercent24Hr': '9.3359749688559781',
#   'explorer': 'https://bsvexplorer.io/',
#   'id': 'bitcoin-sv',
#   'marketCapUsd': '1658577858.5070036330920594',
#   'maxSupply': None,
#   'name': 'Bitcoin SV',
#   'priceUsd': '83.7963818755319582',
#   'rank': '54',
#   'supply': '19792953.1250000000000000',
#   'symbol': 'BSV',
#   'volumeUsd24Hr': '30149667.9409338093684252',
#   'vwap24Hr': '80.2765930736927243'},
#  {'changePercent24Hr': '4.0424511907355225',
#   'explorer': 'https://etherscan.io/token/0xf34960d9d60be18cc1d5afc1a6f012a723a28811',
#   'id': 'kucoin-token',
#   'marketCapUsd': '1612864489.9455887874138020',
#   'maxSupply': '200000000.0000000000000000',
#   'name': 'KuCoin Token',
#   'priceUsd': '13.4153075663250706',
#   'rank': '55',
#   'supply': '120225681.1460797300000000',
#   'symbol': 'KCS',
#   'volumeUsd24Hr': '3018307.6748828334482512',
#   'vwap24Hr': '13.1863800379986625'},
#  {'changePercent24Hr': '-6.6554172383471674',
#   'explorer': 'https://neotracker.io',
#   'id': 'neo',
#   'marketCapUsd': '1523912151.2198612095508991',
#   'maxSupply': '100000000.0000000000000000',
#   'name': 'Neo',
#   'priceUsd': '21.6038759023361361',
#   'rank': '56',
#   'supply': '70538831.0000000000000000',
#   'symbol': 'NEO',
#   'volumeUsd24Hr': '118340283.9270931342265062',
#   'vwap24Hr': '22.9264367196206204'},
#  {'changePercent24Hr': '8.1440898700041297',
#   'explorer': 'https://etherscan.io/token/decentraland',
#   'id': 'decentraland',
#   'marketCapUsd': '1457317072.4873791359888276',
#   'maxSupply': None,
#   'name': 'Decentraland',
#   'priceUsd': '0.7503221432527044',
#   'rank': '57',
#   'supply': '1942255184.1130493000000000',
#   'symbol': 'MANA',
#   'volumeUsd24Hr': '263308982.0433752665517075',
#   'vwap24Hr': '0.7804368023728730'},
#  {'changePercent24Hr': '-3.0292784282892287',
#   'explorer': 'https://explorer.solana.com/address/4k3Dyjzvzp8eMZWUXbBCjEvwSkkk59S5iCNLY3QrkX6R',
#   'id': 'raydium',
#   'marketCapUsd': '1444239929.8318519263795470',
#   'maxSupply': None,
#   'name': 'Raydium',
#   'priceUsd': '4.9644427870040190',
#   'rank': '58',
#   'supply': '290916824.2632590000000000',
#   'symbol': 'RAY',
#   'volumeUsd24Hr': '41077439.5873739350600406',
#   'vwap24Hr': '5.0581367214815246'},
#  {'changePercent24Hr': '0.2774858142056974',
#   'explorer': 'https://etherscan.io/token/0xf5d669627376ebd411e34b98f19c868c8aba5ada',
#   'id': 'axie-infinity',
#   'marketCapUsd': '1441176552.9646411951241860',
#   'maxSupply': None,
#   'name': 'Axie Infinity',
#   'priceUsd': '9.2721717464061439',
#   'rank': '59',
#   'supply': '155430312.5935124500000000',
#   'symbol': 'AXS',
#   'volumeUsd24Hr': '85962667.7092627617139093',
#   'vwap24Hr': '9.6930851120346021'},
#  {'changePercent24Hr': '-5.9046683265082919',
#   'explorer': 'https://explorer.helium.com/',
#   'id': 'helium',
#   'marketCapUsd': '1432420396.0782901501960565',
#   'maxSupply': None,
#   'name': 'Helium',
#   'priceUsd': '8.4026660451123527',
#   'rank': '60',
#   'supply': '170472132.1052022300000000',
#   'symbol': 'HNT',
#   'volumeUsd24Hr': '18163954.0119569271139935',
#   'vwap24Hr': '8.5902485219818746'},
#  {'changePercent24Hr': '-1.9250969461265761',
#   'explorer': 'https://etherscan.io/token/0x7D1AfA7B718fb893dB30A3aBc0Cfc608AaCfeBB0',
#   'id': 'polygon',
#   'marketCapUsd': '1359595860.9044633203494903',
#   'maxSupply': None,
#   'name': 'Polygon',
#   'priceUsd': '0.6924954198555131',
#   'rank': '61',
#   'supply': '1963328307.9159405000000000',
#   'symbol': 'MATIC',
#   'volumeUsd24Hr': '25222149.6165395832042145',
#   'vwap24Hr': '0.7200759224572315'},
#  {'changePercent24Hr': '21.9879468000310851',
#   'explorer': 'https://etherscan.io/token/0xD533a949740bb3306d119CC777fa900bA034cd52',
#   'id': 'curve-dao-token',
#   'marketCapUsd': '1319596526.0404586612496712',
#   'maxSupply': None,
#   'name': 'Curve DAO Token',
#   'priceUsd': '1.0592702213575706',
#   'rank': '62',
#   'supply': '1245760052.0000000000000000',
#   'symbol': 'CRV',
#   'volumeUsd24Hr': '306102999.0358695771070106',
#   'vwap24Hr': '1.0910834682277222'},
#  {'changePercent24Hr': '3.3147999306190219',
#   'explorer': 'https://explorer.elrond.com/',
#   'id': 'elrond-egld',
#   'marketCapUsd': '1319029312.7499550056360755',
#   'maxSupply': '31415926.0000000000000000',
#   'name': 'MultiversX',
#   'priceUsd': '54.5401428405608015',
#   'rank': '63',
#   'supply': '24184559.1898415400000000',
#   'symbol': 'EGLD',
#   'volumeUsd24Hr': '62351240.0754221670634305',
#   'vwap24Hr': '55.1829380477371709'},
#  {'changePercent24Hr': '-0.2927523247780680',
#   'explorer': 'https://etherscan.io/token/0x626e8036deb333b408be468f951bdb42433cbf18',
#   'id': 'aioz-network',
#   'marketCapUsd': '1259540323.8347767405595044',
#   'maxSupply': None,
#   'name': 'AIOZ Network',
#   'priceUsd': '1.1037923917833145',
#   'rank': '64',
#   'supply': '1141102559.8752606000000000',
#   'symbol': 'AIOZ',
#   'volumeUsd24Hr': '20366495.2642189378100732',
#   'vwap24Hr': '1.1337711111983629'},
#  {'changePercent24Hr': '6.6973197196652288',
#   'explorer': 'https://etherscan.io/token/0x3506424f91fd33084466f402d5d97f05f8e3b4af',
#   'id': 'chiliz',
#   'marketCapUsd': '1179854339.1843697201395852',
#   'maxSupply': None,
#   'name': 'Chiliz',
#   'priceUsd': '0.1281504393198156',
#   'rank': '65',
#   'supply': '9206791217.0000000000000000',
#   'symbol': 'CHZ',
#   'volumeUsd24Hr': '182571710.8834058857427533',
#   'vwap24Hr': '0.1312056098382506'},
#  {'changePercent24Hr': '-3.5168953752317274',
#   'explorer': 'https://explorer.zcha.in/',
#   'id': 'zcash',
#   'marketCapUsd': '1147686109.4898779250192525',
#   'maxSupply': '21000000.0000000000000000',
#   'name': 'Zcash',
#   'priceUsd': '70.2882912488733948',
#   'rank': '66',
#   'supply': '16328268.7500000000000000',
#   'symbol': 'ZEC',
#   'volumeUsd24Hr': '124380548.5496591935264149',
#   'vwap24Hr': '71.9430139296992168'},
#  {'changePercent24Hr': '-5.6459915622422733',
#   'explorer': 'http://www.confluxscan.io/',
#   'id': 'conflux-network',
#   'marketCapUsd': '1142345533.5937651861557197',
#   'maxSupply': None,
#   'name': 'Conflux',
#   'priceUsd': '0.2419300833344888',
#   'rank': '67',
#   'supply': '4721800273.2400000000000000',
#   'symbol': 'CFX',
#   'volumeUsd24Hr': '86679435.2975893224768192',
#   'vwap24Hr': '0.2500738003995627'},
#  {'changePercent24Hr': '4.8214398349566010',
#   'explorer': 'https://explorer.bitcoinabc.org/',
#   'id': 'ecash',
#   'marketCapUsd': '1131909855.9841651990056896',
#   'maxSupply': '21000000000000.0000000000000000',
#   'name': 'eCash',
#   'priceUsd': '0.0000571854094844',
#   'rank': '68',
#   'supply': '19793682797584.0000000000000000',
#   'symbol': 'XEC',
#   'volumeUsd24Hr': '30968000.3748601468502087',
#   'vwap24Hr': '0.0000559574153327'},
#  {'changePercent24Hr': '10.7402264726682469',
#   'explorer': 'https://bscscan.com/token/0x0e09fabb73bd3ade0a17ecc321fd13a19e81ce82',
#   'id': 'pancakeswap',
#   'marketCapUsd': '1118534033.9769502202734974',
#   'maxSupply': '450000000.0000000000000000',
#   'name': 'PancakeSwap',
#   'priceUsd': '3.9024750737726047',
#   'rank': '69',
#   'supply': '286621698.4944480000000000',
#   'symbol': 'CAKE',
#   'volumeUsd24Hr': '236832560.3811535498805499',
#   'vwap24Hr': '4.0164313730796087'},
#  {'changePercent24Hr': '-3.5003105434825597',
#   'explorer': None,
#   'id': 'gatetoken',
#   'marketCapUsd': '1092274624.1719561577675223',
#   'maxSupply': None,
#   'name': 'GateToken',
#   'priceUsd': '12.3037861240202475',
#   'rank': '70',
#   'supply': '88775488.5497844400000000',
#   'symbol': 'GT',
#   'volumeUsd24Hr': '16062829.1093712845433753',
#   'vwap24Hr': '12.8340115014687852'},
#  {'changePercent24Hr': '1.0380513703557835',
#   'explorer': 'https://etherscan.io/token/0x808507121b80c02388fad14726482e061b8da827',
#   'id': 'pendle',
#   'marketCapUsd': '1064511416.0526037030572974',
#   'maxSupply': None,
#   'name': 'Pendle',
#   'priceUsd': '6.4473361210612182',
#   'rank': '71',
#   'supply': '165108720.2628094600000000',
#   'symbol': 'PENDLE',
#   'volumeUsd24Hr': '24856905.8928309249750423',
#   'vwap24Hr': '6.5882855876774612'},
#  {'changePercent24Hr': '-3.6274453122662926',
#   'explorer': 'https://minaexplorer.com/',
#   'id': 'mina',
#   'marketCapUsd': '1059243483.1926020222001764',
#   'maxSupply': None,
#   'name': 'Mina',
#   'priceUsd': '0.8901313246238534',
#   'rank': '72',
#   'supply': '1189985627.8400393000000000',
#   'symbol': 'MINA',
#   'volumeUsd24Hr': '51481852.2798802395067524',
#   'vwap24Hr': '0.9162109530873094'},
#  {'changePercent24Hr': '35.5704001074692384',
#   'explorer': 'https://etherscan.io/token/0xc00e94cb662c3520282e6f5717214004a7f26888',
#   'id': 'compound',
#   'marketCapUsd': '1052926381.5765963790261337',
#   'maxSupply': None,
#   'name': 'Compound',
#   'priceUsd': '119.0033041338523938',
#   'rank': '73',
#   'supply': '8847875.1849804700000000',
#   'symbol': 'COMP',
#   'volumeUsd24Hr': '323006287.7962667103122518',
#   'vwap24Hr': '118.8413657900149212'},
#  {'changePercent24Hr': '-1.9255141623924219',
#   'explorer': 'https://akash.bigdipper.live/',
#   'id': 'akash-network',
#   'marketCapUsd': '1041069334.4653670968325097',
#   'maxSupply': '388539008.0000000000000000',
#   'name': 'Akash Network',
#   'priceUsd': '4.1930281830509572',
#   'rank': '74',
#   'supply': '248285794.6611410000000000',
#   'symbol': 'AKT',
#   'volumeUsd24Hr': '8073501.8690067824162520',
#   'vwap24Hr': '4.2415516498791999'},
#  {'changePercent24Hr': '-8.7729697697710157',
#   'explorer': 'https://etherscan.io/token/0x8762db106b2c2a0bccb3a80d1ed41273552616e8',
#   'id': 'reserve-rights',
#   'marketCapUsd': '1027763365.4943574455375815',
#   'maxSupply': '100000000000.0000000000000000',
#   'name': 'Reserve Rights',
#   'priceUsd': '0.0192201092791165',
#   'rank': '75',
#   'supply': '53473336211.0000000000000000',
#   'symbol': 'RSR',
#   'volumeUsd24Hr': '471231431.7015510680481966',
#   'vwap24Hr': '0.0212601995910951'},
#  {'changePercent24Hr': '2.3457676122634308',
#   'explorer': 'https://etherscan.io/token/0xb62132e35a6c13ee1ee0f84dc5d40bad8d815206',
#   'id': 'nexo',
#   'marketCapUsd': '978544779.3516374383001380',
#   'maxSupply': None,
#   'name': 'Nexo',
#   'priceUsd': '1.5144333050194196',
#   'rank': '76',
#   'supply': '646145839.5746847000000000',
#   'symbol': 'NEXO',
#   'volumeUsd24Hr': '660184.4215116810675822',
#   'vwap24Hr': '1.4961516942139404'},
#  {'changePercent24Hr': '-4.1369019922006887',
#   'explorer': 'https://www.oasisscan.com/',
#   'id': 'oasis-network',
#   'marketCapUsd': '922729382.5829899913451702',
#   'maxSupply': None,
#   'name': 'Oasis',
#   'priceUsd': '0.1306217513531142',
#   'rank': '77',
#   'supply': '7064132681.0000000000000000',
#   'symbol': 'ROSE',
#   'volumeUsd24Hr': '46195755.8069409843047161',
#   'vwap24Hr': '0.1324716772453990'},
#  {'changePercent24Hr': '-2.1259936719659900',
#   'explorer': 'https://etherscan.io/token/0x50d1c9771902476076ecfc8b2a83ad6b9355a4c9',
#   'id': 'ftx-token',
#   'marketCapUsd': '875600414.5843444107264181',
#   'maxSupply': None,
#   'name': 'FTX Token',
#   'priceUsd': '2.6622482500731715',
#   'rank': '78',
#   'supply': '328895103.8132070000000000',
#   'symbol': 'FTT',
#   'volumeUsd24Hr': '28722938.8824731269481046',
#   'vwap24Hr': '2.7067685145291441'},
#  {'changePercent24Hr': '-11.4143349156560247',
#   'explorer': 'https://etherscan.io/token/0x41ab1b6fcbb2fa9dced81acbdec13ea6315f2bf2',
#   'id': 'xinfin-network',
#   'marketCapUsd': '850854231.7346513633863523',
#   'maxSupply': None,
#   'name': 'XinFin Network',
#   'priceUsd': '0.0692128785870729',
#   'rank': '79',
#   'supply': '12293293518.5500000000000000',
#   'symbol': 'XDC',
#   'volumeUsd24Hr': '5436016.4579255217010491',
#   'vwap24Hr': '0.0743411260330535'},
#  {'changePercent24Hr': '-9.5237004386880930',
#   'explorer': None,
#   'id': 'amp',
#   'marketCapUsd': '832450816.8615662311333186',
#   'maxSupply': None,
#   'name': 'Amp',
#   'priceUsd': '0.0103124874053234',
#   'rank': '80',
#   'supply': '80722602039.9159500000000000',
#   'symbol': 'AMP',
#   'volumeUsd24Hr': '92543850.9420407405006462',
#   'vwap24Hr': '0.0119975663013834'},
#  {'changePercent24Hr': '-3.5099454442524173',
#   'explorer': 'https://etherscan.io/token/0xe53ec727dbdeb9e2d5456c3be40cff031ab40a55',
#   'id': 'superfarm',
#   'marketCapUsd': '810649634.5199484271817931',
#   'maxSupply': '1000000000.0000000000000000',
#   'name': 'SuperVerse',
#   'priceUsd': '1.6612486665967572',
#   'rank': '81',
#   'supply': '487976093.4169172600000000',
#   'symbol': 'SUPER',
#   'volumeUsd24Hr': '16991344.9932489793680293',
#   'vwap24Hr': '1.6631806915522566'},
#  {'changePercent24Hr': '-6.3054435746544570',
#   'explorer': 'https://explorer.nervos.org/',
#   'id': 'nervos-network',
#   'marketCapUsd': '772105678.1756065898068834',
#   'maxSupply': None,
#   'name': 'Nervos Network',
#   'priceUsd': '0.0169743583178038',
#   'rank': '82',
#   'supply': '45486590050.6985550000000000',
#   'symbol': 'CKB',
#   'volumeUsd24Hr': '73410604.9428062023747583',
#   'vwap24Hr': '0.0177975777218477'},
#  {'changePercent24Hr': '0.9046724305543300',
#   'explorer': 'https://www.mintscan.io/kava',
#   'id': 'kava',
#   'marketCapUsd': '749939292.6115313817692224',
#   'maxSupply': None,
#   'name': 'Kava',
#   'priceUsd': '0.6925581573052352',
#   'rank': '83',
#   'supply': '1082853887.0000000000000000',
#   'symbol': 'KAVA',
#   'volumeUsd24Hr': '38055999.9810793894472376',
#   'vwap24Hr': '0.7136312736474626'},
#  {'changePercent24Hr': '2.3360767817121198',
#   'explorer': 'https://etherscan.io/token/Gnosis',
#   'id': 'gnosis-gno',
#   'marketCapUsd': '736263056.0396873445230736',
#   'maxSupply': '3000000.0000000000000000',
#   'name': 'Gnosis',
#   'priceUsd': '284.3166774172908372',
#   'rank': '84',
#   'supply': '2589588.0000000000000000',
#   'symbol': 'GNO',
#   'volumeUsd24Hr': '6209027.3626601632317522',
#   'vwap24Hr': '281.4757804400228550'},
#  {'changePercent24Hr': '-1.5408834774062934',
#   'explorer': 'https://etherscan.io/token/0x111111111117dc0aa78b770fa6a738034120c302',
#   'id': '1inch',
#   'marketCapUsd': '709565616.9632448246779960',
#   'maxSupply': None,
#   'name': '1inch Network',
#   'priceUsd': '0.5097359677451995',
#   'rank': '85',
#   'supply': '1392025797.3985734000000000',
#   'symbol': '1INCH',
#   'volumeUsd24Hr': '69572913.9547052947135333',
#   'vwap24Hr': '0.5277909974350292'},
#  {'changePercent24Hr': '1.4013002527668877',
#   'explorer': 'https://kusama.subscan.io/',
#   'id': 'kusama',
#   'marketCapUsd': '705258550.3219158067133275',
#   'maxSupply': None,
#   'name': 'Kusama',
#   'priceUsd': '44.6249668646969095',
#   'rank': '86',
#   'supply': '15804124.9074820100000000',
#   'symbol': 'KSM',
#   'volumeUsd24Hr': '73921165.8189207982543236',
#   'vwap24Hr': '46.5966792538972819'},
#  {'changePercent24Hr': '1.1291753583408621',
#   'explorer': 'https://explorer.dash.org',
#   'id': 'dash',
#   'marketCapUsd': '696345524.7897072719016233',
#   'maxSupply': '18900000.0000000000000000',
#   'name': 'Dash',
#   'priceUsd': '57.7551019010352121',
#   'rank': '87',
#   'supply': '12056866.0061047500000000',
#   'symbol': 'DASH',
#   'volumeUsd24Hr': '107753500.9341237264161507',
#   'vwap24Hr': '59.0471037280956610'},
#  {'changePercent24Hr': '2.7992109499812575',
#   'explorer': 'https://etherscan.io/token/0xc011a72400e58ecd99ee497cf89e3775d4bd732f',
#   'id': 'synthetix-network-token',
#   'marketCapUsd': '692147153.2525778021213785',
#   'maxSupply': '212424133.0000000000000000',
#   'name': 'Synthetix',
#   'priceUsd': '2.9614788077730540',
#   'rank': '88',
#   'supply': '233716733.4900000000000000',
#   'symbol': 'SNX',
#   'volumeUsd24Hr': '74773214.5054959402302600',
#   'vwap24Hr': '3.0338300153130353'},
#  {'changePercent24Hr': '6.4568271470971158',
#   'explorer': 'https://explorer.bitcoingold.org/insight/',
#   'id': 'bitcoin-gold',
#   'marketCapUsd': '674751775.0131119530654345',
#   'maxSupply': '21000000.0000000000000000',
#   'name': 'Bitcoin Gold',
#   'priceUsd': '38.5265912337829575',
#   'rank': '89',
#   'supply': '17513923.5890000000000000',
#   'symbol': 'BTG',
#   'volumeUsd24Hr': '252058.0923098411913045',
#   'vwap24Hr': '37.6143806496369659'},
#  {'changePercent24Hr': '6.0233954667309438',
#   'explorer': 'https://etherscan.io/token/0xf629cbd94d3791c9250152bd8dfbdf380e2a3b9c',
#   'id': 'enjin-coin',
#   'marketCapUsd': '655046120.1442740384897777',
#   'maxSupply': None,
#   'name': 'Enjin Coin',
#   'priceUsd': '0.3677179360619357',
#   'rank': '90',
#   'supply': '1781382021.1205115000000000',
#   'symbol': 'ENJ',
#   'volumeUsd24Hr': '40169331.2792776804707812',
#   'vwap24Hr': '0.3688436857103774'},
#  {'changePercent24Hr': '4.2824302321553767',
#   'explorer': 'https://etherscan.io/token/0x4691937a7508860f876c9c0a2a617e7d9e945d4b',
#   'id': 'wootrade',
#   'marketCapUsd': '651345159.4290857500742029',
#   'maxSupply': None,
#   'name': 'WOO',
#   'priceUsd': '0.3511726183454052',
#   'rank': '91',
#   'supply': '1854772056.2553594000000000',
#   'symbol': 'WOO',
#   'volumeUsd24Hr': '6631836.0612411060965177',
#   'vwap24Hr': '0.3583694752718722'},
#  {'changePercent24Hr': '3.6013075595296234',
#   'explorer': 'https://etherscan.io/token/0x85e076361cc813a908ff672f9bad1541474402b2',
#   'id': 'telcoin',
#   'marketCapUsd': '643824599.9373440411611645',
#   'maxSupply': '100000000000.0000000000000000',
#   'name': 'Telcoin',
#   'priceUsd': '0.0070248627544971',
#   'rank': '92',
#   'supply': '91649420413.9700000000000000',
#   'symbol': 'TEL',
#   'volumeUsd24Hr': '3152651.5296038417629265',
#   'vwap24Hr': '0.0069452945844596'},
#  {'changePercent24Hr': '-2.8212111185123160',
#   'explorer': 'https://etherscan.io/token/0x05f4a42e251f2d52b8ed15e9fedaacfcef1fad27',
#   'id': 'zilliqa',
#   'marketCapUsd': '642616214.4914120105409428',
#   'maxSupply': None,
#   'name': 'Zilliqa',
#   'priceUsd': '0.0334025896051304',
#   'rank': '93',
#   'supply': '19238514800.4426200000000000',
#   'symbol': 'ZIL',
#   'volumeUsd24Hr': '63029945.1965669521652060',
#   'vwap24Hr': '0.0342056980889209'},
#  {'changePercent24Hr': '-1.4187012974895007',
#   'explorer': 'https://etherscan.io/token/0x6c6ee5e31d828de241282b9606c8e98ea48526e2',
#   'id': 'holo',
#   'marketCapUsd': '636804330.6972250945015800',
#   'maxSupply': None,
#   'name': 'Holo',
#   'priceUsd': '0.0036476894084639',
#   'rank': '94',
#   'supply': '174577454215.1585000000000000',
#   'symbol': 'HOT',
#   'volumeUsd24Hr': '26122853.9460820701184059',
#   'vwap24Hr': '0.0036647078333665'},
#  {'changePercent24Hr': '5.9489030035011708',
#   'explorer': 'https://explorer.livepeer.org/',
#   'id': 'livepeer',
#   'marketCapUsd': '636310019.1713218991886187',
#   'maxSupply': None,
#   'name': 'Livepeer',
#   'priceUsd': '17.5228489752240218',
#   'rank': '95',
#   'supply': '36313160.0387023800000000',
#   'symbol': 'LPT',
#   'volumeUsd24Hr': '40571178.8559568649664691',
#   'vwap24Hr': '17.3245813402485970'},
#  {'changePercent24Hr': '1.2357296750980222',
#   'explorer': 'https://explorer.thetatoken.org/',
#   'id': 'theta-fuel',
#   'marketCapUsd': '619010028.2101940369601096',
#   'maxSupply': None,
#   'name': 'Theta Fuel',
#   'priceUsd': '0.0914792450616974',
#   'rank': '96',
#   'supply': '6766671804.0000000000000000',
#   'symbol': 'TFUEL',
#   'volumeUsd24Hr': '7538323.2109756757630578',
#   'vwap24Hr': '0.0939208805295643'},
#  {'changePercent24Hr': '3.3583477793251409',
#   'explorer': 'https://etherscan.io/token/0xde4EE8057785A7e8e800Db58F9784845A5C2Cbd6',
#   'id': 'dexe',
#   'marketCapUsd': '612351192.4067913989169500',
#   'maxSupply': None,
#   'name': 'DeXe',
#   'priceUsd': '10.7235791126812905',
#   'rank': '97',
#   'supply': '57103247.5232684700000000',
#   'symbol': 'DEXE',
#   'volumeUsd24Hr': '1153078.8798687834399177',
#   'vwap24Hr': '10.8714203548685448'},
#  {'changePercent24Hr': '3.8139376984400908',
#   'explorer': 'https://explorer.binance.org/asset/TWT-8C2',
#   'id': 'trust-wallet-token',
#   'marketCapUsd': '589262161.1336837255241900',
#   'maxSupply': None,
#   'name': 'Trust Wallet Token',
#   'priceUsd': '1.4142860975934081',
#   'rank': '98',
#   'supply': '416649900.0000000000000000',
#   'symbol': 'TWT',
#   'volumeUsd24Hr': '24845669.1861287621703875',
#   'vwap24Hr': '1.4538153722022050'},
#  {'changePercent24Hr': '1.0958208987865670',
#   'explorer': 'https://explorer.celo.org/blocks',
#   'id': 'celo',
#   'marketCapUsd': '585546346.2952235573446032',
#   'maxSupply': '1000000000.0000000000000000',
#   'name': 'Celo',
#   'priceUsd': '1.0518316998480432',
#   'rank': '99',
#   'supply': '556692051.0000000000000000',
#   'symbol': 'CELO',
#   'volumeUsd24Hr': '48650326.5133355598974510',
#   'vwap24Hr': '1.0843726556111153'},
#  {'changePercent24Hr': '-4.2249801243123883',
#   'explorer': 'https://etherscan.io/token/0x6fb3e0a217407efff7ca062d46c26e5d60a14d69',
#   'id': 'iotex',
#   'marketCapUsd': '574477845.2465667725814837',
#   'maxSupply': '10000000000.0000000000000000',
#   'name': 'IoTeX',
#   'priceUsd': '0.0608468794915541',
#   'rank': '100',
#   'supply': '9441369057.0000000000000000',
#   'symbol': 'IOTX',
#   'volumeUsd24Hr': '29913480.7624330196208121',
#   'vwap24Hr': '0.0664599106014929'}]
# [{'baseId': 'bitcoin',
#   'baseSymbol': 'BTC',
#   'exchangeId': 'alterdice',
#   'percentExchangeVolume': '100.0000000000000000',
#   'priceQuote': '100915.9800000000000000',
#   'priceUsd': '100937.7399958714716024',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '1',
#   'tradesCount24Hr': '7',
#   'updated': 1733366502860,
#   'volumeUsd24Hr': '48443840.0501293730335927'},
#  {'baseId': 'ethereum',
#   'baseSymbol': 'ETH',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '12.8560863339509766',
#   'priceQuote': '3834.2000000000000000',
#   'priceUsd': '3835.0267489070650299',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '1',
#   'tradesCount24Hr': None,
#   'updated': 1733366280938,
#   'volumeUsd24Hr': '16844719.5306419892432481'},
#  {'baseId': 'chainlink',
#   'baseSymbol': 'LINK',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '10.3584945910872924',
#   'priceQuote': '23.3040000000000000',
#   'priceUsd': '23.3090249221559239',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '2',
#   'tradesCount24Hr': None,
#   'updated': 1733361064151,
#   'volumeUsd24Hr': '13572243.6528562034929416'},
#  {'baseId': 'binance-coin',
#   'baseSymbol': 'BNB',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '4.2502557043822509',
#   'priceQuote': '705.3300000000000000',
#   'priceUsd': '705.4820866951698340',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '3',
#   'tradesCount24Hr': None,
#   'updated': 1733363083954,
#   'volumeUsd24Hr': '5568908.2520207065753745'},
#  {'baseId': 'livepeer',
#   'baseSymbol': 'LPT',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '4.1027268272335217',
#   'priceQuote': '18.1451050000000000',
#   'priceUsd': '18.1490175360511528',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '4',
#   'tradesCount24Hr': None,
#   'updated': 1733341126193,
#   'volumeUsd24Hr': '5375608.1688003445993516'},
#  {'baseId': 'wink',
#   'baseSymbol': 'WIN',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '3.8515038751813012',
#   'priceQuote': '0.0001555500000000',
#   'priceUsd': '0.0001555835404498',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '5',
#   'tradesCount24Hr': None,
#   'updated': 1733366131432,
#   'volumeUsd24Hr': '5046442.6625137164418576'},
#  {'baseId': 'gnosis-gno',
#   'baseSymbol': 'GNO',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '3.1929456799331050',
#   'priceQuote': '284.3820000000000000',
#   'priceUsd': '284.4433198340433382',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '6',
#   'tradesCount24Hr': None,
#   'updated': 1733357856300,
#   'volumeUsd24Hr': '4183565.1268934013003452'},
#  {'baseId': 'small-love-potion',
#   'baseSymbol': 'SLP',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '2.9416088935104113',
#   'priceQuote': '0.0052860000000000',
#   'priceUsd': '0.0052871397931049',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '7',
#   'tradesCount24Hr': None,
#   'updated': 1733362023776,
#   'volumeUsd24Hr': '3854250.4688358719257109'},
#  {'baseId': 'chiliz',
#   'baseSymbol': 'CHZ',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '2.2604525327177700',
#   'priceQuote': '0.1277960000000000',
#   'priceUsd': '0.1278235559969035',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '8',
#   'tradesCount24Hr': None,
#   'updated': 1733366135247,
#   'volumeUsd24Hr': '2961763.6298385304823829'},
#  {'baseId': 'litecoin',
#   'baseSymbol': 'LTC',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '2.2099262981116808',
#   'priceQuote': '0.0337489500000000',
#   'priceUsd': '129.5344100980548368',
#   'quoteId': 'ethereum',
#   'quoteSymbol': 'ETH',
#   'rank': '9',
#   'tradesCount24Hr': None,
#   'updated': 1733366311977,
#   'volumeUsd24Hr': '2895561.5035638054426665'},
#  {'baseId': 'tokocrypto',
#   'baseSymbol': 'TKO',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '1.9856653916906046',
#   'priceQuote': '0.4878680000000000',
#   'priceUsd': '0.4879731964779594',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '10',
#   'tradesCount24Hr': None,
#   'updated': 1733357835858,
#   'volumeUsd24Hr': '2601723.0855396142589461'},
#  {'baseId': 'polkadot',
#   'baseSymbol': 'DOT',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '1.8849668988259880',
#   'priceQuote': '8.9499000000000000',
#   'priceUsd': '8.9518298210952327',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '11',
#   'tradesCount24Hr': None,
#   'updated': 1733355447862,
#   'volumeUsd24Hr': '2469782.6313919696327818'},
#  {'baseId': 'myneighboralice',
#   'baseSymbol': 'ALICE',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '1.7436778599747878',
#   'priceQuote': '1.8225000000000000',
#   'priceUsd': '1.8228929763400777',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '12',
#   'tradesCount24Hr': None,
#   'updated': 1733357832030,
# ...
#   'volumeUsd24Hr': '584461.2178826437272647'},
#  {'baseId': 'litecoin',
#   'baseSymbol': 'LTC',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.4430913753835201',
#   'priceQuote': '123.1400000000000000',
#   'priceUsd': '123.1665520474716989',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '56',
#   'tradesCount24Hr': None,
#   'updated': 1733366313250,
#   'volumeUsd24Hr': '580561.5916774896381578'},
#  {'baseId': 'basic-attention-token',
#   'baseSymbol': 'BAT',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.4374333037831619',
#   'priceQuote': '0.3354000000000000',
#   'priceUsd': '0.3354723205840670',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '57',
#   'tradesCount24Hr': None,
#   'updated': 1733363614538,
#   'volumeUsd24Hr': '573148.0890985105422579'},
#  {'baseId': 'ecash',
#   'baseSymbol': 'XEC',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.4346028602327091',
#   'priceQuote': '0.0000549800000000',
#   'priceUsd': '0.0000549918550558',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '58',
#   'tradesCount24Hr': None,
#   'updated': 1733364936611,
#   'volumeUsd24Hr': '569439.4933006756476964'},
#  {'baseId': 'aave',
#   'baseSymbol': 'AAVE',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.4312258421625339',
#   'priceQuote': '0.0025185500000000',
#   'priceUsd': '252.1268787415159534',
#   'quoteId': 'bitcoin',
#   'quoteSymbol': 'BTC',
#   'rank': '59',
#   'tradesCount24Hr': None,
#   'updated': 1733362036515,
#   'volumeUsd24Hr': '565014.7468604011801051'},
#  {'baseId': 'avalanche',
#   'baseSymbol': 'AVAX',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.4292248876027095',
#   'priceQuote': '52.6889000000000000',
#   'priceUsd': '52.7002610376322202',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '60',
#   'tradesCount24Hr': None,
#   'updated': 1733357862667,
#   'volumeUsd24Hr': '562392.9911037686769222'},
#  {'baseId': 'bitcoin-sv',
#   'baseSymbol': 'BSV',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.4187231103431702',
#   'priceQuote': '80.7300000000000000',
#   'priceUsd': '80.7474073963975170',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '61',
#   'tradesCount24Hr': None,
#   'updated': 1733359192649,
#   'volumeUsd24Hr': '548633.0109733421637440'},
#  {'baseId': 'internet-computer',
#   'baseSymbol': 'ICP',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.4080418462340047',
#   'priceQuote': '14.9900000000000000',
#   'priceUsd': '14.9932322169205844',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '62',
#   'tradesCount24Hr': None,
#   'updated': 1733350698671,
#   'volumeUsd24Hr': '534637.8577456870632490'},
#  {'baseId': 'dogecoin',
#   'baseSymbol': 'DOGE',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.4045156103245466',
#   'priceQuote': '0.4117080000000000',
#   'priceUsd': '0.4117967744872542',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '63',
#   'tradesCount24Hr': None,
#   'updated': 1733363594211,
#   'volumeUsd24Hr': '530017.5982552979575381'},
#  {'baseId': 'tellor',
#   'baseSymbol': 'TRB',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3992761063871764',
#   'priceQuote': '86.3630000000000000',
#   'priceUsd': '86.3816220113350522',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '64',
#   'tradesCount24Hr': None,
#   'updated': 1733346262546,
#   'volumeUsd24Hr': '523152.5250120030120824'},
#  {'baseId': 'phala-network',
#   'baseSymbol': 'PHA',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3933003656779115',
#   'priceQuote': '0.1751360000000000',
#   'priceUsd': '0.1751737636786260',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '65',
#   'tradesCount24Hr': None,
#   'updated': 1733362009767,
#   'volumeUsd24Hr': '515322.7956822006785208'},
#  {'baseId': 'akropolis',
#   'baseSymbol': 'AKRO',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3844138380819421',
#   'priceQuote': '0.0067120000000000',
#   'priceUsd': '0.0067134472741809',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '66',
#   'tradesCount24Hr': None,
#   'updated': 1733361993502,
#   'volumeUsd24Hr': '503679.2004956856325249'},
#  {'baseId': 'bitcoin-sv',
#   'baseSymbol': 'BSV',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3814309960625335',
#   'priceQuote': '0.0008382300000000',
#   'priceUsd': '83.9134873508570081',
#   'quoteId': 'bitcoin',
#   'quoteSymbol': 'BTC',
#   'rank': '67',
#   'tradesCount24Hr': None,
#   'updated': 1733359193945,
#   'volumeUsd24Hr': '499770.9242196884881512'},
#  {'baseId': 'just',
#   'baseSymbol': 'JST',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3721499011403689',
#   'priceQuote': '0.0536000000000000',
#   'priceUsd': '0.0536115574934585',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '68',
#   'tradesCount24Hr': None,
#   'updated': 1733366130139,
#   'volumeUsd24Hr': '487610.3461992791169692'},
#  {'baseId': 'mobox',
#   'baseSymbol': 'MBOX',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3683630537911285',
#   'priceQuote': '0.3146970000000000',
#   'priceUsd': '0.3147648565022186',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '69',
#   'tradesCount24Hr': None,
#   'updated': 1733357849985,
#   'volumeUsd24Hr': '482648.6199128855609236'},
#  {'baseId': 'chainlink',
#   'baseSymbol': 'LINK',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3653628612756327',
#   'priceQuote': '0.0002372700000000',
#   'priceUsd': '23.7526134160526852',
#   'quoteId': 'bitcoin',
#   'quoteSymbol': 'BTC',
#   'rank': '70',
#   'tradesCount24Hr': None,
#   'updated': 1733361061597,
#   'volumeUsd24Hr': '478717.6101056477249168'},
#  {'baseId': 'nem',
#   'baseSymbol': 'XEM',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3522358334566901',
#   'priceQuote': '0.0394000000000000',
#   'priceUsd': '0.0394084956201915',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '71',
#   'tradesCount24Hr': None,
#   'updated': 1733363075003,
#   'volumeUsd24Hr': '461517.8888112226853559'},
#  {'baseId': 'kusama',
#   'baseSymbol': 'KSM',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3401404936798602',
#   'priceQuote': '43.8399270000000000',
#   'priceUsd': '43.8493799789090451',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '72',
#   'tradesCount24Hr': None,
#   'updated': 1733361080052,
#   'volumeUsd24Hr': '445669.9393749728254693'},
#  {'baseId': 'ontology',
#   'baseSymbol': 'ONT',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3347484279855932',
#   'priceQuote': '0.0000035700000000',
#   'priceUsd': '0.3573853832988076',
#   'quoteId': 'bitcoin',
#   'quoteSymbol': 'BTC',
#   'rank': '73',
#   'tradesCount24Hr': None,
#   'updated': 1733365793746,
#   'volumeUsd24Hr': '438604.9717050793493271'},
#  {'baseId': 'zilliqa',
#   'baseSymbol': 'ZIL',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3127124685161564',
#   'priceQuote': '0.0332000000000000',
#   'priceUsd': '0.0332071587459482',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '74',
#   'tradesCount24Hr': None,
#   'updated': 1733361445071,
#   'volumeUsd24Hr': '409732.3002552149916551'},
#  {'baseId': 'filecoin',
#   'baseSymbol': 'FIL',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3124125545780716',
#   'priceQuote': '7.6667000000000000',
#   'priceUsd': '7.6683531312518375',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '75',
#   'tradesCount24Hr': None,
#   'updated': 1733362026294,
#   'volumeUsd24Hr': '409339.3372617239955882'},
#  {'baseId': 'uma',
#   'baseSymbol': 'UMA',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3047622580136750',
#   'priceQuote': '3.9025790000000000',
#   'priceUsd': '3.9034204931205949',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '76',
#   'tradesCount24Hr': None,
#   'updated': 1733359201581,
#   'volumeUsd24Hr': '399315.5169009990612956'},
#  {'baseId': 'kusama',
#   'baseSymbol': 'KSM',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.3019886623549673',
#   'priceQuote': '0.0116501000000000',
#   'priceUsd': '44.7151342807212863',
#   'quoteId': 'ethereum',
#   'quoteSymbol': 'ETH',
#   'rank': '77',
#   'tradesCount24Hr': None,
#   'updated': 1733361082603,
#   'volumeUsd24Hr': '395681.4061966429766789'},
#  {'baseId': 'loopring',
#   'baseSymbol': 'LRC',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2972646146489468',
#   'priceQuote': '0.2985670000000000',
#   'priceUsd': '0.2986313784729372',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '78',
#   'tradesCount24Hr': None,
#   'updated': 1733362008488,
#   'volumeUsd24Hr': '389491.7107799948816782'},
#  {'baseId': 'ontology',
#   'baseSymbol': 'ONT',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2905258116359186',
#   'priceQuote': '0.3564000000000000',
#   'priceUsd': '0.3564768487065041',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '79',
#   'tradesCount24Hr': None,
#   'updated': 1733365795012,
#   'volumeUsd24Hr': '380662.1771429241801717'},
#  {'baseId': 'xrp',
#   'baseSymbol': 'XRP',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2861554697174965',
#   'priceQuote': '2.2930600000000000',
#   'priceUsd': '2.2909679840631823',
#   'quoteId': 'usd-coin',
#   'quoteSymbol': 'USDC',
#   'rank': '80',
#   'tradesCount24Hr': None,
#   'updated': 1733365816547,
#   'volumeUsd24Hr': '374935.9256262075043601'},
#  {'baseId': 'qtum',
#   'baseSymbol': 'QTUM',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2853684849083748',
#   'priceQuote': '0.0012858900000000',
#   'priceUsd': '4.9354721436070673',
#   'quoteId': 'ethereum',
#   'quoteSymbol': 'ETH',
#   'rank': '81',
#   'tradesCount24Hr': None,
#   'updated': 1733365774466,
#   'volumeUsd24Hr': '373904.7767959819885740'},
#  {'baseId': 'mxc',
#   'baseSymbol': 'MXC',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2666450019815645',
#   'priceQuote': '0.0068850000000000',
#   'priceUsd': '0.0068864845772847',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '82',
#   'tradesCount24Hr': None,
#   'updated': 1733365819096,
#   'volumeUsd24Hr': '349372.2860872053099066'},
#  {'baseId': 'qtum',
#   'baseSymbol': 'QTUM',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2664064732854664',
#   'priceQuote': '0.0000521700000000',
#   'priceUsd': '5.2226317777867770',
#   'quoteId': 'bitcoin',
#   'quoteSymbol': 'BTC',
#   'rank': '83',
#   'tradesCount24Hr': None,
#   'updated': 1733365773206,
#   'volumeUsd24Hr': '349059.7532617861628522'},
#  {'baseId': 'stellar',
#   'baseSymbol': 'XLM',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2607603508358587',
#   'priceQuote': '0.5011780000000000',
#   'priceUsd': '0.5012860664450850',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '84',
#   'tradesCount24Hr': None,
#   'updated': 1733341127595,
#   'volumeUsd24Hr': '341661.9070877028929674'},
#  {'baseId': 'xch',
#   'baseSymbol': 'XCH',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2492680770702199',
#   'priceQuote': '32.7000000000000000',
#   'priceUsd': '32.7070509335092135',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '85',
#   'tradesCount24Hr': None,
#   'updated': 1733350696161,
#   'volumeUsd24Hr': '326604.1264130108539207'},
#  {'baseId': 'nxm',
#   'baseSymbol': 'NXM',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2434306635368051',
#   'priceQuote': '73.0775730000000000',
#   'priceUsd': '73.0933303427595626',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '86',
#   'tradesCount24Hr': None,
#   'updated': 1733346265394,
#   'volumeUsd24Hr': '318955.6406141038142133'},
#  {'baseId': 'ethereum-classic',
#   'baseSymbol': 'ETC',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2427436422374310',
#   'priceQuote': '0.0003671800000000',
#   'priceUsd': '36.7576372660101359',
#   'quoteId': 'bitcoin',
#   'quoteSymbol': 'BTC',
#   'rank': '87',
#   'tradesCount24Hr': None,
#   'updated': 1733366291128,
#   'volumeUsd24Hr': '318055.4692245439620791'},
#  {'baseId': 'synthetix-network-token',
#   'baseSymbol': 'SNX',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2400571365194635',
#   'priceQuote': '3.0872000000000000',
#   'priceUsd': '3.0878656771232307',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '88',
#   'tradesCount24Hr': None,
#   'updated': 1733352287003,
#   'volumeUsd24Hr': '314535.4683346058708946'},
#  {'baseId': 'phala-network',
#   'baseSymbol': 'PHA',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2377260813012356',
#   'priceQuote': '0.0000018300000000',
#   'priceUsd': '0.1831975494220779',
#   'quoteId': 'bitcoin',
#   'quoteSymbol': 'BTC',
#   'rank': '89',
#   'tradesCount24Hr': None,
#   'updated': 1733362011054,
#   'volumeUsd24Hr': '311481.1973580807473657'},
#  {'baseId': 'tron',
#   'baseSymbol': 'TRX',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.2250511442492074',
#   'priceQuote': '0.3319510000000000',
#   'priceUsd': '0.3320225768938629',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '90',
#   'tradesCount24Hr': None,
#   'updated': 1733366344729,
#   'volumeUsd24Hr': '294873.8291307750107703'},
#  {'baseId': 'phala-network',
#   'baseSymbol': 'PHA',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1733810176782624',
#   'priceQuote': '0.0000463300000000',
#   'priceUsd': '0.1778226943310201',
#   'quoteId': 'ethereum',
#   'quoteSymbol': 'ETH',
#   'rank': '91',
#   'tradesCount24Hr': None,
#   'updated': 1733362012323,
#   'volumeUsd24Hr': '227172.9155252223480303'},
#  {'baseId': 'algorand',
#   'baseSymbol': 'ALGO',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1604379799659484',
#   'priceQuote': '0.4685000000000000',
#   'priceUsd': '0.4680725757431558',
#   'quoteId': 'usd-coin',
#   'quoteSymbol': 'USDC',
#   'rank': '92',
#   'tradesCount24Hr': None,
#   'updated': 1733363608178,
#   'volumeUsd24Hr': '210214.2677318663442986'},
#  {'baseId': 'marlin',
#   'baseSymbol': 'POND',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1522453300655687',
#   'priceQuote': '0.0216020000000000',
#   'priceUsd': '0.0216066579286136',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '93',
#   'tradesCount24Hr': None,
#   'updated': 1733362049250,
#   'volumeUsd24Hr': '199479.8275453382220939'},
#  {'baseId': 'orbs',
#   'baseSymbol': 'ORBS',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1518919374130186',
#   'priceQuote': '0.0391900000000000',
#   'priceUsd': '0.0391984503389672',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '94',
#   'tradesCount24Hr': None,
#   'updated': 1733350693653,
#   'volumeUsd24Hr': '199016.7939313934095264'},
#  {'baseId': 'conflux-network',
#   'baseSymbol': 'CFX',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1438969977673574',
#   'priceQuote': '0.2438920000000000',
#   'priceUsd': '0.2439445891827348',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '95',
#   'tradesCount24Hr': None,
#   'updated': 1733357833290,
#   'volumeUsd24Hr': '188541.4041045591403874'},
#  {'baseId': 'crypto-com-coin',
#   'baseSymbol': 'CRO',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1386606933051831',
#   'priceQuote': '0.2046000000000000',
#   'priceUsd': '0.2046441168500301',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '96',
#   'tradesCount24Hr': None,
#   'updated': 1733363604339,
#   'volumeUsd24Hr': '181680.5229817059867779'},
#  {'baseId': 'dao',
#   'baseSymbol': 'DAO',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1352518055430320',
#   'priceQuote': '0.4790470000000000',
#   'priceUsd': '0.4791502944509110',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '97',
#   'tradesCount24Hr': None,
#   'updated': 1733363071191,
#   'volumeUsd24Hr': '177214.0191971732014151'},
#  {'baseId': 'ravencoin',
#   'baseSymbol': 'RVN',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1345246347171670',
#   'priceQuote': '0.0338680000000000',
#   'priceUsd': '0.0338753027833667',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '98',
#   'tradesCount24Hr': None,
#   'updated': 1733346263942,
#   'volumeUsd24Hr': '176261.2417893072764038'},
#  {'baseId': 'stafi',
#   'baseSymbol': 'FIS',
#   'exchangeId': 'bibox',
#   'percentExchangeVolume': '0.1214213984066582',
#   'priceQuote': '0.4337000000000000',
#   'priceUsd': '0.4337935165095702',
#   'quoteId': 'tether',
#   'quoteSymbol': 'USDT',
#   'rank': '99',
#   'tradesCount24Hr': None,
#   'updated': 1733362013607,
#   'volumeUsd24Hr': '159092.6933787886672781'}]

# %%
df_assets = build_table(json_data)

df_markets = build_table(json_data2)

# %%
df_assets.head()

df_markets.head()
# Out:
#   exchangeId rank baseSymbol        baseId quoteSymbol quoteId  \
# 0  alterdice    1        BTC       bitcoin        USDT  tether
# 1      bibox    1        ETH      ethereum        USDT  tether
# 2      bibox    2       LINK     chainlink        USDT  tether
# 3      bibox    3        BNB  binance-coin        USDT  tether
# 4      bibox    4        LPT      livepeer        USDT  tether
#
#                 priceQuote                 priceUsd  \
# 0  100915.9800000000000000  100937.7399958714716024
# 1    3834.2000000000000000    3835.0267489070650299
# 2      23.3040000000000000      23.3090249221559239
# 3     705.3300000000000000     705.4820866951698340
# 4      18.1451050000000000      18.1490175360511528
#
#                volumeUsd24Hr percentExchangeVolume tradesCount24Hr  \
# 0  48443840.0501293730335927  100.0000000000000000               7
# 1  16844719.5306419892432481   12.8560863339509766            None
# 2  13572243.6528562034929416   10.3584945910872924            None
# 3   5568908.2520207065753745    4.2502557043822509            None
# 4   5375608.1688003445993516    4.1027268272335217            None
#
#          updated
# 0  1733366502860
# 1  1733366280938
# 2  1733361064151
# 3  1733363083954
# 4  1733341126193

# %%
# Si los datos de los activos y el timestamp son válidos
if df_assets is not None and json_data_times is not None:
    # Convertir el timestamp de milisegundos a segundos y luego a una fecha legible
    timestamp_datetime = datetime.fromtimestamp(json_data_times / 1000, tz=timezone.utc)

    # Dividir el timestamp en columnas de fecha y hora
    df_assets['date'] = timestamp_datetime.date()  
    df_assets['time'] = timestamp_datetime.time()

    # Convertir la columna 'date' a un tipo compatible con Delta Lake
    df_assets['date'] = pd.to_datetime(df_assets['date'], errors='coerce')

    # Convertir la columna 'time' a un tipo compatible (por ejemplo, string)
    df_assets['time'] = df_assets['time'].astype(str)
# Si los datos de los activos y el timestamp son válidos
if df_markets is not None and json_data_times2 is not None:
    # Convertir el timestamp de milisegundos a segundos y luego a una fecha legible
    timestamp_datetime2 = datetime.fromtimestamp(json_data_times2 / 1000, tz=timezone.utc)

# Asignar el timestamp al DataFrame
    # Dividir el timestamp en columnas de fecha y hora
    df_markets['date'] = timestamp_datetime2.date()  
    df_markets['time'] = timestamp_datetime2.time()
    
    # Convertir la columna 'date' a un tipo compatible con Delta Lake
    df_markets['date'] = pd.to_datetime(df_markets['date'], errors='coerce')

    # Convertir la columna 'time' a un tipo compatible (por ejemplo, string)
    df_markets['time'] = df_markets['time'].astype(str)

# %%
# Aquí debería aparecer la columna 'timestamp' en el DataFrame
# DF temporal
df_assets.head()
# Out:
#              id rank symbol      name                         supply  \
# 0       bitcoin    1    BTC   Bitcoin      19790568.0000000000000000
# 1      ethereum    2    ETH  Ethereum     120441990.1196158200000000
# 2        tether    3   USDT    Tether  135691101232.3204500000000000
# 3  binance-coin    4    BNB       BNB     166801148.0000000000000000
# 4        solana    5    SOL    Solana     475356454.2156859000000000
#
#                     maxSupply                    marketCapUsd  \
# 0   21000000.0000000000000000  1979715808471.1145134388494256
# 1                        None   461769382749.4349832916737059
# 2                        None   135746019561.9712812862370636
# 3  166801148.0000000000000000   120620418671.5942988014635172
# 4                        None   110067415722.1157333236138697
#
#                   volumeUsd24Hr                 priceUsd    changePercent24Hr  \
# 0  27055581785.2751703938677858  100033.2991186061215342   4.2783813194041564
# 1  19690161901.8066180021863565    3833.9567645040828457   5.0276625574947599
# 2  67212530575.9733740471874540       1.0004047305177132   0.0060468274224712
# 3   1925464184.0828705250403807     723.1390198321314839  -4.0687374077078990
# 4   2053827815.3164765042266833     231.5471153194320264  -2.7100850749053788
#
#                  vwap24Hr                                           explorer  \
# 0  97051.5062276099056651                           https://blockchain.info/
# 1   3776.4260733775174657                              https://etherscan.io/
# 2      1.0008207745951950             https://www.omniexplorer.info/asset/31
# 3    749.4005444409089440  https://etherscan.io/token/0xB8c77482e45F1F44d...
# 4    232.6796691822089342                       https://explorer.solana.com/
#
#         date             time
# 0 2024-12-05  02:43:00.613000
# 1 2024-12-05  02:43:00.613000
# 2 2024-12-05  02:43:00.613000
# 3 2024-12-05  02:43:00.613000
# 4 2024-12-05  02:43:00.613000

# %%
# DF estatico
df_markets.head()
# Out:
#   exchangeId rank baseSymbol        baseId quoteSymbol quoteId  \
# 0  alterdice    1        BTC       bitcoin        USDT  tether
# 1      bibox    1        ETH      ethereum        USDT  tether
# 2      bibox    2       LINK     chainlink        USDT  tether
# 3      bibox    3        BNB  binance-coin        USDT  tether
# 4      bibox    4        LPT      livepeer        USDT  tether
#
#                 priceQuote                 priceUsd  \
# 0  100915.9800000000000000  100937.7399958714716024
# 1    3834.2000000000000000    3835.0267489070650299
# 2      23.3040000000000000      23.3090249221559239
# 3     705.3300000000000000     705.4820866951698340
# 4      18.1451050000000000      18.1490175360511528
#
#                volumeUsd24Hr percentExchangeVolume tradesCount24Hr  \
# 0  48443840.0501293730335927  100.0000000000000000               7
# 1  16844719.5306419892432481   12.8560863339509766            None
# 2  13572243.6528562034929416   10.3584945910872924            None
# 3   5568908.2520207065753745    4.2502557043822509            None
# 4   5375608.1688003445993516    4.1027268272335217            None
#
#          updated       date             time
# 0  1733366502860 2024-12-05  02:43:03.304000
# 1  1733366280938 2024-12-05  02:43:03.304000
# 2  1733361064151 2024-12-05  02:43:03.304000
# 3  1733363083954 2024-12-05  02:43:03.304000
# 4  1733341126193 2024-12-05  02:43:03.304000

# %% [markdown]
# ## Delta lake

# %%
def save_data_as_delta(df, path, mode="overwrite", partition_cols=None):
    #Guardar datos (opcionalmente particionados)|Escribe (write_deltalake)

    write_deltalake(
        path, df, mode=mode, partition_by=partition_cols
    )

def save_new_data_as_delta(new_data, data_path, predicate, partition_cols=None):
    #Guardar solo datos nuevos evitando duplicados	| MERGE (inserción condicional)
    try:
        dt = DeltaTable(data_path)
        # Convertir los nuevos datos a formato Arrow para trabajar con Delta
        new_data_pa = pa.Table.from_pandas(new_data)
        # Se insertan en target, datos de source que no existen en target
        dt.merge(
            source=new_data_pa,
            source_alias="source",
            target_alias="target",
            predicate=predicate
        ) \
        .when_not_matched_insert_all() \
        .execute()

    # sino se guarda como nueva
    except TableNotFoundError:
        save_data_as_delta(new_data, data_path, partition_cols=partition_cols)

def upsert_data_as_delta(data, data_path, predicate):
    #Actualizar o insertar registros dependiendo de coincidencias | MERGE (actualización/inserción)
    try:
        dt = DeltaTable(data_path)
        data_pa = pa.Table.from_pandas(data)
        dt.merge(
            source=data_pa,
            source_alias="source",
            target_alias="target",
            predicate=predicate
        ) \
        .when_matched_update_all() \
        .when_not_matched_insert_all() \
        .execute()
    except TableNotFoundError:
        save_data_as_delta(data, data_path)
    except Exception as e:
        # Capturar cualquier otro error
        print(f"Ocurrió un error al realizar el upsert: {e}")

# %%
#Ruta de guardado
bronze_dir = "datalake/bronze/api_coincap"
assets_raw_dir = f"{bronze_dir}/assets"

markets_raw_dir = f"{bronze_dir}/markets"

# %% [markdown]
# ### Assets
# https://api.coincap.io/v2/assets

# %%
# Guardar solo los nuevos datos (evitar duplicados) usando el predicado basado en el id
try:
    upsert_data_as_delta(
        df_assets,
        assets_raw_dir,
        "target.id = source.id"
    )
except Exception as e:
    print(f"Ocurrió un error al guardar los datos: {e}")

# %%
canRow = DeltaTable(assets_raw_dir)
print(f"Cant de filas: {canRow.to_pandas().shape[0]}")
# Out:
# Cant de filas: 105

# %%
#.sort_values("rank")
DeltaTable(assets_raw_dir).to_pandas()
# Cargar la tabla Delta como un DataFrame de Pandas
#df = DeltaTable(f"{bronze_dir}/assets").to_pandas()

# Filtrar las filas donde el id es "bitcoin"
#df_bitcoin = df[df['id'] == 'bitcoin']

# Mostrar las primeras 10 filas del DataFrame filtrado
#df_bitcoin.head(10)
# Out:
#                   id rank symbol             name  \
# 0             kusama   86    KSM           Kusama
# 1         enjin-coin   90    ENJ       Enjin Coin
# 2           algorand   33   ALGO         Algorand
# 3      akash-network   74    AKT    Akash Network
# 4    conflux-network   67    CFX          Conflux
# ..               ...  ...    ...              ...
# 100             dash   87   DASH             Dash
# 101          zilliqa   93    ZIL          Zilliqa
# 102        avalanche   12   AVAX        Avalanche
# 103  curve-dao-token   62    CRV  Curve DAO Token
# 104             holo   94    HOT             Holo
#
#                             supply                     maxSupply  \
# 0        15804124.9074820100000000                          None
# 1      1781382021.1205115000000000                          None
# 2      8298319517.0083080000000000  10000000000.0000000000000000
# 3       248285794.6611410000000000    388539008.0000000000000000
# 4      4721800273.2400000000000000                          None
# ..                             ...                           ...
# 100      12056866.0061047500000000     18900000.0000000000000000
# 101   19238514800.4426200000000000                          None
# 102     409353106.3767472000000000    715748719.0000000000000000
# 103    1245760052.0000000000000000                          None
# 104  174577454215.1585000000000000                          None
#
#                      marketCapUsd               volumeUsd24Hr  \
# 0      705258550.3219158067133275   73921165.8189207982543236
# 1      655046120.1442740384897777   40169331.2792776804707812
# 2     3954903910.3248322047038693  327451306.3084226791951081
# 3     1041069334.4653670968325097    8073501.8690067824162520
# 4     1142345533.5937651861557197   86679435.2975893224768192
# ..                            ...                         ...
# 100    696345524.7897072719016233  107753500.9341237264161507
# 101    642616214.4914120105409428   63029945.1965669521652060
# 102  21084856462.1773733553440941  709826759.0292905378102378
# 103   1319596526.0404586612496712  306102999.0358695771070106
# 104    636804330.6972250945015800   26122853.9460820701184059
#
#                 priceUsd    changePercent24Hr             vwap24Hr  \
# 0    44.6249668646969095   1.4013002527668877  46.5966792538972819
# 1     0.3677179360619357   6.0233954667309438   0.3688436857103774
# 2     0.4765909413609378  -8.3264024690324576   0.5001748223200967
# 3     4.1930281830509572  -1.9255141623924219   4.2415516498791999
# 4     0.2419300833344888  -5.6459915622422733   0.2500738003995627
# ..                   ...                  ...                  ...
# 100  57.7551019010352121   1.1291753583408621  59.0471037280956610
# 101   0.0334025896051304  -2.8212111185123160   0.0342056980889209
# 102  51.5077475502823562   0.0216949785181647  53.7161168045991353
# 103   1.0592702213575706  21.9879468000310851   1.0910834682277222
# 104   0.0036476894084639  -1.4187012974895007   0.0036647078333665
#
#                                               explorer       date  \
# 0                           https://kusama.subscan.io/ 2024-12-05
# 1    https://etherscan.io/token/0xf629cbd94d3791c92... 2024-12-05
# 2                             https://algoexplorer.io/ 2024-12-05
# 3                        https://akash.bigdipper.live/ 2024-12-05
# 4                           http://www.confluxscan.io/ 2024-12-05
# ..                                                 ...        ...
# 100                          https://explorer.dash.org 2024-12-05
# 101  https://etherscan.io/token/0x05f4a42e251f2d52b... 2024-12-05
# 102                              https://avascan.info/ 2024-12-05
# 103  https://etherscan.io/token/0xD533a949740bb3306... 2024-12-05
# 104  https://etherscan.io/token/0x6c6ee5e31d828de24... 2024-12-05
#
#                 time
# 0    02:43:00.613000
# 1    02:43:00.613000
# 2    02:43:00.613000
# 3    02:43:00.613000
# 4    02:43:00.613000
# ..               ...
# 100  02:43:00.613000
# 101  02:43:00.613000
# 102  02:43:00.613000
# 103  02:43:00.613000
# 104  02:43:00.613000
#
# [105 rows x 14 columns]

# %% [markdown]
# ### markets
# https://api.coincap.io/v2/markets

# %%
save_new_data_as_delta(
    df_markets,
    markets_raw_dir,
    """target.date = source.date""",
    partition_cols=["date"]
    )

# %%
canRowTwo = DeltaTable(markets_raw_dir)
print(f"Cant de filas: {canRowTwo.to_pandas().shape[0]}")
# Out:
# Cant de filas: 400

# %%
DeltaTable(markets_raw_dir).to_pandas()
# Out:
#     exchangeId rank baseSymbol                          baseId quoteSymbol  \
# 0    alterdice    1        BTC                         bitcoin        USDT
# 1        bibox    1        ETH                        ethereum        USDT
# 2        bibox    2       LINK                       chainlink        USDT
# 3        bibox    3        BNB                    binance-coin        USDT
# 4        bibox    4        LPT                        livepeer        USDT
# ..         ...  ...        ...                             ...         ...
# 395      bibox   95       COMP                        compound        USDT
# 396      bibox   96       ALGO                        algorand        USDC
# 397      bibox   97        FEI                    fei-protocol        USDT
# 398      bibox   98        MXC                             mxc        USDT
# 399      bibox   99       STPT  standard-tokenization-protocol        USDT
#
#       quoteId               priceQuote                 priceUsd  \
# 0      tether  100915.9800000000000000  100937.7399958714716024
# 1      tether    3834.2000000000000000    3835.0267489070650299
# 2      tether      23.3040000000000000      23.3090249221559239
# 3      tether     705.3300000000000000     705.4820866951698340
# 4      tether      18.1451050000000000      18.1490175360511528
# ..        ...                      ...                      ...
# 395    tether      50.9800000000000000      50.9786590664539657
# 396  usd-coin       0.1910000000000000       0.1909546324229206
# 397    tether       0.9778000000000000       0.9777742807998958
# 398    tether       0.0053000000000000       0.0052998605934132
# 399    tether       0.0468260000000000       0.0468247683296542
#
#                  volumeUsd24Hr percentExchangeVolume tradesCount24Hr  \
# 0    48443840.0501293730335927  100.0000000000000000               7
# 1    16844719.5306419892432481   12.8560863339509766            None
# 2    13572243.6528562034929416   10.3584945910872924            None
# 3     5568908.2520207065753745    4.2502557043822509            None
# 4     5375608.1688003445993516    4.1027268272335217            None
# ..                         ...                   ...             ...
# 395     98973.3129116484884251    0.0801091686095969            None
# 396     95641.1571956254842941    0.0774121160786120            None
# 397     92663.8837017479005621    0.0750023058247021            None
# 398     85479.0422475346855024    0.0691868828732385            None
# 399     84881.8597533795870478    0.0687035223419236            None
#
#            updated       date             time
# 0    1733366502860 2024-12-05  02:43:03.304000
# 1    1733366280938 2024-12-05  02:43:03.304000
# 2    1733361064151 2024-12-05  02:43:03.304000
# 3    1733363083954 2024-12-05  02:43:03.304000
# 4    1733341126193 2024-12-05  02:43:03.304000
# ..             ...        ...              ...
# 395  1731900793438 2024-11-18  03:43:38.954000
# 396  1731901088017 2024-11-18  03:43:38.954000
# 397  1731893360925 2024-11-18  03:43:38.954000
# 398  1731901070425 2024-11-18  03:43:38.954000
# 399  1731849859506 2024-11-18  03:43:38.954000
#
# [400 rows x 14 columns]

# %% [markdown]
# ## TP 2 final

# %%
# Leer los datos en DataFrames
assets_for_modify = DeltaTable(assets_raw_dir).to_pandas()
markets_for_modify = DeltaTable(markets_raw_dir).to_pandas()

# %%
# Renombrar columnas para mayor claridad
assets_for_modify = assets_for_modify.rename(columns={
    'id': 'asset_id',
    'rank': 'asset_rank',
    'name': 'asset_name'
})
markets_for_modify = markets_for_modify.rename(columns={
    'rank': 'market_rank',
    'baseSymbol': 'base_asset',
    'quoteSymbol': 'quote_asset'
})

# %%
# Convertir columnas a sus tipos correctos
assets_for_modify['supply'] = assets_for_modify['supply'].astype(float)  
assets_for_modify['priceUsd'] = assets_for_modify['priceUsd'].astype(float)  

markets_for_modify['volumeUsd24Hr'] = markets_for_modify['volumeUsd24Hr'].astype(float)
markets_for_modify['percentExchangeVolume'] = markets_for_modify['percentExchangeVolume'].astype(float)

#modificar valores nulos
markets_for_modify['tradesCount24Hr'] = markets_for_modify['tradesCount24Hr'].fillna(0)
markets_for_modify['volumeUsd24Hr'] = markets_for_modify['volumeUsd24Hr'].fillna(0)
assets_for_modify['maxSupply'] = assets_for_modify['maxSupply'].fillna(0)
assets_for_modify['explorer'] = assets_for_modify['explorer'].fillna("Not Data")

# %%
markets_for_modify.head(10)
# Out:
#   exchangeId market_rank base_asset             baseId quote_asset   quoteId  \
# 0  alterdice           1        BTC            bitcoin        USDT    tether
# 1      bibox           1        ETH           ethereum        USDT    tether
# 2      bibox           2       LINK          chainlink        USDT    tether
# 3      bibox           3        BNB       binance-coin        USDT    tether
# 4      bibox           4        LPT           livepeer        USDT    tether
# 5      bibox           5        WIN               wink        USDT    tether
# 6      bibox           6        GNO         gnosis-gno        USDT    tether
# 7      bibox           7        SLP  small-love-potion        USDT    tether
# 8      bibox           8        CHZ             chiliz        USDT    tether
# 9      bibox           9        LTC           litecoin         ETH  ethereum
#
#                 priceQuote                 priceUsd  volumeUsd24Hr  \
# 0  100915.9800000000000000  100937.7399958714716024   4.844384e+07
# 1    3834.2000000000000000    3835.0267489070650299   1.684472e+07
# 2      23.3040000000000000      23.3090249221559239   1.357224e+07
# 3     705.3300000000000000     705.4820866951698340   5.568908e+06
# 4      18.1451050000000000      18.1490175360511528   5.375608e+06
# 5       0.0001555500000000       0.0001555835404498   5.046443e+06
# 6     284.3820000000000000     284.4433198340433382   4.183565e+06
# 7       0.0052860000000000       0.0052871397931049   3.854250e+06
# 8       0.1277960000000000       0.1278235559969035   2.961764e+06
# 9       0.0337489500000000     129.5344100980548368   2.895562e+06
#
#    percentExchangeVolume tradesCount24Hr        updated       date  \
# 0             100.000000               7  1733366502860 2024-12-05
# 1              12.856086               0  1733366280938 2024-12-05
# 2              10.358495               0  1733361064151 2024-12-05
# 3               4.250256               0  1733363083954 2024-12-05
# 4               4.102727               0  1733341126193 2024-12-05
# 5               3.851504               0  1733366131432 2024-12-05
# 6               3.192946               0  1733357856300 2024-12-05
# 7               2.941609               0  1733362023776 2024-12-05
# 8               2.260453               0  1733366135247 2024-12-05
# 9               2.209926               0  1733366311977 2024-12-05
#
#               time
# 0  02:43:03.304000
# 1  02:43:03.304000
# 2  02:43:03.304000
# 3  02:43:03.304000
# 4  02:43:03.304000
# 5  02:43:03.304000
# 6  02:43:03.304000
# 7  02:43:03.304000
# 8  02:43:03.304000
# 9  02:43:03.304000

# %%
# Crear una columna booleana que indique si el precio supera cierto límite
assets_for_modify['high_value'] = assets_for_modify['priceUsd'] > 1000

# Crear una columna que indique si el volumen del mercado es significativo
markets_for_modify['high_volume'] = markets_for_modify['volumeUsd24Hr'] > 1_000_000

# %%
assets_for_modify.head(10)
# Out:
#           asset_id asset_rank symbol       asset_name        supply  \
# 0           kusama         86    KSM           Kusama  1.580412e+07
# 1       enjin-coin         90    ENJ       Enjin Coin  1.781382e+09
# 2         algorand         33   ALGO         Algorand  8.298320e+09
# 3    akash-network         74    AKT    Akash Network  2.482858e+08
# 4  conflux-network         67    CFX          Conflux  4.721800e+09
# 5       theta-fuel         96  TFUEL       Theta Fuel  6.766672e+09
# 6  wrapped-bitcoin         17   WBTC  Wrapped Bitcoin  1.379721e+05
# 7            sp8de         28    SPX            Sp8de  7.783757e+09
# 8            theta         39  THETA            THETA  1.000000e+09
# 9            maker         46    MKR            Maker  8.891726e+05
#
#                       maxSupply                  marketCapUsd  \
# 0                             0    705258550.3219158067133275
# 1                             0    655046120.1442740384897777
# 2  10000000000.0000000000000000   3954903910.3248322047038693
# 3    388539008.0000000000000000   1041069334.4653670968325097
# 4                             0   1142345533.5937651861557197
# 5                             0    619010028.2101940369601096
# 6                             0  13730859020.5108990156782745
# 7                             0   4905117871.4441059838450521
# 8   1000000000.0000000000000000   2914499801.2571051000000000
# 9      1005577.0000000000000000   1994512456.8930219224948408
#
#                 volumeUsd24Hr      priceUsd    changePercent24Hr  \
# 0   73921165.8189207982543236     44.624967   1.4013002527668877
# 1   40169331.2792776804707812      0.367718   6.0233954667309438
# 2  327451306.3084226791951081      0.476591  -8.3264024690324576
# 3    8073501.8690067824162520      4.193028  -1.9255141623924219
# 4   86679435.2975893224768192      0.241930  -5.6459915622422733
# 5    7538323.2109756757630578      0.091479   1.2357296750980222
# 6   61025741.3989695921550446  99519.074800   4.1459312335977909
# 7    5720435.1428574279804251      0.630174  -0.3504096179925493
# 8   96742749.9131060205215919      2.914500  -0.7506804989914074
# 9  171264004.5327777882643063   2243.110492  -3.6399577885640656
#
#                  vwap24Hr                                           explorer  \
# 0     46.5966792538972819                         https://kusama.subscan.io/
# 1      0.3688436857103774  https://etherscan.io/token/0xf629cbd94d3791c92...
# 2      0.5001748223200967                           https://algoexplorer.io/
# 3      4.2415516498791999                      https://akash.bigdipper.live/
# 4      0.2500738003995627                         http://www.confluxscan.io/
# 5      0.0939208805295643                   https://explorer.thetatoken.org/
# 6  96604.7771043853842781  https://etherscan.io/token/0x2260fac5e5542a773...
# 7      0.6573450021708661  https://etherscan.io/token/0x05aaaa829afa407d8...
# 8      2.9864967619894860                   https://explorer.thetatoken.org/
# 9   2314.5162287797212921                   https://etherscan.io/token/Maker
#
#         date             time  high_value
# 0 2024-12-05  02:43:00.613000       False
# 1 2024-12-05  02:43:00.613000       False
# 2 2024-12-05  02:43:00.613000       False
# 3 2024-12-05  02:43:00.613000       False
# 4 2024-12-05  02:43:00.613000       False
# 5 2024-12-05  02:43:00.613000       False
# 6 2024-12-05  02:43:00.613000        True
# 7 2024-12-05  02:43:00.613000       False
# 8 2024-12-05  02:43:00.613000       False
# 9 2024-12-05  02:43:00.613000        True

# %% [markdown]
# ### Join

# %%
# Hacer un JOIN entre assets y markets basado en el símbolo base (base_asset)
merged_markets_assets = pd.merge(markets_for_modify, assets_for_modify, left_on='base_asset', right_on='symbol', how='inner')

merged_markets_assets.head(10)
# Out:
#   exchangeId market_rank base_asset        baseId quote_asset   quoteId  \
# 0  alterdice           1        BTC       bitcoin        USDT    tether
# 1      bibox           1        ETH      ethereum        USDT    tether
# 2      bibox           2       LINK     chainlink        USDT    tether
# 3      bibox           3        BNB  binance-coin        USDT    tether
# 4      bibox           4        LPT      livepeer        USDT    tether
# 5      bibox           6        GNO    gnosis-gno        USDT    tether
# 6      bibox           8        CHZ        chiliz        USDT    tether
# 7      bibox           9        LTC      litecoin         ETH  ethereum
# 8      bibox          11        DOT      polkadot        USDT    tether
# 9      bibox          13        BCH  bitcoin-cash        USDT    tether
#
#                 priceQuote               priceUsd_x  volumeUsd24Hr_x  \
# 0  100915.9800000000000000  100937.7399958714716024     4.844384e+07
# 1    3834.2000000000000000    3835.0267489070650299     1.684472e+07
# 2      23.3040000000000000      23.3090249221559239     1.357224e+07
# 3     705.3300000000000000     705.4820866951698340     5.568908e+06
# 4      18.1451050000000000      18.1490175360511528     5.375608e+06
# 5     284.3820000000000000     284.4433198340433382     4.183565e+06
# 6       0.1277960000000000       0.1278235559969035     2.961764e+06
# 7       0.0337489500000000     129.5344100980548368     2.895562e+06
# 8       8.9499000000000000       8.9518298210952327     2.469783e+06
# 9     597.9400000000000000     598.0689307395259673     2.185309e+06
#
#    percentExchangeVolume  ...                   maxSupply  \
# 0             100.000000  ...   21000000.0000000000000000
# 1              12.856086  ...                           0
# 2              10.358495  ...                           0
# 3               4.250256  ...  166801148.0000000000000000
# 4               4.102727  ...                           0
# 5               3.192946  ...    3000000.0000000000000000
# 6               2.260453  ...                           0
# 7               2.209926  ...   84000000.0000000000000000
# 8               1.884967  ...                           0
# 9               1.667853  ...                           0
#
#                      marketCapUsd               volumeUsd24Hr_y  \
# 0  1979715808471.1145134388494256  27055581785.2751703938677858
# 1   461769382749.4349832916737059  19690161901.8066180021863565
# 2    14874802064.0965675160925789    936764121.2937993228263504
# 3   120620418671.5942988014635172   1925464184.0828705250403807
# 4      636310019.1713218991886187     40571178.8559568649664691
# 5      736263056.0396873445230736      6209027.3626601632317522
# 6     1179854339.1843697201395852    182571710.8834058857427533
# 7     9788320465.0213880828806823    960588302.2843340228315603
# 8    15705739800.5834280542317800   1113866189.6466356219373558
# 9    11764477707.2009327164250475    294250106.9395359741390944
#
#       priceUsd_y    changePercent24Hr                vwap24Hr  \
# 0  100033.299119   4.2783813194041564  97051.5062276099056651
# 1    3833.956765   5.0276625574947599   3776.4260733775174657
# 2      23.729445  -0.7816364667146088     24.6583153616802486
# 3     723.139020  -4.0687374077078990    749.4005444409089440
# 4      17.522849   5.9489030035011708     17.3245813402485970
# 5     284.316677   2.3360767817121198    281.4757804400228550
# 6       0.128150   6.6973197196652288      0.1312056098382506
# 7     130.043909   0.8403479537374443    129.5068442075368518
# 8      10.317335   5.4087788648598725     10.7743967641186914
# 9     594.237194   5.0108645154239155    569.2856248686518891
#
#                                             explorer     date_y  \
# 0                           https://blockchain.info/ 2024-12-05
# 1                              https://etherscan.io/ 2024-12-05
# 2  https://etherscan.io/token/0x514910771af9ca656... 2024-12-05
# 3  https://etherscan.io/token/0xB8c77482e45F1F44d... 2024-12-05
# 4                     https://explorer.livepeer.org/ 2024-12-05
# 5                  https://etherscan.io/token/Gnosis 2024-12-05
# 6  https://etherscan.io/token/0x3506424f91fd33084... 2024-12-05
# 7        http://explorer.litecoin.net/chain/Litecoin 2024-12-05
# 8                      https://polkascan.io/polkadot 2024-12-05
# 9         https://blockchair.com/bitcoin-cash/blocks 2024-12-05
#
#             time_y  high_value
# 0  02:43:00.613000        True
# 1  02:43:00.613000        True
# 2  02:43:00.613000       False
# 3  02:43:00.613000       False
# 4  02:43:00.613000       False
# 5  02:43:00.613000       False
# 6  02:43:00.613000       False
# 7  02:43:00.613000       False
# 8  02:43:00.613000       False
# 9  02:43:00.613000       False
#
# [10 rows x 30 columns]

# %% [markdown]
# ### Aggregation

# %%
#Convertir tradesCount24Hr a valores numéricos
markets_for_modify['tradesCount24Hr'] = pd.to_numeric(markets_for_modify['tradesCount24Hr'], errors='coerce').fillna(0)
#Confirmar los tipos de datos
print(markets_for_modify.dtypes[['volumeUsd24Hr', 'tradesCount24Hr']])
# Out:
# volumeUsd24Hr      float64
# tradesCount24Hr      int64
# dtype: object

# %%
# Calcular el volumen total en dólares y el promedio de transacciones por mercado
market_volume_summary = markets_for_modify.groupby('exchangeId').agg({
    'volumeUsd24Hr': 'sum', # Sumar el volumen de intercambio en USD por mercado
    'tradesCount24Hr': 'mean' # Calcular el promedio de transacciones por mercado
}).reset_index()

market_volume_summary.head()
# Out:
#   exchangeId  volumeUsd24Hr  tradesCount24Hr
# 0  alterdice   1.595605e+08              7.0
# 1      bibox   5.487822e+08              0.0

# %% [markdown]
# ### Guardado en Delta lake

# %%
#Ruta de guardado
silver_dir = "datalake/silver/api_coincap"
assets_raw_dir = f"{silver_dir}/assets"

markets_raw_dir = f"{silver_dir}/markets"
